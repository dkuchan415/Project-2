# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd
from config import api_key
from citipy import citipy
import numpy as np
import json
import random

# %%
# Save config information.
url = "http://api.sportradar.us/mlb/trial/v7/en/players/6e1cac5c-b059-4b80-a267-5143b19efb27/profile.json?"


# Build partial query URL
query_url = f"{url}api_key={api_key}"

# %%
# #test response to get data out of json
response1 = requests.get(query_url).json()
response1
# Out:
# {'player': {'id': '6e1cac5c-b059-4b80-a267-5143b19efb27',
#   'status': 'RET',
#   'position': 'IF',
#   'primary_position': '1B',
#   'first_name': 'Steven',
#   'last_name': 'Pearce',
#   'preferred_name': 'Steve',
#   'full_name': 'Steve Pearce',
#   'height': '71',
#   'weight': '200',
#   'throw_hand': 'R',
#   'bat_hand': 'R',
#   'college': 'South Carolina',
#   'high_school': 'Lakeland, FL',
#   'birthdate': '1983-04-13',
#   'birthstate': 'FL',
#   'birthcountry': 'USA',
#   'birthcity': 'Lakeland',
#   'pro_debut': '2007-09-01',
#   'updated': '2020-04-14T14:03:57+00:00',
#   'reference': '456665',
#   'draft': {'team_id': '481dfe7e-5dab-46ab-a49f-9dcc2b6e2cfd',
#    'year': 2005,
#    'round': 8,
#    'pick': 11},
#   'seasons': [{'id': '7f533168-b22c-4d8f-9593-0dacb2f0e84a',
#     'year': 2019,
#     'type': 'REG',
#     'totals': {'statistics': {'hitting': {'overall': {'ab': 89,
#         'lob': 53,
#         'rbi': 9,
#         'abhr': 89.0,
#         'abk': 2.871,
#         'bip': 58,
#         'babip': 0.259,
#         'bbk': 0.226,
#         'bbpa': 0.071,
#         'iso': 0.078,
#         'obp': 0.245,
#         'ops': 0.503,
#         'seca': 0.157,
#         'slg': 0.258,
#         'xbh': 5,
#         'pitch_count': 441,
#         'lob_risp_2out': 10,
#         'team_lob': 25,
#         'ab_risp': 23,
#         'hit_risp': 3,
#         'rbi_2out': 2,
#         'linedrive': 16,
#         'groundball': 25,
#         'popup': 5,
#         'flyball': 13,
#         'ap': 99,
#         'avg': '.180',
#         'gofo': 1.09,
#         'onbase': {'s': 11,
#          'd': 4,
#          't': 0,
#          'hr': 1,
#          'tb': 23,
#          'bb': 7,
#          'ibb': 0,
#          'hbp': 1,
#          'fc': 2,
#          'roe': 2,
#          'h': 16,
#          'cycle': 0},
#         'runs': {'total': 9},
#         'outcome': {'klook': 73,
#          'kswing': 66,
#          'ktotal': 139,
#          'ball': 136,
#          'iball': 0,
#          'dirtball': 20,
#          'foul': 85},
#         'outs': {'po': 4,
#          'fo': 11,
#          'fidp': 0,
#          'lo': 8,
#          'lidp': 0,
#          'go': 25,
#          'gidp': 5,
#          'klook': 7,
#          'kswing': 24,
#          'ktotal': 31,
#          'sacfly': 1,
#          'sachit': 0},
#         'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#         'pitches': {'count': 441, 'btotal': 158, 'ktotal': 283},
#         'games': {'start': 23, 'play': 29, 'finish': 6, 'complete': 17}}},
#       'fielding': {'overall': {'po': 100,
#         'a': 10,
#         'dp': 10,
#         'tp': 0,
#         'error': 3,
#         'tc': 113,
#         'fpct': 0.973,
#         'c_wp': 0,
#         'pb': 0,
#         'rf': 4.783,
#         'inn_1': 495,
#         'inn_2': 165.0,
#         'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#         'errors': {'throwing': 1,
#          'fielding': 2,
#          'interference': 0,
#          'total': 3},
#         'assists': {'outfield': 1, 'total': 10},
#         'games': {'start': 18, 'play': 23, 'finish': 5, 'complete': 0}},
#        'positions': [{'po': 97,
#          'a': 9,
#          'dp': 9,
#          'tp': 0,
#          'error': 3,
#          'tc': 109,
#          'fpct': 0.972,
#          'c_wp': 0,
#          'pb': 0,
#          'rf': 5.579,
#          'inn_1': 390,
#          'inn_2': 130.0,
#          'position': '1B',
#          'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#          'errors': {'throwing': 1,
#           'fielding': 2,
#           'interference': 0,
#           'total': 3},
#          'assists': {'outfield': 0, 'total': 9},
#          'games': {'start': 15, 'play': 19, 'finish': 4, 'complete': 0}},
#         {'po': 3,
#          'a': 1,
#          'dp': 1,
#          'tp': 0,
#          'error': 0,
#          'tc': 4,
#          'fpct': 1.0,
#          'c_wp': 0,
#          'pb': 0,
#          'rf': 1.0,
#          'inn_1': 105,
#          'inn_2': 35.0,
#          'position': 'LF',
#          'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#          'errors': {'throwing': 0,
#           'fielding': 0,
#           'interference': 0,
#           'total': 0},
#          'assists': {'outfield': 1, 'total': 1},
#          'games': {'start': 3, 'play': 4, 'finish': 1, 'complete': 0}}]}},
#      'splits': {'hitting': {'overall': [{'total': [{'ab': 89,
#            'runs': 9,
#            's': 11,
#            'd': 4,
#            't': 0,
#            'hr': 1,
#            'rbi': 9,
#            'bb': 7,
#            'ibb': 0,
#            'hbp': 1,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.245,
#            'slg': 0.258,
#            'ops': 0.503,
#            'h': 16,
#            'ktotal': 31,
#            'avg': '.180'}],
#          'day_night': [{'value': 'day',
#            'ab': 48,
#            'runs': 5,
#            's': 6,
#            'd': 1,
#            't': 0,
#            'hr': 1,
#            'rbi': 5,
#            'bb': 3,
#            'ibb': 0,
#            'hbp': 1,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.226,
#            'slg': 0.25,
#            'ops': 0.476,
#            'h': 8,
#            'ktotal': 17,
#            'avg': '.167'},
#           {'value': 'night',
#            'ab': 41,
#            'runs': 4,
#            's': 5,
#            'd': 3,
#            't': 0,
#            'hr': 0,
#            'rbi': 4,
#            'bb': 4,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.267,
#            'slg': 0.268,
#            'ops': 0.535,
#            'h': 8,
#            'ktotal': 14,
#            'avg': '.195'}],
#          'venue': [{'id': 'f0600f04-1386-4c61-a412-804960c46cb1',
#            'name': 'Minute Maid Park',
#            'market': 'Houston',
#            'surface': 'grass',
#            'ab': 8,
#            'runs': 1,
#            's': 2,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.25,
#            'ops': 0.5,
#            'h': 2,
#            'ktotal': 3,
#            'avg': '.250'},
#           {'id': '4a550fc1-c03d-4294-b63a-30ff197bedc4',
#            'name': 'Guaranteed Rate Field',
#            'market': 'Chicago',
#            'surface': 'grass',
#            'ab': 12,
#            'runs': 2,
#            's': 2,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 2,
#            'bb': 2,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.286,
#            'slg': 0.167,
#            'ops': 0.453,
#            'h': 2,
#            'ktotal': 5,
#            'avg': '.167'},
#           {'id': 'bf05de0d-7ced-4a19-8e17-2bbd985f8a92',
#            'name': 'Chase Field',
#            'market': 'Arizona',
#            'surface': 'turf',
#            'ab': 3,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.0,
#            'slg': 0.0,
#            'ops': 0.0,
#            'h': 0,
#            'ktotal': 1,
#            'avg': '.000'},
#           {'id': '706e9828-6687-4ac8-a409-3fb972e8bae9',
#            'name': 'Yankee Stadium',
#            'market': 'New York',
#            'surface': 'grass',
#            'ab': 9,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.111,
#            'slg': 0.111,
#            'ops': 0.222,
#            'h': 1,
#            'ktotal': 3,
#            'avg': '.111'},
#           {'id': '3aaaf4af-0f8c-49c1-8bf1-1780bb5a5f5c',
#            'name': 'Tropicana Field',
#            'market': 'Tampa Bay',
#            'surface': 'turf',
#            'ab': 5,
#            'runs': 1,
#            's': 0,
#            'd': 1,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.333,
#            'slg': 0.4,
#            'ops': 0.733,
#            'h': 1,
#            'ktotal': 2,
#            'avg': '.200'},
#           {'id': '84d72338-2173-4a90-9d25-99adc6c86f4b',
#            'name': 'Rogers Centre',
#            'market': 'Toronto',
#            'surface': 'turf',
#            'ab': 10,
#            'runs': 2,
#            's': 3,
#            'd': 1,
#            't': 0,
#            'hr': 1,
#            'rbi': 4,
#            'bb': 3,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.571,
#            'slg': 0.9,
#            'ops': 1.471,
#            'h': 5,
#            'ktotal': 2,
#            'avg': '.500'},
#           {'id': '48cbd35a-d932-4a75-beab-067bfbacfc26',
#            'name': 'Oakland Coliseum',
#            'market': 'Oakland',
#            'surface': 'grass',
#            'ab': 4,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.25,
#            'ops': 0.5,
#            'h': 1,
#            'ktotal': 3,
#            'avg': '.250'},
#           {'id': 'b27b0dc5-c2c5-401d-b8b9-a6a2dbc225e5',
#            'name': 'Fenway Park',
#            'market': 'Boston',
#            'surface': 'grass',
#            'ab': 35,
#            'runs': 3,
#            's': 2,
#            'd': 2,
#            't': 0,
#            'hr': 0,
#            'rbi': 3,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 1,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.162,
#            'slg': 0.171,
#            'ops': 0.333,
#            'h': 4,
#            'ktotal': 12,
#            'avg': '.114'},
#           {'id': '434aa63c-1049-4a54-a6bc-3790c7772ee1',
#            'name': 'Oriole Park at Camden Yards',
#            'market': 'Baltimore',
#            'surface': 'grass',
#            'ab': 3,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.0,
#            'slg': 0.0,
#            'ops': 0.0,
#            'h': 0,
#            'ktotal': 0,
#            'avg': '.000'}],
#          'surface': [{'value': 'grass',
#            'ab': 74,
#            'runs': 6,
#            's': 8,
#            'd': 2,
#            't': 0,
#            'hr': 0,
#            'rbi': 5,
#            'bb': 3,
#            'ibb': 0,
#            'hbp': 1,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.179,
#            'slg': 0.162,
#            'ops': 0.341,
#            'h': 10,
#            'ktotal': 27,
#            'avg': '.135'},
#           {'value': 'turf',
#            'ab': 15,
#            'runs': 3,
#            's': 3,
#            'd': 2,
#            't': 0,
#            'hr': 1,
#            'rbi': 4,
#            'bb': 4,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.5,
#            'slg': 0.733,
#            'ops': 1.233,
#            'h': 6,
#            'ktotal': 4,
#            'avg': '.400'}],
#          'month': [{'value': '4',
#            'ab': 39,
#            'runs': 2,
#            's': 3,
#            'd': 1,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 2,
#            'ibb': 0,
#            'hbp': 1,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.167,
#            'slg': 0.128,
#            'ops': 0.295,
#            'h': 4,
#            'ktotal': 17,
#            'avg': '.103'},
#           {'value': '5',
#            'ab': 50,
#            'runs': 7,
#            's': 8,
#            'd': 3,
#            't': 0,
#            'hr': 1,
#            'rbi': 8,
#            'bb': 5,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.304,
#            'slg': 0.36,
#            'ops': 0.664,
#            'h': 12,
#            'ktotal': 14,
#            'avg': '.240'}],
#          'home_away': [{'value': 'away',
#            'ab': 54,
#            'runs': 6,
#            's': 9,
#            'd': 2,
#            't': 0,
#            'hr': 1,
#            'rbi': 6,
#            'bb': 6,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.295,
#            'slg': 0.315,
#            'ops': 0.61,
#            'h': 12,
#            'ktotal': 19,
#            'avg': '.222'},
#           {'value': 'home',
#            'ab': 35,
#            'runs': 3,
#            's': 2,
#            'd': 2,
#            't': 0,
#            'hr': 0,
#            'rbi': 3,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 1,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.162,
#            'slg': 0.171,
#            'ops': 0.333,
#            'h': 4,
#            'ktotal': 12,
#            'avg': '.114'}],
#          'pitcher_hand': [{'value': 'L',
#            'ab': 40,
#            'runs': 5,
#            's': 6,
#            'd': 1,
#            't': 0,
#            'hr': 1,
#            'rbi': 3,
#            'bb': 2,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.238,
#            'slg': 0.3,
#            'ops': 0.538,
#            'h': 8,
#            'ktotal': 16,
#            'avg': '.200'},
#           {'value': 'R',
#            'ab': 49,
#            'runs': 4,
#            's': 5,
#            'd': 3,
#            't': 0,
#            'hr': 0,
#            'rbi': 6,
#            'bb': 5,
#            'ibb': 0,
#            'hbp': 1,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.224,
#            'ops': 0.474,
#            'h': 8,
#            'ktotal': 15,
#            'avg': '.163'}],
#          'opponent': [{'id': '29dd9a87-5bcc-4774-80c3-7f50d985068b',
#            'name': 'Rockies',
#            'market': 'Colorado',
#            'abbr': 'COL',
#            'ab': 3,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.0,
#            'slg': 0.0,
#            'ops': 0.0,
#            'h': 0,
#            'ktotal': 1,
#            'avg': '.000'},
#           {'id': '43a39081-52b4-4f93-ad29-da7f329ea960',
#            'name': 'Mariners',
#            'market': 'Seattle',
#            'abbr': 'SEA',
#            'ab': 6,
#            'runs': 2,
#            's': 0,
#            'd': 1,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.167,
#            'slg': 0.333,
#            'ops': 0.5,
#            'h': 1,
#            'ktotal': 2,
#            'avg': '.167'},
#           {'id': '80715d0d-0d2a-450f-a970-1b9a3b18c7e7',
#            'name': 'Indians',
#            'market': 'Cleveland',
#            'abbr': 'CLE',
#            'ab': 4,
#            'runs': 0,
#            's': 0,
#            'd': 1,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.5,
#            'ops': 0.75,
#            'h': 1,
#            'ktotal': 1,
#            'avg': '.250'},
#           {'id': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107',
#            'name': 'Astros',
#            'market': 'Houston',
#            'abbr': 'HOU',
#            'ab': 11,
#            'runs': 1,
#            's': 3,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.273,
#            'slg': 0.273,
#            'ops': 0.546,
#            'h': 3,
#            'ktotal': 3,
#            'avg': '.273'},
#           {'id': '47f490cd-2f58-4ef7-9dfd-2ad6ba6c1ae8',
#            'name': 'White Sox',
#            'market': 'Chicago',
#            'abbr': 'CWS',
#            'ab': 12,
#            'runs': 2,
#            's': 2,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 2,
#            'bb': 2,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.286,
#            'slg': 0.167,
#            'ops': 0.453,
#            'h': 2,
#            'ktotal': 5,
#            'avg': '.167'},
#           {'id': '27a59d3b-ff7c-48ea-b016-4798f560f5e1',
#            'name': 'Athletics',
#            'market': 'Oakland',
#            'abbr': 'OAK',
#            'ab': 4,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.25,
#            'ops': 0.5,
#            'h': 1,
#            'ktotal': 3,
#            'avg': '.250'},
#           {'id': '575c19b7-4052-41c2-9f0a-1c5813d02f99',
#            'name': 'Tigers',
#            'market': 'Detroit',
#            'abbr': 'DET',
#            'ab': 3,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.0,
#            'slg': 0.0,
#            'ops': 0.0,
#            'h': 0,
#            'ktotal': 2,
#            'avg': '.000'},
#           {'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#            'name': 'Orioles',
#            'market': 'Baltimore',
#            'abbr': 'BAL',
#            'ab': 12,
#            'runs': 1,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 1,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.154,
#            'slg': 0.083,
#            'ops': 0.237,
#            'h': 1,
#            'ktotal': 4,
#            'avg': '.083'},
#           {'id': 'a09ec676-f887-43dc-bbb3-cf4bbaee9a18',
#            'name': 'Yankees',
#            'market': 'New York',
#            'abbr': 'NYY',
#            'ab': 9,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.111,
#            'slg': 0.111,
#            'ops': 0.222,
#            'h': 1,
#            'ktotal': 3,
#            'avg': '.111'},
#           {'id': 'bdc11650-6f74-49c4-875e-778aeb7632d9',
#            'name': 'Rays',
#            'market': 'Tampa Bay',
#            'abbr': 'TB',
#            'ab': 12,
#            'runs': 1,
#            's': 0,
#            'd': 1,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 2,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.214,
#            'slg': 0.167,
#            'ops': 0.381,
#            'h': 1,
#            'ktotal': 4,
#            'avg': '.083'},
#           {'id': '25507be1-6a68-4267-bd82-e097d94b359b',
#            'name': 'Diamondbacks',
#            'market': 'Arizona',
#            'abbr': 'ARI',
#            'ab': 3,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.0,
#            'slg': 0.0,
#            'ops': 0.0,
#            'h': 0,
#            'ktotal': 1,
#            'avg': '.000'},
#           {'id': '1d678440-b4b1-4954-9b39-70afb3ebbcfa',
#            'name': 'Blue Jays',
#            'market': 'Toronto',
#            'abbr': 'TOR',
#            'ab': 10,
#            'runs': 2,
#            's': 3,
#            'd': 1,
#            't': 0,
#            'hr': 1,
#            'rbi': 4,
#            'bb': 3,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.571,
#            'slg': 0.9,
#            'ops': 1.471,
#            'h': 5,
#            'ktotal': 2,
#            'avg': '.500'}]}]}},
#      'statcast_metrics': {'hitting': {'overall': [{'travel_distance': {'min': 4.18,
#           'avg': 171.06,
#           'max': 376.36,
#           'count': 53}},
#         {'barreled_ball': {'min': 0.0, 'avg': 0.06, 'max': 1.0, 'count': 54}},
#         {'travel_time': {'min': 0.04, 'avg': 2.12, 'max': 5.2, 'count': 53}},
#         {'homerun_distance': {'min': 398.93,
#           'avg': 398.93,
#           'max': 398.93,
#           'count': 1}},
#         {'max_height': {'min': 1.67, 'avg': 44.6, 'max': 153.37, 'count': 54}},
#         {'generated_speed': {'min': 27.09,
#           'avg': 73.1,
#           'max': 91.92,
#           'count': 54}},
#         {'launch_speed': {'min': 43.66,
#           'avg': 88.52,
#           'max': 107.32,
#           'count': 59}},
#         {'launch_angle': {'min': -48.41,
#           'avg': 12.8,
#           'max': 70.68,
#           'count': 59}},
#         {'hang_time': {'min': 0.03, 'avg': 2.58, 'max': 6.4, 'count': 54}},
#         {'launch_spin_rate': {'min': 1009.78,
#           'avg': 2960.74,
#           'max': 5657.41,
#           'count': 34}},
#         {'distance': {'min': 3.68,
#           'avg': 168.12,
#           'max': 377.24,
#           'count': 53}}]}}},
#     'teams': [{'name': 'Red Sox',
#       'market': 'Boston',
#       'abbr': 'BOS',
#       'id': '93941372-eb4c-4c40-aced-fe3267174393',
#       'statistics': {'hitting': {'overall': {'ab': 89,
#          'lob': 53,
#          'rbi': 9,
#          'abhr': 89.0,
#          'abk': 2.871,
#          'bip': 58,
#          'babip': 0.259,
#          'bbk': 0.226,
#          'bbpa': 0.071,
#          'iso': 0.078,
#          'obp': 0.245,
#          'ops': 0.503,
#          'seca': 0.157,
#          'slg': 0.258,
#          'xbh': 5,
#          'pitch_count': 441,
#          'lob_risp_2out': 10,
#          'team_lob': 25,
#          'ab_risp': 23,
#          'hit_risp': 3,
#          'rbi_2out': 2,
#          'linedrive': 16,
#          'groundball': 25,
#          'popup': 5,
#          'flyball': 13,
#          'ap': 99,
#          'avg': '.180',
#          'gofo': 1.09,
#          'onbase': {'s': 11,
#           'd': 4,
#           't': 0,
#           'hr': 1,
#           'tb': 23,
#           'bb': 7,
#           'ibb': 0,
#           'hbp': 1,
#           'fc': 2,
#           'roe': 2,
#           'h': 16,
#           'cycle': 0},
#          'runs': {'total': 9},
#          'outcome': {'klook': 73,
#           'kswing': 66,
#           'ktotal': 139,
#           'ball': 136,
#           'iball': 0,
#           'dirtball': 20,
#           'foul': 85},
#          'outs': {'po': 4,
#           'fo': 11,
#           'fidp': 0,
#           'lo': 8,
#           'lidp': 0,
#           'go': 25,
#           'gidp': 5,
#           'klook': 7,
#           'kswing': 24,
#           'ktotal': 31,
#           'sacfly': 1,
#           'sachit': 0},
#          'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#          'pitches': {'count': 441, 'btotal': 158, 'ktotal': 283},
#          'games': {'start': 23, 'play': 29, 'finish': 6, 'complete': 17}}},
#        'fielding': {'overall': {'po': 100,
#          'a': 10,
#          'dp': 10,
#          'tp': 0,
#          'error': 3,
#          'tc': 113,
#          'fpct': 0.973,
#          'c_wp': 0,
#          'pb': 0,
#          'rf': 4.783,
#          'inn_1': 495,
#          'inn_2': 165.0,
#          'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#          'errors': {'throwing': 1,
#           'fielding': 2,
#           'interference': 0,
#           'total': 3},
#          'assists': {'outfield': 1, 'total': 10},
#          'games': {'start': 18, 'play': 23, 'finish': 5, 'complete': 0}},
#         'positions': [{'po': 97,
#           'a': 9,
#           'dp': 9,
#           'tp': 0,
#           'error': 3,
#           'tc': 109,
#           'fpct': 0.972,
#           'c_wp': 0,
#           'pb': 0,
#           'rf': 5.579,
#           'inn_1': 390,
#           'inn_2': 130.0,
#           'position': '1B',
#           'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#           'errors': {'throwing': 1,
#            'fielding': 2,
#            'interference': 0,
#            'total': 3},
#           'assists': {'outfield': 0, 'total': 9},
#           'games': {'start': 15, 'play': 19, 'finish': 4, 'complete': 0}},
#          {'po': 3,
#           'a': 1,
#           'dp': 1,
#           'tp': 0,
#           'error': 0,
#           'tc': 4,
#           'fpct': 1.0,
#           'c_wp': 0,
#           'pb': 0,
#           'rf': 1.0,
#           'inn_1': 105,
#           'inn_2': 35.0,
#           'position': 'LF',
#           'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#           'errors': {'throwing': 0,
#            'fielding': 0,
#            'interference': 0,
#            'total': 0},
#           'assists': {'outfield': 1, 'total': 1},
#           'games': {'start': 3, 'play': 4, 'finish': 1, 'complete': 0}}]}},
#       'splits': {'hitting': {'overall': [{'total': [{'ab': 89,
#             'runs': 9,
#             's': 11,
#             'd': 4,
#             't': 0,
#             'hr': 1,
#             'rbi': 9,
#             'bb': 7,
#             'ibb': 0,
#             'hbp': 1,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.245,
#             'slg': 0.258,
#             'ops': 0.503,
#             'h': 16,
#             'ktotal': 31,
#             'avg': '.180'}],
#           'day_night': [{'value': 'day',
#             'ab': 48,
#             'runs': 5,
#             's': 6,
#             'd': 1,
#             't': 0,
#             'hr': 1,
#             'rbi': 5,
#             'bb': 3,
#             'ibb': 0,
#             'hbp': 1,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.226,
#             'slg': 0.25,
#             'ops': 0.476,
#             'h': 8,
#             'ktotal': 17,
#             'avg': '.167'},
#            {'value': 'night',
#             'ab': 41,
#             'runs': 4,
#             's': 5,
#             'd': 3,
#             't': 0,
#             'hr': 0,
#             'rbi': 4,
#             'bb': 4,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.267,
#             'slg': 0.268,
#             'ops': 0.535,
#             'h': 8,
#             'ktotal': 14,
#             'avg': '.195'}],
#           'venue': [{'id': 'f0600f04-1386-4c61-a412-804960c46cb1',
#             'name': 'Minute Maid Park',
#             'market': 'Houston',
#             'surface': 'grass',
#             'ab': 8,
#             'runs': 1,
#             's': 2,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.25,
#             'slg': 0.25,
#             'ops': 0.5,
#             'h': 2,
#             'ktotal': 3,
#             'avg': '.250'},
#            {'id': '4a550fc1-c03d-4294-b63a-30ff197bedc4',
#             'name': 'Guaranteed Rate Field',
#             'market': 'Chicago',
#             'surface': 'grass',
#             'ab': 12,
#             'runs': 2,
#             's': 2,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 2,
#             'bb': 2,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.286,
#             'slg': 0.167,
#             'ops': 0.453,
#             'h': 2,
#             'ktotal': 5,
#             'avg': '.167'},
#            {'id': 'bf05de0d-7ced-4a19-8e17-2bbd985f8a92',
#             'name': 'Chase Field',
#             'market': 'Arizona',
#             'surface': 'turf',
#             'ab': 3,
#             'runs': 0,
#             's': 0,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.0,
#             'slg': 0.0,
#             'ops': 0.0,
#             'h': 0,
#             'ktotal': 1,
#             'avg': '.000'},
#            {'id': '706e9828-6687-4ac8-a409-3fb972e8bae9',
#             'name': 'Yankee Stadium',
#             'market': 'New York',
#             'surface': 'grass',
#             'ab': 9,
#             'runs': 0,
#             's': 1,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.111,
#             'slg': 0.111,
#             'ops': 0.222,
#             'h': 1,
#             'ktotal': 3,
#             'avg': '.111'},
#            {'id': '3aaaf4af-0f8c-49c1-8bf1-1780bb5a5f5c',
#             'name': 'Tropicana Field',
#             'market': 'Tampa Bay',
#             'surface': 'turf',
#             'ab': 5,
#             'runs': 1,
#             's': 0,
#             'd': 1,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 1,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.333,
#             'slg': 0.4,
#             'ops': 0.733,
#             'h': 1,
#             'ktotal': 2,
#             'avg': '.200'},
#            {'id': '84d72338-2173-4a90-9d25-99adc6c86f4b',
#             'name': 'Rogers Centre',
#             'market': 'Toronto',
#             'surface': 'turf',
#             'ab': 10,
#             'runs': 2,
#             's': 3,
#             'd': 1,
#             't': 0,
#             'hr': 1,
#             'rbi': 4,
#             'bb': 3,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.571,
#             'slg': 0.9,
#             'ops': 1.471,
#             'h': 5,
#             'ktotal': 2,
#             'avg': '.500'},
#            {'id': '48cbd35a-d932-4a75-beab-067bfbacfc26',
#             'name': 'Oakland Coliseum',
#             'market': 'Oakland',
#             'surface': 'grass',
#             'ab': 4,
#             'runs': 0,
#             's': 1,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.25,
#             'slg': 0.25,
#             'ops': 0.5,
#             'h': 1,
#             'ktotal': 3,
#             'avg': '.250'},
#            {'id': 'b27b0dc5-c2c5-401d-b8b9-a6a2dbc225e5',
#             'name': 'Fenway Park',
#             'market': 'Boston',
#             'surface': 'grass',
#             'ab': 35,
#             'runs': 3,
#             's': 2,
#             'd': 2,
#             't': 0,
#             'hr': 0,
#             'rbi': 3,
#             'bb': 1,
#             'ibb': 0,
#             'hbp': 1,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.162,
#             'slg': 0.171,
#             'ops': 0.333,
#             'h': 4,
#             'ktotal': 12,
#             'avg': '.114'},
#            {'id': '434aa63c-1049-4a54-a6bc-3790c7772ee1',
#             'name': 'Oriole Park at Camden Yards',
#             'market': 'Baltimore',
#             'surface': 'grass',
#             'ab': 3,
#             'runs': 0,
#             's': 0,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.0,
#             'slg': 0.0,
#             'ops': 0.0,
#             'h': 0,
#             'ktotal': 0,
#             'avg': '.000'}],
#           'surface': [{'value': 'grass',
#             'ab': 74,
#             'runs': 6,
#             's': 8,
#             'd': 2,
#             't': 0,
#             'hr': 0,
#             'rbi': 5,
#             'bb': 3,
#             'ibb': 0,
#             'hbp': 1,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.179,
#             'slg': 0.162,
#             'ops': 0.341,
#             'h': 10,
#             'ktotal': 27,
#             'avg': '.135'},
#            {'value': 'turf',
#             'ab': 15,
#             'runs': 3,
#             's': 3,
#             'd': 2,
#             't': 0,
#             'hr': 1,
#             'rbi': 4,
#             'bb': 4,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.5,
#             'slg': 0.733,
#             'ops': 1.233,
#             'h': 6,
#             'ktotal': 4,
#             'avg': '.400'}],
#           'month': [{'value': '4',
#             'ab': 39,
#             'runs': 2,
#             's': 3,
#             'd': 1,
#             't': 0,
#             'hr': 0,
#             'rbi': 1,
#             'bb': 2,
#             'ibb': 0,
#             'hbp': 1,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.167,
#             'slg': 0.128,
#             'ops': 0.295,
#             'h': 4,
#             'ktotal': 17,
#             'avg': '.103'},
#            {'value': '5',
#             'ab': 50,
#             'runs': 7,
#             's': 8,
#             'd': 3,
#             't': 0,
#             'hr': 1,
#             'rbi': 8,
#             'bb': 5,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.304,
#             'slg': 0.36,
#             'ops': 0.664,
#             'h': 12,
#             'ktotal': 14,
#             'avg': '.240'}],
#           'home_away': [{'value': 'away',
#             'ab': 54,
#             'runs': 6,
#             's': 9,
#             'd': 2,
#             't': 0,
#             'hr': 1,
#             'rbi': 6,
#             'bb': 6,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.295,
#             'slg': 0.315,
#             'ops': 0.61,
#             'h': 12,
#             'ktotal': 19,
#             'avg': '.222'},
#            {'value': 'home',
#             'ab': 35,
#             'runs': 3,
#             's': 2,
#             'd': 2,
#             't': 0,
#             'hr': 0,
#             'rbi': 3,
#             'bb': 1,
#             'ibb': 0,
#             'hbp': 1,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.162,
#             'slg': 0.171,
#             'ops': 0.333,
#             'h': 4,
#             'ktotal': 12,
#             'avg': '.114'}],
#           'pitcher_hand': [{'value': 'L',
#             'ab': 40,
#             'runs': 5,
#             's': 6,
#             'd': 1,
#             't': 0,
#             'hr': 1,
#             'rbi': 3,
#             'bb': 2,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.238,
#             'slg': 0.3,
#             'ops': 0.538,
#             'h': 8,
#             'ktotal': 16,
#             'avg': '.200'},
#            {'value': 'R',
#             'ab': 49,
#             'runs': 4,
#             's': 5,
#             'd': 3,
#             't': 0,
#             'hr': 0,
#             'rbi': 6,
#             'bb': 5,
#             'ibb': 0,
#             'hbp': 1,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.25,
#             'slg': 0.224,
#             'ops': 0.474,
#             'h': 8,
#             'ktotal': 15,
#             'avg': '.163'}],
#           'opponent': [{'id': '29dd9a87-5bcc-4774-80c3-7f50d985068b',
#             'name': 'Rockies',
#             'market': 'Colorado',
#             'abbr': 'COL',
#             'ab': 3,
#             'runs': 0,
#             's': 0,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.0,
#             'slg': 0.0,
#             'ops': 0.0,
#             'h': 0,
#             'ktotal': 1,
#             'avg': '.000'},
#            {'id': '43a39081-52b4-4f93-ad29-da7f329ea960',
#             'name': 'Mariners',
#             'market': 'Seattle',
#             'abbr': 'SEA',
#             'ab': 6,
#             'runs': 2,
#             's': 0,
#             'd': 1,
#             't': 0,
#             'hr': 0,
#             'rbi': 1,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.167,
#             'slg': 0.333,
#             'ops': 0.5,
#             'h': 1,
#             'ktotal': 2,
#             'avg': '.167'},
#            {'id': '80715d0d-0d2a-450f-a970-1b9a3b18c7e7',
#             'name': 'Indians',
#             'market': 'Cleveland',
#             'abbr': 'CLE',
#             'ab': 4,
#             'runs': 0,
#             's': 0,
#             'd': 1,
#             't': 0,
#             'hr': 0,
#             'rbi': 1,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.25,
#             'slg': 0.5,
#             'ops': 0.75,
#             'h': 1,
#             'ktotal': 1,
#             'avg': '.250'},
#            {'id': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107',
#             'name': 'Astros',
#             'market': 'Houston',
#             'abbr': 'HOU',
#             'ab': 11,
#             'runs': 1,
#             's': 3,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.273,
#             'slg': 0.273,
#             'ops': 0.546,
#             'h': 3,
#             'ktotal': 3,
#             'avg': '.273'},
#            {'id': '47f490cd-2f58-4ef7-9dfd-2ad6ba6c1ae8',
#             'name': 'White Sox',
#             'market': 'Chicago',
#             'abbr': 'CWS',
#             'ab': 12,
#             'runs': 2,
#             's': 2,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 2,
#             'bb': 2,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.286,
#             'slg': 0.167,
#             'ops': 0.453,
#             'h': 2,
#             'ktotal': 5,
#             'avg': '.167'},
#            {'id': '27a59d3b-ff7c-48ea-b016-4798f560f5e1',
#             'name': 'Athletics',
#             'market': 'Oakland',
#             'abbr': 'OAK',
#             'ab': 4,
#             'runs': 0,
#             's': 1,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.25,
#             'slg': 0.25,
#             'ops': 0.5,
#             'h': 1,
#             'ktotal': 3,
#             'avg': '.250'},
#            {'id': '575c19b7-4052-41c2-9f0a-1c5813d02f99',
#             'name': 'Tigers',
#             'market': 'Detroit',
#             'abbr': 'DET',
#             'ab': 3,
#             'runs': 0,
#             's': 0,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.0,
#             'slg': 0.0,
#             'ops': 0.0,
#             'h': 0,
#             'ktotal': 2,
#             'avg': '.000'},
#            {'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#             'name': 'Orioles',
#             'market': 'Baltimore',
#             'abbr': 'BAL',
#             'ab': 12,
#             'runs': 1,
#             's': 1,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 1,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 1,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.154,
#             'slg': 0.083,
#             'ops': 0.237,
#             'h': 1,
#             'ktotal': 4,
#             'avg': '.083'},
#            {'id': 'a09ec676-f887-43dc-bbb3-cf4bbaee9a18',
#             'name': 'Yankees',
#             'market': 'New York',
#             'abbr': 'NYY',
#             'ab': 9,
#             'runs': 0,
#             's': 1,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.111,
#             'slg': 0.111,
#             'ops': 0.222,
#             'h': 1,
#             'ktotal': 3,
#             'avg': '.111'},
#            {'id': 'bdc11650-6f74-49c4-875e-778aeb7632d9',
#             'name': 'Rays',
#             'market': 'Tampa Bay',
#             'abbr': 'TB',
#             'ab': 12,
#             'runs': 1,
#             's': 0,
#             'd': 1,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 2,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.214,
#             'slg': 0.167,
#             'ops': 0.381,
#             'h': 1,
#             'ktotal': 4,
#             'avg': '.083'},
#            {'id': '25507be1-6a68-4267-bd82-e097d94b359b',
#             'name': 'Diamondbacks',
#             'market': 'Arizona',
#             'abbr': 'ARI',
#             'ab': 3,
#             'runs': 0,
#             's': 0,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.0,
#             'slg': 0.0,
#             'ops': 0.0,
#             'h': 0,
#             'ktotal': 1,
#             'avg': '.000'},
#            {'id': '1d678440-b4b1-4954-9b39-70afb3ebbcfa',
#             'name': 'Blue Jays',
#             'market': 'Toronto',
#             'abbr': 'TOR',
#             'ab': 10,
#             'runs': 2,
#             's': 3,
#             'd': 1,
#             't': 0,
#             'hr': 1,
#             'rbi': 4,
#             'bb': 3,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.571,
#             'slg': 0.9,
#             'ops': 1.471,
#             'h': 5,
#             'ktotal': 2,
#             'avg': '.500'}]}]}}}]},
#    {'id': '00cd4d28-e638-4ae7-9824-6dbbfba50d4a',
#     'year': 2018,
#     'type': 'REG',
#     'totals': {'statistics': {'hitting': {'overall': {'ab': 215,
#         'lob': 85,
#         'rbi': 42,
#         'abhr': 19.545,
#         'abk': 5.244,
#         'bip': 165,
#         'babip': 0.303,
#         'bbk': 0.707,
#         'bbpa': 0.116,
#         'iso': 0.228,
#         'obp': 0.378,
#         'ops': 0.89,
#         'seca': 0.363,
#         'slg': 0.512,
#         'xbh': 26,
#         'pitch_count': 1047,
#         'lob_risp_2out': 26,
#         'team_lob': 46,
#         'ab_risp': 57,
#         'hit_risp': 21,
#         'rbi_2out': 18,
#         'linedrive': 46,
#         'groundball': 77,
#         'popup': 12,
#         'flyball': 41,
#         'ap': 251,
#         'avg': '.284',
#         'gofo': 1.05,
#         'onbase': {'s': 35,
#          'd': 14,
#          't': 1,
#          'hr': 11,
#          'tb': 110,
#          'bb': 29,
#          'ibb': 0,
#          'hbp': 5,
#          'fc': 8,
#          'roe': 4,
#          'h': 61,
#          'cycle': 0},
#         'runs': {'total': 35},
#         'outcome': {'klook': 165,
#          'kswing': 111,
#          'ktotal': 276,
#          'ball': 398,
#          'iball': 0,
#          'dirtball': 27,
#          'foul': 165},
#         'outs': {'po': 12,
#          'fo': 28,
#          'fidp': 0,
#          'lo': 17,
#          'lidp': 1,
#          'go': 60,
#          'gidp': 2,
#          'klook': 11,
#          'kswing': 30,
#          'ktotal': 41,
#          'sacfly': 2,
#          'sachit': 0},
#         'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#         'pitches': {'count': 1047, 'btotal': 430, 'ktotal': 617},
#         'games': {'start': 55, 'play': 76, 'finish': 19, 'complete': 37}}},
#       'fielding': {'overall': {'po': 200,
#         'a': 15,
#         'dp': 13,
#         'tp': 0,
#         'error': 1,
#         'tc': 216,
#         'fpct': 0.995,
#         'c_wp': 0,
#         'pb': 0,
#         'rf': 4.388,
#         'inn_1': 945,
#         'inn_2': 315.0,
#         'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#         'errors': {'throwing': 0,
#          'fielding': 1,
#          'interference': 0,
#          'total': 1},
#         'assists': {'outfield': 0, 'total': 15},
#         'games': {'start': 37, 'play': 49, 'finish': 11, 'complete': 0}},
#        'positions': [{'po': 182,
#          'a': 15,
#          'dp': 13,
#          'tp': 0,
#          'error': 1,
#          'tc': 198,
#          'fpct': 0.995,
#          'c_wp': 0,
#          'pb': 0,
#          'rf': 5.794,
#          'inn_1': 708,
#          'inn_2': 236.0,
#          'position': '1B',
#          'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#          'errors': {'throwing': 0,
#           'fielding': 1,
#           'interference': 0,
#           'total': 1},
#          'assists': {'outfield': 0, 'total': 15},
#          'games': {'start': 28, 'play': 34, 'finish': 6, 'complete': 0}},
#         {'po': 15,
#          'a': 0,
#          'dp': 0,
#          'tp': 0,
#          'error': 0,
#          'tc': 15,
#          'fpct': 1.0,
#          'c_wp': 0,
#          'pb': 0,
#          'rf': 1.364,
#          'inn_1': 171,
#          'inn_2': 57.0,
#          'position': 'LF',
#          'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#          'errors': {'throwing': 0,
#           'fielding': 0,
#           'interference': 0,
#           'total': 0},
#          'assists': {'outfield': 0, 'total': 0},
#          'games': {'start': 7, 'play': 11, 'finish': 4, 'complete': 0}},
#         {'po': 3,
#          'a': 0,
#          'dp': 0,
#          'tp': 0,
#          'error': 0,
#          'tc': 3,
#          'fpct': 1.0,
#          'c_wp': 0,
#          'pb': 0,
#          'rf': 0.75,
#          'inn_1': 66,
#          'inn_2': 22.0,
#          'position': 'RF',
#          'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#          'errors': {'throwing': 0,
#           'fielding': 0,
#           'interference': 0,
#           'total': 0},
#          'assists': {'outfield': 0, 'total': 0},
#          'games': {'start': 2, 'play': 4, 'finish': 1, 'complete': 0}}]}},
#      'splits': {'hitting': {'overall': [{'total': [{'ab': 215,
#            'runs': 35,
#            's': 35,
#            'd': 14,
#            't': 1,
#            'hr': 11,
#            'rbi': 42,
#            'bb': 29,
#            'ibb': 0,
#            'hbp': 5,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.378,
#            'slg': 0.512,
#            'ops': 0.89,
#            'h': 61,
#            'ktotal': 41,
#            'avg': '.284'}],
#          'day_night': [{'value': 'night',
#            'ab': 150,
#            'runs': 24,
#            's': 21,
#            'd': 12,
#            't': 1,
#            'hr': 9,
#            'rbi': 35,
#            'bb': 19,
#            'ibb': 0,
#            'hbp': 4,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.382,
#            'slg': 0.56,
#            'ops': 0.942,
#            'h': 43,
#            'ktotal': 25,
#            'avg': '.287'},
#           {'value': 'day',
#            'ab': 65,
#            'runs': 11,
#            's': 14,
#            'd': 2,
#            't': 0,
#            'hr': 2,
#            'rbi': 7,
#            'bb': 10,
#            'ibb': 0,
#            'hbp': 1,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.372,
#            'slg': 0.4,
#            'ops': 0.772,
#            'h': 18,
#            'ktotal': 16,
#            'avg': '.277'}],
#          'venue': [{'id': 'f0600f04-1386-4c61-a412-804960c46cb1',
#            'name': 'Minute Maid Park',
#            'market': 'Houston',
#            'surface': 'grass',
#            'ab': 2,
#            'runs': 1,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.333,
#            'slg': 0.0,
#            'ops': 0.333,
#            'h': 0,
#            'ktotal': 1,
#            'avg': '.000'},
#           {'id': '60732da9-ad03-4feb-9a36-aee3e98c7a2b',
#            'name': 'Angel Stadium of Anaheim',
#            'market': 'Los Angeles',
#            'surface': 'grass',
#            'ab': 11,
#            'runs': 1,
#            's': 3,
#            'd': 1,
#            't': 0,
#            'hr': 1,
#            'rbi': 3,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.455,
#            'slg': 0.818,
#            'ops': 1.273,
#            'h': 5,
#            'ktotal': 2,
#            'avg': '.455'},
#           {'id': '706e9828-6687-4ac8-a409-3fb972e8bae9',
#            'name': 'Yankee Stadium',
#            'market': 'New York',
#            'surface': 'grass',
#            'ab': 15,
#            'runs': 0,
#            's': 3,
#            'd': 1,
#            't': 0,
#            'hr': 0,
# ...
#             'h': 2,
#             'ktotal': 4,
#             'avg': '.133'},
#            {'id': 'f246a5e5-afdb-479c-9aaa-c68beeda7af6',
#             'name': 'Mets',
#             'market': 'New York',
#             'abbr': 'NYM',
#             'ab': 1,
#             'runs': 0,
#             's': 0,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.0,
#             'slg': 0.0,
#             'ops': 0.0,
#             'h': 0,
#             'ktotal': 1,
#             'avg': '.000'},
#            {'id': '2142e1ba-3b40-445c-b8bb-f1f8b1054220',
#             'name': 'Phillies',
#             'market': 'Philadelphia',
#             'abbr': 'PHI',
#             'ab': 1,
#             'runs': 0,
#             's': 0,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.0,
#             'slg': 0.0,
#             'ops': 0.0,
#             'h': 0,
#             'ktotal': 0,
#             'avg': '.000'},
#            {'id': '43a39081-52b4-4f93-ad29-da7f329ea960',
#             'name': 'Mariners',
#             'market': 'Seattle',
#             'abbr': 'SEA',
#             'ab': 11,
#             'runs': 2,
#             's': 2,
#             'd': 0,
#             't': 0,
#             'hr': 1,
#             'rbi': 5,
#             'bb': 1,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.333,
#             'slg': 0.545,
#             'ops': 0.878,
#             'h': 3,
#             'ktotal': 2,
#             'avg': '.273'},
#            {'id': '93941372-eb4c-4c40-aced-fe3267174393',
#             'name': 'Red Sox',
#             'market': 'Boston',
#             'abbr': 'BOS',
#             'ab': 47,
#             'runs': 6,
#             's': 7,
#             'd': 3,
#             't': 0,
#             'hr': 1,
#             'rbi': 7,
#             'bb': 5,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 1,
#             'cs': 0,
#             'obp': 0.302,
#             'slg': 0.362,
#             'ops': 0.664,
#             'h': 11,
#             'ktotal': 7,
#             'avg': '.234'},
#            {'id': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107',
#             'name': 'Astros',
#             'market': 'Houston',
#             'abbr': 'HOU',
#             'ab': 22,
#             'runs': 4,
#             's': 3,
#             'd': 0,
#             't': 0,
#             'hr': 2,
#             'rbi': 5,
#             'bb': 2,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.292,
#             'slg': 0.5,
#             'ops': 0.792,
#             'h': 5,
#             'ktotal': 9,
#             'avg': '.227'},
#            {'id': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d',
#             'name': 'Twins',
#             'market': 'Minnesota',
#             'abbr': 'MIN',
#             'ab': 5,
#             'runs': 1,
#             's': 0,
#             'd': 0,
#             't': 1,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.2,
#             'slg': 0.6,
#             'ops': 0.8,
#             'h': 1,
#             'ktotal': 1,
#             'avg': '.200'},
#            {'id': '575c19b7-4052-41c2-9f0a-1c5813d02f99',
#             'name': 'Tigers',
#             'market': 'Detroit',
#             'abbr': 'DET',
#             'ab': 5,
#             'runs': 0,
#             's': 1,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.2,
#             'slg': 0.2,
#             'ops': 0.4,
#             'h': 1,
#             'ktotal': 2,
#             'avg': '.200'},
#            {'id': 'bdc11650-6f74-49c4-875e-778aeb7632d9',
#             'name': 'Rays',
#             'market': 'Tampa Bay',
#             'abbr': 'TB',
#             'ab': 43,
#             'runs': 9,
#             's': 2,
#             'd': 3,
#             't': 0,
#             'hr': 4,
#             'rbi': 8,
#             'bb': 4,
#             'ibb': 0,
#             'hbp': 2,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.306,
#             'slg': 0.558,
#             'ops': 0.864,
#             'h': 9,
#             'ktotal': 10,
#             'avg': '.209'},
#            {'id': '833a51a9-0d84-410f-bd77-da08c3e5e26e',
#             'name': 'Royals',
#             'market': 'Kansas City',
#             'abbr': 'KC',
#             'ab': 16,
#             'runs': 4,
#             's': 4,
#             'd': 1,
#             't': 0,
#             'hr': 1,
#             'rbi': 2,
#             'bb': 1,
#             'ibb': 0,
#             'hbp': 1,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.444,
#             'slg': 0.625,
#             'ops': 1.069,
#             'h': 6,
#             'ktotal': 4,
#             'avg': '.375'},
#            {'id': '80715d0d-0d2a-450f-a970-1b9a3b18c7e7',
#             'name': 'Indians',
#             'market': 'Cleveland',
#             'abbr': 'CLE',
#             'ab': 5,
#             'runs': 0,
#             's': 1,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 1,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.333,
#             'slg': 0.2,
#             'ops': 0.533,
#             'h': 1,
#             'ktotal': 3,
#             'avg': '.200'}]}]}}}]},
#    {'id': '8f4e3a30-8444-11e3-808c-22000a904a71',
#     'year': 2014,
#     'type': 'PST',
#     'totals': {'statistics': {'hitting': {'overall': {'ab': 27,
#         'lob': 12,
#         'rbi': 1,
#         'abhr': 0,
#         'abk': 9.0,
#         'bip': 24,
#         'babip': 0.167,
#         'bbk': 0.667,
#         'bbpa': 0.067,
#         'iso': 0.037,
#         'obp': 0.233,
#         'ops': 0.418,
#         'seca': 0.111,
#         'slg': 0.185,
#         'xbh': 1,
#         'pitch_count': 100,
#         'ap': 30,
#         'avg': '.148',
#         'gofo': 0.33,
#         'onbase': {'s': 3,
#          'd': 1,
#          't': 0,
#          'hr': 0,
#          'tb': 5,
#          'bb': 2,
#          'ibb': 0,
#          'hbp': 1,
#          'fc': 1,
#          'roe': 0,
#          'h': 4,
#          'cycle': 0},
#         'runs': {'total': 4},
#         'outcome': {'klook': 5,
#          'kswing': 16,
#          'ktotal': 21,
#          'ball': 26,
#          'iball': 0,
#          'dirtball': 2,
#          'foul': 0},
#         'outs': {'po': 3,
#          'fo': 7,
#          'fidp': 0,
#          'lo': 5,
#          'lidp': 0,
#          'go': 5,
#          'gidp': 0,
#          'klook': 1,
#          'kswing': 2,
#          'ktotal': 3,
#          'sacfly': 0,
#          'sachit': 0},
#         'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#         'games': {'start': 7, 'play': 7, 'finish': 0, 'complete': 7}}},
#       'fielding': {'overall': {'po': 59,
#         'a': 4,
#         'dp': 7,
#         'tp': 0,
#         'error': 0,
#         'tc': 63,
#         'fpct': 1.0,
#         'rf': 9.0,
#         'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#         'errors': {'throwing': 0,
#          'fielding': 0,
#          'interference': 0,
#          'total': 0},
#         'games': {'start': 7, 'play': 7, 'finish': 0, 'complete': 0}}}}},
#     'teams': [{'name': 'Orioles',
#       'market': 'Baltimore',
#       'abbr': 'BAL',
#       'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#       'statistics': {'hitting': {'overall': {'ab': 27,
#          'lob': 12,
#          'rbi': 1,
#          'abhr': 0,
#          'abk': 9.0,
#          'bip': 24,
#          'babip': 0.167,
#          'bbk': 0.667,
#          'bbpa': 0.067,
#          'iso': 0.037,
#          'obp': 0.233,
#          'ops': 0.418,
#          'seca': 0.111,
#          'slg': 0.185,
#          'xbh': 1,
#          'pitch_count': 100,
#          'ap': 30,
#          'avg': '.148',
#          'gofo': 0.33,
#          'onbase': {'s': 3,
#           'd': 1,
#           't': 0,
#           'hr': 0,
#           'tb': 5,
#           'bb': 2,
#           'ibb': 0,
#           'hbp': 1,
#           'fc': 1,
#           'roe': 0,
#           'h': 4,
#           'cycle': 0},
#          'runs': {'total': 4},
#          'outcome': {'klook': 5,
#           'kswing': 16,
#           'ktotal': 21,
#           'ball': 26,
#           'iball': 0,
#           'dirtball': 2,
#           'foul': 0},
#          'outs': {'po': 3,
#           'fo': 7,
#           'fidp': 0,
#           'lo': 5,
#           'lidp': 0,
#           'go': 5,
#           'gidp': 0,
#           'klook': 1,
#           'kswing': 2,
#           'ktotal': 3,
#           'sacfly': 0,
#           'sachit': 0},
#          'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#          'games': {'start': 7, 'play': 7, 'finish': 0, 'complete': 7}}},
#        'fielding': {'overall': {'po': 59,
#          'a': 4,
#          'dp': 7,
#          'tp': 0,
#          'error': 0,
#          'tc': 63,
#          'fpct': 1.0,
#          'rf': 9.0,
#          'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#          'errors': {'throwing': 0,
#           'fielding': 0,
#           'interference': 0,
#           'total': 0},
#          'games': {'start': 7, 'play': 7, 'finish': 0, 'complete': 0}}}}}]},
#    {'id': '8f4e3a30-8444-11e3-808c-22000a904a71',
#     'year': 2014,
#     'type': 'REG',
#     'totals': {'statistics': {'hitting': {'overall': {'ab': 338,
#         'lob': 117,
#         'rbi': 49,
#         'abhr': 16.095,
#         'abk': 4.447,
#         'bip': 242,
#         'babip': 0.322,
#         'bbk': 0.526,
#         'bbpa': 0.104,
#         'iso': 0.263,
#         'obp': 0.373,
#         'ops': 0.929,
#         'seca': 0.396,
#         'slg': 0.556,
#         'xbh': 47,
#         'pitch_count': 1525,
#         'ap': 383,
#         'avg': '.293',
#         'gofo': 0.79,
#         'onbase': {'s': 52,
#          'd': 26,
#          't': 0,
#          'hr': 21,
#          'tb': 188,
#          'bb': 39,
#          'ibb': 1,
#          'hbp': 4,
#          'fc': 8,
#          'roe': 4,
#          'h': 99,
#          'cycle': 0},
#         'runs': {'total': 51},
#         'outcome': {'klook': 216,
#          'kswing': 124,
#          'ktotal': 340,
#          'ball': 513,
#          'iball': 3,
#          'dirtball': 23,
#          'foul': 0},
#         'outs': {'po': 23,
#          'fo': 64,
#          'fidp': 0,
#          'lo': 6,
#          'lidp': 0,
#          'go': 74,
#          'gidp': 4,
#          'klook': 14,
#          'kswing': 62,
#          'ktotal': 76,
#          'sacfly': 1,
#          'sachit': 0},
#         'steal': {'caught': 0, 'stolen': 5, 'pct': 1.0, 'pickoff': 0},
#         'games': {'start': 86, 'play': 102, 'finish': 14, 'complete': 62}}},
#       'fielding': {'overall': {'po': 474,
#         'a': 42,
#         'dp': 35,
#         'tp': 0,
#         'error': 1,
#         'tc': 517,
#         'fpct': 0.998,
#         'rf': 5.489,
#         'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#         'errors': {'throwing': 0,
#          'fielding': 0,
#          'interference': 0,
#          'total': 1},
#         'games': {'start': 78, 'play': 94, 'finish': 14, 'complete': 6}}}}},
#     'teams': [{'name': 'Orioles',
#       'market': 'Baltimore',
#       'abbr': 'BAL',
#       'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#       'statistics': {'hitting': {'overall': {'ab': 338,
#          'lob': 117,
#          'rbi': 49,
#          'abhr': 16.095,
#          'abk': 4.447,
#          'bip': 242,
#          'babip': 0.322,
#          'bbk': 0.526,
#          'bbpa': 0.104,
#          'iso': 0.263,
#          'obp': 0.373,
#          'ops': 0.929,
#          'seca': 0.396,
#          'slg': 0.556,
#          'xbh': 47,
#          'pitch_count': 1525,
#          'ap': 383,
#          'avg': '.293',
#          'gofo': 0.79,
#          'onbase': {'s': 52,
#           'd': 26,
#           't': 0,
#           'hr': 21,
#           'tb': 188,
#           'bb': 39,
#           'ibb': 1,
#           'hbp': 4,
#           'fc': 8,
#           'roe': 4,
#           'h': 99,
#           'cycle': 0},
#          'runs': {'total': 51},
#          'outcome': {'klook': 216,
#           'kswing': 124,
#           'ktotal': 340,
#           'ball': 513,
#           'iball': 3,
#           'dirtball': 23,
#           'foul': 0},
#          'outs': {'po': 23,
#           'fo': 64,
#           'fidp': 0,
#           'lo': 6,
#           'lidp': 0,
#           'go': 74,
#           'gidp': 4,
#           'klook': 14,
#           'kswing': 62,
#           'ktotal': 76,
#           'sacfly': 1,
#           'sachit': 0},
#          'steal': {'caught': 0, 'stolen': 5, 'pct': 1.0, 'pickoff': 0},
#          'games': {'start': 86, 'play': 102, 'finish': 14, 'complete': 62}}},
#        'fielding': {'overall': {'po': 474,
#          'a': 42,
#          'dp': 35,
#          'tp': 0,
#          'error': 1,
#          'tc': 517,
#          'fpct': 0.998,
#          'rf': 5.489,
#          'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#          'errors': {'throwing': 0,
#           'fielding': 0,
#           'interference': 0,
#           'total': 1},
#          'games': {'start': 78, 'play': 94, 'finish': 14, 'complete': 6}}}}}]},
#    {'id': '58dd9a81-4a38-4a66-8cd7-32ae4d567ba8',
#     'year': 2013,
#     'type': 'REG',
#     'totals': {'statistics': {'hitting': {'overall': {'ab': 119,
#         'lob': 50,
#         'rbi': 13,
#         'abhr': 29.75,
#         'abk': 4.76,
#         'bip': 90,
#         'babip': 0.3,
#         'bbk': 0.6,
#         'bbpa': 0.109,
#         'iso': 0.159,
#         'obp': 0.362,
#         'ops': 0.782,
#         'seca': 0.294,
#         'slg': 0.42,
#         'xbh': 11,
#         'pitch_count': 562,
#         'ap': 138,
#         'avg': '.261',
#         'gofo': 0.51,
#         'onbase': {'s': 20,
#          'd': 7,
#          't': 0,
#          'hr': 4,
#          'tb': 50,
#          'bb': 14,
#          'ibb': 1,
#          'hbp': 4,
#          'fc': 6,
#          'roe': 1,
#          'h': 31,
#          'cycle': 0},
#         'runs': {'total': 14},
#         'outcome': {'klook': 98,
#          'kswing': 37,
#          'ktotal': 135,
#          'ball': 181,
#          'iball': 3,
#          'dirtball': 13,
#          'foul': 0},
#         'outs': {'po': 10,
#          'fo': 24,
#          'fidp': 0,
#          'lo': 3,
#          'lidp': 0,
#          'go': 19,
#          'gidp': 0,
#          'klook': 2,
#          'kswing': 23,
#          'ktotal': 25,
#          'sacfly': 0,
#          'sachit': 0},
#         'steal': {'caught': 0, 'stolen': 1, 'pct': 1.0, 'pickoff': 0},
#         'games': {'start': 37, 'play': 44, 'finish': 27, 'complete': 22}}}}},
#     'teams': [{'name': 'Orioles',
#       'market': 'Baltimore',
#       'abbr': 'BAL',
#       'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#       'statistics': {'hitting': {'overall': {'ab': 119,
#          'lob': 50,
#          'rbi': 13,
#          'abhr': 29.75,
#          'abk': 4.76,
#          'bip': 90,
#          'babip': 0.3,
#          'bbk': 0.6,
#          'bbpa': 0.109,
#          'iso': 0.159,
#          'obp': 0.362,
#          'ops': 0.782,
#          'seca': 0.294,
#          'slg': 0.42,
#          'xbh': 11,
#          'pitch_count': 562,
#          'ap': 138,
#          'avg': '.261',
#          'gofo': 0.51,
#          'onbase': {'s': 20,
#           'd': 7,
#           't': 0,
#           'hr': 4,
#           'tb': 50,
#           'bb': 14,
#           'ibb': 1,
#           'hbp': 4,
#           'fc': 6,
#           'roe': 1,
#           'h': 31,
#           'cycle': 0},
#          'runs': {'total': 14},
#          'outcome': {'klook': 98,
#           'kswing': 37,
#           'ktotal': 135,
#           'ball': 181,
#           'iball': 3,
#           'dirtball': 13,
#           'foul': 0},
#          'outs': {'po': 10,
#           'fo': 24,
#           'fidp': 0,
#           'lo': 3,
#           'lidp': 0,
#           'go': 19,
#           'gidp': 0,
#           'klook': 2,
#           'kswing': 23,
#           'ktotal': 25,
#           'sacfly': 0,
#           'sachit': 0},
#          'steal': {'caught': 0, 'stolen': 1, 'pct': 1.0, 'pickoff': 0},
#          'games': {'start': 37,
#           'play': 44,
#           'finish': 27,
#           'complete': 22}}}}}]}]},
#  '_comment': 'Generation started @ 2021-01-18 03:28:52 UTC ended @ 2021-01-18 03:28:52 UTC'}

# %%
# Save config information.
url2 = "http://api.sportradar.us/mlb/trial/v7/en/players/29a80d91-946d-4701-af7d-034850bdef00/profile.json?"


# Build partial query URL
query_url = f"{url2}api_key={api_key}"

# %%
# #test response to get data out of json
response2 = requests.get(query_url).json()
response2
# Out:
# {'player': {'id': '29a80d91-946d-4701-af7d-034850bdef00',
#   'status': 'FA',
#   'position': 'IF',
#   'primary_position': '2B',
#   'first_name': 'James',
#   'last_name': 'Dozier',
#   'preferred_name': 'Brian',
#   'full_name': 'Brian Dozier',
#   'height': '71',
#   'weight': '200',
#   'throw_hand': 'R',
#   'bat_hand': 'R',
#   'college': 'Southern Mississippi',
#   'high_school': 'Itawamba Agricultural (MS)',
#   'birthdate': '1987-05-15',
#   'birthstate': 'MS',
#   'birthcountry': 'USA',
#   'birthcity': 'Tupelo',
#   'pro_debut': '2012-05-07',
#   'updated': '2020-08-24T13:25:47+00:00',
#   'reference': '572821',
#   'draft': {'team_id': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d',
#    'year': 2009,
#    'round': 8,
#    'pick': 21},
#   'seasons': [{'id': 'bd17502c-7dff-4f86-980b-df765f895163',
#     'year': 2020,
#     'type': 'PRE',
#     'totals': {'statistics': {'hitting': {'overall': {'ab': 22,
#         'lob': 11,
#         'rbi': 1,
#         'abhr': 0,
#         'abk': 2.444,
#         'bip': 13,
#         'babip': 0.385,
#         'bbk': 0.333,
#         'bbpa': 0.12,
#         'iso': 0.0,
#         'obp': 0.32,
#         'ops': 0.547,
#         'seca': 0.136,
#         'slg': 0.227,
#         'xbh': 0,
#         'pitch_count': 56,
#         'lob_risp_2out': 1,
#         'team_lob': 4,
#         'ab_risp': 4,
#         'hit_risp': 1,
#         'rbi_2out': 0,
#         'linedrive': 3,
#         'groundball': 4,
#         'popup': 2,
#         'flyball': 4,
#         'ap': 25,
#         'avg': '.227',
#         'gofo': 0.33,
#         'onbase': {'s': 5,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'tb': 5,
#          'bb': 3,
#          'ibb': 0,
#          'hbp': 0,
#          'fc': 1,
#          'roe': 0,
#          'h': 5,
#          'cycle': 0},
#         'runs': {'total': 1},
#         'outcome': {'klook': 8,
#          'kswing': 19,
#          'ktotal': 27,
#          'ball': 15,
#          'iball': 0,
#          'dirtball': 0,
#          'foul': 1},
#         'outs': {'po': 2,
#          'fo': 3,
#          'fidp': 0,
#          'lo': 1,
#          'lidp': 0,
#          'go': 2,
#          'gidp': 0,
#          'klook': 1,
#          'kswing': 8,
#          'ktotal': 9,
#          'sacfly': 0,
#          'sachit': 0},
#         'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#         'pitches': {'count': 56, 'btotal': 15, 'ktotal': 41},
#         'games': {'start': 8, 'play': 8, 'finish': 0, 'complete': 0}}},
#       'fielding': {'overall': {'po': 11,
#         'a': 11,
#         'dp': 5,
#         'tp': 0,
#         'error': 0,
#         'tc': 22,
#         'fpct': 1.0,
#         'c_wp': 0,
#         'pb': 0,
#         'rf': 3.667,
#         'inn_1': 96,
#         'inn_2': 32.0,
#         'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#         'errors': {'throwing': 0,
#          'fielding': 0,
#          'interference': 0,
#          'total': 0},
#         'assists': {'outfield': 0, 'total': 11},
#         'games': {'start': 6, 'play': 6, 'finish': 0, 'complete': 0}},
#        'positions': [{'po': 11,
#          'a': 11,
#          'dp': 5,
#          'tp': 0,
#          'error': 0,
#          'tc': 22,
#          'fpct': 1.0,
#          'c_wp': 0,
#          'pb': 0,
#          'rf': 3.667,
#          'inn_1': 96,
#          'inn_2': 32.0,
#          'position': '2B',
#          'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#          'errors': {'throwing': 0,
#           'fielding': 0,
#           'interference': 0,
#           'total': 0},
#          'assists': {'outfield': 0, 'total': 11},
#          'games': {'start': 6, 'play': 6, 'finish': 0, 'complete': 0}}]}},
#      'splits': {'hitting': {'overall': [{'total': [{'ab': 22,
#            'runs': 1,
#            's': 5,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 3,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.32,
#            'slg': 0.227,
#            'ops': 0.547,
#            'h': 5,
#            'ktotal': 9,
#            'avg': '.227'}],
#          'day_night': [{'value': 'day',
#            'ab': 19,
#            'runs': 1,
#            's': 5,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 2,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.333,
#            'slg': 0.263,
#            'ops': 0.596,
#            'h': 5,
#            'ktotal': 8,
#            'avg': '.263'},
#           {'value': 'night',
#            'ab': 3,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.0,
#            'ops': 0.25,
#            'h': 0,
#            'ktotal': 1,
#            'avg': '.000'}],
#          'venue': [{'id': '6a22ca0a-2d84-4301-86b8-587e2b01afb0',
#            'name': 'Tempe Diablo Stadium',
#            'surface': 'grass',
#            'ab': 3,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.333,
#            'slg': 0.333,
#            'ops': 0.666,
#            'h': 1,
#            'ktotal': 1,
#            'avg': '.333'},
#           {'id': '164ee38f-1444-4461-adcb-d6ee21e48aa8',
#            'name': 'Salt River Fields at Talking Stick',
#            'surface': 'grass',
#            'ab': 3,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.0,
#            'slg': 0.0,
#            'ops': 0.0,
#            'h': 0,
#            'ktotal': 2,
#            'avg': '.000'},
#           {'id': '228bcacb-77e3-43eb-b149-eb9762d41ff8',
#            'name': 'Peoria Sports Complex',
#            'surface': 'grass',
#            'ab': 7,
#            'runs': 1,
#            's': 2,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 2,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.444,
#            'slg': 0.286,
#            'ops': 0.73,
#            'h': 2,
#            'ktotal': 2,
#            'avg': '.286'},
#           {'id': '1795d517-a828-4078-a759-805cb9e54d67',
#            'name': 'Sloan Park',
#            'surface': 'grass',
#            'ab': 3,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.0,
#            'ops': 0.25,
#            'h': 0,
#            'ktotal': 1,
#            'avg': '.000'},
#           {'id': '8f0cd62f-3d82-4a90-9710-f67f7402b190',
#            'name': 'Goodyear Ballpark',
#            'surface': 'grass',
#            'ab': 3,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.0,
#            'slg': 0.0,
#            'ops': 0.0,
#            'h': 0,
#            'ktotal': 2,
#            'avg': '.000'},
#           {'id': 'ed6c506c-8bbd-4b7e-8cbc-acbe33148c98',
#            'name': 'Camelback Ranch',
#            'surface': 'grass',
#            'ab': 3,
#            'runs': 0,
#            's': 2,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.667,
#            'slg': 0.667,
#            'ops': 1.334,
#            'h': 2,
#            'ktotal': 1,
#            'avg': '.667'}],
#          'surface': [{'value': 'grass',
#            'ab': 22,
#            'runs': 1,
#            's': 5,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 3,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.32,
#            'slg': 0.227,
#            'ops': 0.547,
#            'h': 5,
#            'ktotal': 9,
#            'avg': '.227'}],
#          'month': [{'value': '2',
#            'ab': 6,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.167,
#            'slg': 0.167,
#            'ops': 0.334,
#            'h': 1,
#            'ktotal': 3,
#            'avg': '.167'},
#           {'value': '3',
#            'ab': 16,
#            'runs': 1,
#            's': 4,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 3,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.368,
#            'slg': 0.25,
#            'ops': 0.618,
#            'h': 4,
#            'ktotal': 6,
#            'avg': '.250'}],
#          'home_away': [{'value': 'home',
#            'ab': 5,
#            'runs': 1,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.333,
#            'slg': 0.2,
#            'ops': 0.533,
#            'h': 1,
#            'ktotal': 1,
#            'avg': '.200'},
#           {'value': 'away',
#            'ab': 17,
#            'runs': 0,
#            's': 4,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 2,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.316,
#            'slg': 0.235,
#            'ops': 0.551,
#            'h': 4,
#            'ktotal': 8,
#            'avg': '.235'}],
#          'pitcher_hand': [{'value': 'L',
#            'ab': 5,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.2,
#            'slg': 0.2,
#            'ops': 0.4,
#            'h': 1,
#            'ktotal': 3,
#            'avg': '.200'},
#           {'value': 'R',
#            'ab': 17,
#            'runs': 1,
#            's': 4,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 3,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.35,
#            'slg': 0.235,
#            'ops': 0.585,
#            'h': 4,
#            'ktotal': 6,
#            'avg': '.235'}],
#          'opponent': [{'id': '43a39081-52b4-4f93-ad29-da7f329ea960',
#            'name': 'Mariners',
#            'market': 'Seattle',
#            'abbr': 'SEA',
#            'ab': 2,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.667,
#            'slg': 0.5,
#            'ops': 1.167,
#            'h': 1,
#            'ktotal': 1,
#            'avg': '.500'},
#           {'id': '25507be1-6a68-4267-bd82-e097d94b359b',
#            'name': 'Diamondbacks',
#            'market': 'Arizona',
#            'abbr': 'ARI',
#            'ab': 3,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.0,
#            'slg': 0.0,
#            'ops': 0.0,
#            'h': 0,
#            'ktotal': 2,
#            'avg': '.000'},
#           {'id': '4f735188-37c8-473d-ae32-1f7e34ccf892',
#            'name': 'Angels',
#            'market': 'Los Angeles',
#            'abbr': 'LAA',
#            'ab': 3,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.333,
#            'slg': 0.333,
#            'ops': 0.666,
#            'h': 1,
#            'ktotal': 1,
#            'avg': '.333'},
#           {'id': 'c874a065-c115-4e7d-b0f0-235584fb0e6f',
#            'name': 'Reds',
#            'market': 'Cincinnati',
#            'abbr': 'CIN',
#            'ab': 3,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.0,
#            'slg': 0.0,
#            'ops': 0.0,
#            'h': 0,
#            'ktotal': 2,
#            'avg': '.000'},
#           {'id': '47f490cd-2f58-4ef7-9dfd-2ad6ba6c1ae8',
#            'name': 'White Sox',
#            'market': 'Chicago',
#            'abbr': 'CWS',
#            'ab': 3,
#            'runs': 0,
#            's': 2,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.667,
#            'slg': 0.667,
#            'ops': 1.334,
#            'h': 2,
#            'ktotal': 1,
#            'avg': '.667'},
#           {'id': 'dcfd5266-00ce-442c-bc09-264cd20cf455',
#            'name': 'Brewers',
#            'market': 'Milwaukee',
#            'abbr': 'MIL',
#            'ab': 2,
#            'runs': 1,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.333,
#            'slg': 0.0,
#            'ops': 0.333,
#            'h': 0,
#            'ktotal': 0,
#            'avg': '.000'},
#           {'id': '55714da8-fcaf-4574-8443-59bfb511a524',
#            'name': 'Cubs',
#            'market': 'Chicago',
#            'abbr': 'CHC',
#            'ab': 3,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.0,
#            'ops': 0.25,
#            'h': 0,
#            'ktotal': 1,
#            'avg': '.000'},
#           {'id': 'ef64da7f-cfaf-4300-87b0-9313386b977c',
#            'name': 'Dodgers',
#            'market': 'Los Angeles',
#            'abbr': 'LAD',
#            'ab': 3,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.333,
#            'slg': 0.333,
#            'ops': 0.666,
#            'h': 1,
#            'ktotal': 1,
#            'avg': '.333'}]}]}}},
#     'teams': [{'name': 'Padres',
#       'market': 'San Diego',
#       'abbr': 'SD',
#       'id': 'd52d5339-cbdd-43f3-9dfa-a42fd588b9a3',
#       'statistics': {'hitting': {'overall': {'ab': 22,
#          'lob': 11,
#          'rbi': 1,
#          'abhr': 0,
#          'abk': 2.444,
#          'bip': 13,
#          'babip': 0.385,
#          'bbk': 0.333,
#          'bbpa': 0.12,
#          'iso': 0.0,
#          'obp': 0.32,
#          'ops': 0.547,
#          'seca': 0.136,
#          'slg': 0.227,
#          'xbh': 0,
#          'pitch_count': 56,
#          'lob_risp_2out': 1,
#          'team_lob': 4,
#          'ab_risp': 4,
#          'hit_risp': 1,
#          'rbi_2out': 0,
#          'linedrive': 3,
#          'groundball': 4,
#          'popup': 2,
#          'flyball': 4,
#          'ap': 25,
#          'avg': '.227',
#          'gofo': 0.33,
#          'onbase': {'s': 5,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'tb': 5,
#           'bb': 3,
#           'ibb': 0,
#           'hbp': 0,
#           'fc': 1,
#           'roe': 0,
#           'h': 5,
#           'cycle': 0},
#          'runs': {'total': 1},
#          'outcome': {'klook': 8,
#           'kswing': 19,
#           'ktotal': 27,
#           'ball': 15,
#           'iball': 0,
#           'dirtball': 0,
#           'foul': 1},
#          'outs': {'po': 2,
#           'fo': 3,
#           'fidp': 0,
#           'lo': 1,
#           'lidp': 0,
#           'go': 2,
#           'gidp': 0,
#           'klook': 1,
#           'kswing': 8,
#           'ktotal': 9,
#           'sacfly': 0,
#           'sachit': 0},
#          'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#          'pitches': {'count': 56, 'btotal': 15, 'ktotal': 41},
#          'games': {'start': 8, 'play': 8, 'finish': 0, 'complete': 0}}},
#        'fielding': {'overall': {'po': 11,
#          'a': 11,
#          'dp': 5,
#          'tp': 0,
#          'error': 0,
#          'tc': 22,
#          'fpct': 1.0,
#          'c_wp': 0,
#          'pb': 0,
#          'rf': 3.667,
#          'inn_1': 96,
#          'inn_2': 32.0,
#          'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#          'errors': {'throwing': 0,
#           'fielding': 0,
#           'interference': 0,
#           'total': 0},
#          'assists': {'outfield': 0, 'total': 11},
#          'games': {'start': 6, 'play': 6, 'finish': 0, 'complete': 0}},
#         'positions': [{'po': 11,
#           'a': 11,
#           'dp': 5,
#           'tp': 0,
#           'error': 0,
#           'tc': 22,
#           'fpct': 1.0,
#           'c_wp': 0,
#           'pb': 0,
#           'rf': 3.667,
#           'inn_1': 96,
#           'inn_2': 32.0,
#           'position': '2B',
#           'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#           'errors': {'throwing': 0,
#            'fielding': 0,
#            'interference': 0,
#            'total': 0},
#           'assists': {'outfield': 0, 'total': 11},
#           'games': {'start': 6, 'play': 6, 'finish': 0, 'complete': 0}}]}},
#       'splits': {'hitting': {'overall': [{'total': [{'ab': 22,
#             'runs': 1,
#             's': 5,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 1,
#             'bb': 3,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.32,
#             'slg': 0.227,
#             'ops': 0.547,
#             'h': 5,
#             'ktotal': 9,
#             'avg': '.227'}],
#           'day_night': [{'value': 'day',
#             'ab': 19,
#             'runs': 1,
#             's': 5,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 1,
#             'bb': 2,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.333,
#             'slg': 0.263,
#             'ops': 0.596,
#             'h': 5,
#             'ktotal': 8,
#             'avg': '.263'},
#            {'value': 'night',
#             'ab': 3,
#             'runs': 0,
#             's': 0,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 1,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.25,
#             'slg': 0.0,
#             'ops': 0.25,
#             'h': 0,
#             'ktotal': 1,
#             'avg': '.000'}],
#           'venue': [{'id': '6a22ca0a-2d84-4301-86b8-587e2b01afb0',
#             'name': 'Tempe Diablo Stadium',
#             'surface': 'grass',
#             'ab': 3,
#             'runs': 0,
#             's': 1,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.333,
#             'slg': 0.333,
#             'ops': 0.666,
#             'h': 1,
#             'ktotal': 1,
#             'avg': '.333'},
#            {'id': '164ee38f-1444-4461-adcb-d6ee21e48aa8',
#             'name': 'Salt River Fields at Talking Stick',
#             'surface': 'grass',
#             'ab': 3,
#             'runs': 0,
#             's': 0,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.0,
#             'slg': 0.0,
#             'ops': 0.0,
#             'h': 0,
#             'ktotal': 2,
#             'avg': '.000'},
#            {'id': '228bcacb-77e3-43eb-b149-eb9762d41ff8',
#             'name': 'Peoria Sports Complex',
#             'surface': 'grass',
#             'ab': 7,
#             'runs': 1,
#             's': 2,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 2,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.444,
#             'slg': 0.286,
#             'ops': 0.73,
#             'h': 2,
#             'ktotal': 2,
#             'avg': '.286'},
#            {'id': '1795d517-a828-4078-a759-805cb9e54d67',
#             'name': 'Sloan Park',
#             'surface': 'grass',
#             'ab': 3,
#             'runs': 0,
#             's': 0,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 1,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.25,
#             'slg': 0.0,
#             'ops': 0.25,
#             'h': 0,
#             'ktotal': 1,
#             'avg': '.000'},
#            {'id': '8f0cd62f-3d82-4a90-9710-f67f7402b190',
#             'name': 'Goodyear Ballpark',
#             'surface': 'grass',
#             'ab': 3,
#             'runs': 0,
#             's': 0,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.0,
#             'slg': 0.0,
#             'ops': 0.0,
#             'h': 0,
#             'ktotal': 2,
#             'avg': '.000'},
#            {'id': 'ed6c506c-8bbd-4b7e-8cbc-acbe33148c98',
#             'name': 'Camelback Ranch',
#             'surface': 'grass',
#             'ab': 3,
#             'runs': 0,
#             's': 2,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 1,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.667,
#             'slg': 0.667,
#             'ops': 1.334,
#             'h': 2,
#             'ktotal': 1,
#             'avg': '.667'}],
#           'surface': [{'value': 'grass',
#             'ab': 22,
#             'runs': 1,
#             's': 5,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 1,
#             'bb': 3,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.32,
#             'slg': 0.227,
#             'ops': 0.547,
#             'h': 5,
#             'ktotal': 9,
#             'avg': '.227'}],
#           'month': [{'value': '2',
#             'ab': 6,
#             'runs': 0,
#             's': 1,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.167,
#             'slg': 0.167,
#             'ops': 0.334,
#             'h': 1,
#             'ktotal': 3,
#             'avg': '.167'},
#            {'value': '3',
#             'ab': 16,
#             'runs': 1,
#             's': 4,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 1,
#             'bb': 3,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.368,
#             'slg': 0.25,
#             'ops': 0.618,
#             'h': 4,
#             'ktotal': 6,
#             'avg': '.250'}],
#           'home_away': [{'value': 'home',
#             'ab': 5,
#             'runs': 1,
#             's': 1,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 1,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.333,
#             'slg': 0.2,
#             'ops': 0.533,
#             'h': 1,
#             'ktotal': 1,
#             'avg': '.200'},
#            {'value': 'away',
#             'ab': 17,
#             'runs': 0,
#             's': 4,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 1,
#             'bb': 2,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.316,
#             'slg': 0.235,
#             'ops': 0.551,
#             'h': 4,
#             'ktotal': 8,
#             'avg': '.235'}],
#           'pitcher_hand': [{'value': 'L',
#             'ab': 5,
#             'runs': 0,
#             's': 1,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 1,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.2,
#             'slg': 0.2,
#             'ops': 0.4,
#             'h': 1,
#             'ktotal': 3,
#             'avg': '.200'},
#            {'value': 'R',
#             'ab': 17,
#             'runs': 1,
#             's': 4,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 3,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.35,
#             'slg': 0.235,
#             'ops': 0.585,
#             'h': 4,
#             'ktotal': 6,
#             'avg': '.235'}],
#           'opponent': [{'id': '43a39081-52b4-4f93-ad29-da7f329ea960',
#             'name': 'Mariners',
#             'market': 'Seattle',
#             'abbr': 'SEA',
#             'ab': 2,
#             'runs': 0,
#             's': 1,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 1,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.667,
#             'slg': 0.5,
#             'ops': 1.167,
#             'h': 1,
#             'ktotal': 1,
#             'avg': '.500'},
#            {'id': '25507be1-6a68-4267-bd82-e097d94b359b',
#             'name': 'Diamondbacks',
#             'market': 'Arizona',
#             'abbr': 'ARI',
#             'ab': 3,
#             'runs': 0,
#             's': 0,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.0,
#             'slg': 0.0,
#             'ops': 0.0,
#             'h': 0,
#             'ktotal': 2,
#             'avg': '.000'},
#            {'id': '4f735188-37c8-473d-ae32-1f7e34ccf892',
#             'name': 'Angels',
#             'market': 'Los Angeles',
#             'abbr': 'LAA',
#             'ab': 3,
#             'runs': 0,
#             's': 1,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.333,
#             'slg': 0.333,
#             'ops': 0.666,
#             'h': 1,
#             'ktotal': 1,
#             'avg': '.333'},
#            {'id': 'c874a065-c115-4e7d-b0f0-235584fb0e6f',
#             'name': 'Reds',
#             'market': 'Cincinnati',
#             'abbr': 'CIN',
#             'ab': 3,
#             'runs': 0,
#             's': 0,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.0,
#             'slg': 0.0,
#             'ops': 0.0,
#             'h': 0,
#             'ktotal': 2,
#             'avg': '.000'},
#            {'id': '47f490cd-2f58-4ef7-9dfd-2ad6ba6c1ae8',
#             'name': 'White Sox',
#             'market': 'Chicago',
#             'abbr': 'CWS',
#             'ab': 3,
#             'runs': 0,
#             's': 2,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 1,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.667,
#             'slg': 0.667,
#             'ops': 1.334,
#             'h': 2,
#             'ktotal': 1,
#             'avg': '.667'},
#            {'id': 'dcfd5266-00ce-442c-bc09-264cd20cf455',
#             'name': 'Brewers',
#             'market': 'Milwaukee',
#             'abbr': 'MIL',
#             'ab': 2,
#             'runs': 1,
#             's': 0,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 1,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.333,
#             'slg': 0.0,
#             'ops': 0.333,
#             'h': 0,
#             'ktotal': 0,
#             'avg': '.000'},
#            {'id': '55714da8-fcaf-4574-8443-59bfb511a524',
#             'name': 'Cubs',
#             'market': 'Chicago',
#             'abbr': 'CHC',
#             'ab': 3,
#             'runs': 0,
#             's': 0,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 1,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.25,
#             'slg': 0.0,
#             'ops': 0.25,
#             'h': 0,
#             'ktotal': 1,
#             'avg': '.000'},
#            {'id': 'ef64da7f-cfaf-4300-87b0-9313386b977c',
#             'name': 'Dodgers',
#             'market': 'Los Angeles',
#             'abbr': 'LAD',
#             'ab': 3,
#             'runs': 0,
#             's': 1,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.333,
#             'slg': 0.333,
#             'ops': 0.666,
#             'h': 1,
#             'ktotal': 1,
#             'avg': '.333'}]}]}}}]},
#    {'id': 'd790e0e3-a022-4da3-9507-e127cae8dea2',
#     'year': 2020,
#     'type': 'REG',
#     'totals': {'statistics': {'hitting': {'overall': {'ab': 15,
#         'lob': 5,
#         'rbi': 0,
#         'abhr': 0,
#         'abk': 3.0,
#         'bip': 10,
#         'babip': 0.2,
#         'bbk': 0.2,
#         'bbpa': 0.063,
#         'iso': 0.0,
#         'obp': 0.188,
#         'ops': 0.321,
#         'seca': 0.067,
#         'slg': 0.133,
#         'xbh': 0,
#         'pitch_count': 50,
#         'lob_risp_2out': 1,
#         'team_lob': 2,
#         'ab_risp': 3,
#         'hit_risp': 0,
#         'rbi_2out': 0,
#         'linedrive': 3,
#         'groundball': 2,
#         'popup': 2,
#         'flyball': 3,
#         'ap': 16,
#         'avg': '.133',
#         'gofo': 0.5,
#         'onbase': {'s': 2,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'tb': 2,
#          'bb': 1,
#          'ibb': 0,
#          'hbp': 0,
#          'fc': 1,
#          'roe': 0,
#          'h': 2,
#          'cycle': 0},
#         'runs': {'total': 1},
#         'outcome': {'klook': 12,
#          'kswing': 2,
#          'ktotal': 14,
#          'ball': 18,
#          'iball': 0,
#          'dirtball': 1,
#          'foul': 7},
#         'outs': {'po': 2,
#          'fo': 3,
#          'fidp': 0,
#          'lo': 1,
#          'lidp': 0,
#          'go': 3,
#          'gidp': 1,
#          'klook': 3,
#          'kswing': 2,
#          'ktotal': 5,
#          'sacfly': 0,
#          'sachit': 0},
#         'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#         'pitches': {'count': 50, 'btotal': 19, 'ktotal': 31},
#         'games': {'start': 4, 'play': 7, 'finish': 3, 'complete': 2}}},
#       'fielding': {'overall': {'po': 9,
#         'a': 7,
#         'dp': 3,
#         'tp': 0,
#         'error': 1,
#         'tc': 17,
#         'fpct': 0.941,
#         'c_wp': 0,
#         'pb': 0,
#         'rf': 3.2,
#         'inn_1': 85,
#         'inn_2': 28.1,
#         'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#         'errors': {'throwing': 0,
#          'fielding': 1,
#          'interference': 0,
#          'total': 1},
#         'assists': {'outfield': 0, 'total': 7},
#         'games': {'start': 3, 'play': 5, 'finish': 2, 'complete': 0}},
#        'positions': [{'po': 9,
#          'a': 7,
#          'dp': 3,
#          'tp': 0,
#          'error': 1,
#          'tc': 17,
#          'fpct': 0.941,
#          'c_wp': 0,
#          'pb': 0,
#          'rf': 3.2,
#          'inn_1': 85,
#          'inn_2': 28.1,
#          'position': '2B',
#          'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#          'errors': {'throwing': 0,
#           'fielding': 1,
#           'interference': 0,
#           'total': 1},
#          'assists': {'outfield': 0, 'total': 7},
#          'games': {'start': 3, 'play': 5, 'finish': 2, 'complete': 0}}]}},
#      'splits': {'hitting': {'overall': [{'total': [{'ab': 15,
#            'runs': 1,
#            's': 2,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.188,
#            'slg': 0.133,
#            'ops': 0.321,
#            'h': 2,
#            'ktotal': 5,
#            'avg': '.133'}],
#          'day_night': [{'value': 'night',
#            'ab': 15,
#            'runs': 1,
#            's': 2,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.188,
#            'slg': 0.133,
#            'ops': 0.321,
#            'h': 2,
#            'ktotal': 5,
#            'avg': '.133'}],
#          'venue': [{'id': '3ca8b577-5844-42ed-81a5-bd5d5cbe350c',
#            'name': 'Truist Park',
#            'market': 'Atlanta',
#            'surface': 'grass',
#            'ab': 2,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.0,
#            'slg': 0.0,
#            'ops': 0.0,
#            'h': 0,
#            'ktotal': 1,
#            'avg': '.000'},
#           {'id': '265c7d6c-427a-4b8a-8def-392c41954bec',
#            'name': 'Citi Field',
#            'market': 'New York',
#            'surface': 'grass',
#            'ab': 9,
#            'runs': 1,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.2,
#            'slg': 0.111,
#            'ops': 0.311,
#            'h': 1,
#            'ktotal': 3,
#            'avg': '.111'},
#           {'id': 'bb062fb1-e268-412e-b3d2-2ddb6acc1822',
#            'name': 'Nationals Park',
#            'market': 'Washington',
#            'surface': 'grass',
#            'ab': 4,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.25,
#            'ops': 0.5,
#            'h': 1,
#            'ktotal': 1,
#            'avg': '.250'},
#           {'id': 'b4186004-b6d0-42e7-8dc1-82ef0d946ecc',
#            'name': 'Citizens Bank Park',
#            'market': 'Philadelphia',
#            'surface': 'grass',
#            'ab': 0,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0,
#            'slg': 0,
#            'ops': 0.0,
#            'h': 0,
#            'ktotal': 0,
#            'avg': '.000'}],
#          'surface': [{'value': 'grass',
#            'ab': 15,
#            'runs': 1,
#            's': 2,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.188,
#            'slg': 0.133,
#            'ops': 0.321,
#            'h': 2,
#            'ktotal': 5,
#            'avg': '.133'}],
#          'month': [{'value': '8',
#            'ab': 13,
#            'runs': 1,
#            's': 2,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.214,
#            'slg': 0.154,
#            'ops': 0.368,
#            'h': 2,
#            'ktotal': 4,
#            'avg': '.154'},
#           {'value': '7',
#            'ab': 2,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.0,
#            'slg': 0.0,
#            'ops': 0.0,
#            'h': 0,
#            'ktotal': 1,
#            'avg': '.000'}],
#          'home_away': [{'value': 'away',
#            'ab': 6,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.167,
#            'slg': 0.167,
#            'ops': 0.334,
#            'h': 1,
#            'ktotal': 2,
#            'avg': '.167'},
#           {'value': 'home',
#            'ab': 9,
#            'runs': 1,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.2,
#            'slg': 0.111,
#            'ops': 0.311,
#            'h': 1,
#            'ktotal': 3,
#            'avg': '.111'}],
#          'pitcher_hand': [{'value': 'R',
#            'ab': 2,
#            'runs': 1,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.5,
#            'slg': 0.5,
#            'ops': 1.0,
#            'h': 1,
#            'ktotal': 1,
#            'avg': '.500'},
#           {'value': 'L',
#            'ab': 13,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.143,
#            'slg': 0.077,
#            'ops': 0.22,
#            'h': 1,
#            'ktotal': 4,
#            'avg': '.077'}],
#          'opponent': [{'id': 'd89bed32-3aee-4407-99e3-4103641b999a',
#            'name': 'Nationals',
#            'market': 'Washington',
#            'abbr': 'WSH',
#            'ab': 8,
#            'runs': 0,
#            's': 2,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.25,
#            'ops': 0.5,
#            'h': 2,
#            'ktotal': 2,
#            'avg': '.250'},
#           {'id': '12079497-e414-450a-8bf2-29f91de646bf',
#            'name': 'Braves',
#            'market': 'Atlanta',
#            'abbr': 'ATL',
#            'ab': 2,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.0,
#            'slg': 0.0,
#            'ops': 0.0,
#            'h': 0,
#            'ktotal': 1,
#            'avg': '.000'},
#           {'id': '2142e1ba-3b40-445c-b8bb-f1f8b1054220',
#            'name': 'Phillies',
#            'market': 'Philadelphia',
#            'abbr': 'PHI',
#            'ab': 0,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0,
#            'slg': 0,
#            'ops': 0.0,
#            'h': 0,
#            'ktotal': 0,
#            'avg': '.000'},
#           {'id': '93941372-eb4c-4c40-aced-fe3267174393',
#            'name': 'Red Sox',
#            'market': 'Boston',
#            'abbr': 'BOS',
#            'ab': 2,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.0,
#            'slg': 0.0,
#            'ops': 0.0,
#            'h': 0,
#            'ktotal': 1,
#            'avg': '.000'},
#           {'id': '03556285-bdbb-4576-a06d-42f71f46ddc5',
#            'name': 'Marlins',
#            'market': 'Miami',
#            'abbr': 'MIA',
#            'ab': 3,
#            'runs': 1,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.0,
#            'ops': 0.25,
#            'h': 0,
#            'ktotal': 1,
#            'avg': '.000'}]}]}},
#      'statcast_metrics': {'hitting': {'overall': [{'max_height': {'min': 5.0,
#           'avg': 77.0,
#           'max': 170.0,
#           'count': 10}},
#         {'travel_distance': {'min': 88.0,
#           'avg': 217.0,
#           'max': 362.0,
#           'count': 10}},
#         {'launch_speed': {'min': 70.0, 'avg': 88.0, 'max': 99.2, 'count': 10}},
#         {'distance': {'min': 92.0, 'avg': 218.0, 'max': 368.0, 'count': 10}},
#         {'launch_spin_rate': {'min': 0.0,
#           'avg': 0.0,
#           'max': 0.0,
#           'count': 10}},
#         {'travel_time': {'min': 0.9, 'avg': 3.9, 'max': 6.6, 'count': 10}},
#         {'launch_angle': {'min': 8.0, 'avg': 33.0, 'max': 72.0, 'count': 10}},
#         {'hang_time': {'min': 0.9, 'avg': 4.0, 'max': 6.7, 'count': 10}}]}}},
#     'teams': [{'name': 'Mets',
#       'market': 'New York',
#       'abbr': 'NYM',
#       'id': 'f246a5e5-afdb-479c-9aaa-c68beeda7af6',
#       'statistics': {'hitting': {'overall': {'ab': 15,
#          'lob': 5,
#          'rbi': 0,
#          'abhr': 0,
#          'abk': 3.0,
#          'bip': 10,
#          'babip': 0.2,
#          'bbk': 0.2,
#          'bbpa': 0.063,
#          'iso': 0.0,
#          'obp': 0.188,
#          'ops': 0.321,
#          'seca': 0.067,
#          'slg': 0.133,
#          'xbh': 0,
#          'pitch_count': 50,
#          'lob_risp_2out': 1,
#          'team_lob': 2,
#          'ab_risp': 3,
#          'hit_risp': 0,
#          'rbi_2out': 0,
#          'linedrive': 3,
#          'groundball': 2,
#          'popup': 2,
#          'flyball': 3,
#          'ap': 16,
#          'avg': '.133',
#          'gofo': 0.5,
#          'onbase': {'s': 2,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'tb': 2,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'fc': 1,
#           'roe': 0,
#           'h': 2,
#           'cycle': 0},
#          'runs': {'total': 1},
#          'outcome': {'klook': 12,
#           'kswing': 2,
#           'ktotal': 14,
#           'ball': 18,
#           'iball': 0,
#           'dirtball': 1,
#           'foul': 7},
#          'outs': {'po': 2,
#           'fo': 3,
#           'fidp': 0,
#           'lo': 1,
#           'lidp': 0,
#           'go': 3,
#           'gidp': 1,
#           'klook': 3,
#           'kswing': 2,
#           'ktotal': 5,
#           'sacfly': 0,
#           'sachit': 0},
#          'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#          'pitches': {'count': 50, 'btotal': 19, 'ktotal': 31},
#          'games': {'start': 4, 'play': 7, 'finish': 3, 'complete': 2}}},
#        'fielding': {'overall': {'po': 9,
#          'a': 7,
#          'dp': 3,
#          'tp': 0,
#          'error': 1,
#          'tc': 17,
#          'fpct': 0.941,
#          'c_wp': 0,
#          'pb': 0,
#          'rf': 3.2,
#          'inn_1': 85,
#          'inn_2': 28.1,
#          'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#          'errors': {'throwing': 0,
#           'fielding': 1,
#           'interference': 0,
#           'total': 1},
#          'assists': {'outfield': 0, 'total': 7},
#          'games': {'start': 3, 'play': 5, 'finish': 2, 'complete': 0}},
#         'positions': [{'po': 9,
#           'a': 7,
#           'dp': 3,
#           'tp': 0,
#           'error': 1,
#           'tc': 17,
#           'fpct': 0.941,
#           'c_wp': 0,
#           'pb': 0,
#           'rf': 3.2,
#           'inn_1': 85,
#           'inn_2': 28.1,
#           'position': '2B',
#           'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#           'errors': {'throwing': 0,
#            'fielding': 1,
#            'interference': 0,
#            'total': 1},
#           'assists': {'outfield': 0, 'total': 7},
#           'games': {'start': 3, 'play': 5, 'finish': 2, 'complete': 0}}]}},
#       'splits': {'hitting': {'overall': [{'total': [{'ab': 15,
#             'runs': 1,
#             's': 2,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 1,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.188,
#             'slg': 0.133,
#             'ops': 0.321,
#             'h': 2,
#             'ktotal': 5,
#             'avg': '.133'}],
#           'day_night': [{'value': 'night',
#             'ab': 15,
#             'runs': 1,
#             's': 2,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 1,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.188,
#             'slg': 0.133,
#             'ops': 0.321,
#             'h': 2,
#             'ktotal': 5,
#             'avg': '.133'}],
#           'venue': [{'id': '3ca8b577-5844-42ed-81a5-bd5d5cbe350c',
#             'name': 'Truist Park',
#             'market': 'Atlanta',
#             'surface': 'grass',
#             'ab': 2,
#             'runs': 0,
#             's': 0,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.0,
#             'slg': 0.0,
#             'ops': 0.0,
#             'h': 0,
#             'ktotal': 1,
#             'avg': '.000'},
#            {'id': '265c7d6c-427a-4b8a-8def-392c41954bec',
#             'name': 'Citi Field',
#             'market': 'New York',
#             'surface': 'grass',
#             'ab': 9,
#             'runs': 1,
#             's': 1,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 1,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.2,
#             'slg': 0.111,
#             'ops': 0.311,
#             'h': 1,
#             'ktotal': 3,
#             'avg': '.111'},
#            {'id': 'bb062fb1-e268-412e-b3d2-2ddb6acc1822',
#             'name': 'Nationals Park',
#             'market': 'Washington',
#             'surface': 'grass',
#             'ab': 4,
#             'runs': 0,
#             's': 1,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.25,
#             'slg': 0.25,
#             'ops': 0.5,
#             'h': 1,
#             'ktotal': 1,
#             'avg': '.250'},
#            {'id': 'b4186004-b6d0-42e7-8dc1-82ef0d946ecc',
#             'name': 'Citizens Bank Park',
#             'market': 'Philadelphia',
#             'surface': 'grass',
#             'ab': 0,
#             'runs': 0,
#             's': 0,
#             'd': 0,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
# ...
#             's': 1,
#             'd': 2,
#             't': 1,
#             'hr': 1,
#             'rbi': 1,
#             'bb': 2,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.28,
#             'slg': 0.522,
#             'ops': 0.802,
#             'h': 5,
#             'ktotal': 5,
#             'avg': '.217'},
#            {'id': '93941372-eb4c-4c40-aced-fe3267174393',
#             'name': 'Red Sox',
#             'market': 'Boston',
#             'abbr': 'BOS',
#             'ab': 27,
#             'runs': 6,
#             's': 3,
#             'd': 3,
#             't': 0,
#             'hr': 1,
#             'rbi': 1,
#             'bb': 3,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.333,
#             'slg': 0.481,
#             'ops': 0.814,
#             'h': 7,
#             'ktotal': 9,
#             'avg': '.259'},
#            {'id': '47f490cd-2f58-4ef7-9dfd-2ad6ba6c1ae8',
#             'name': 'White Sox',
#             'market': 'Chicago',
#             'abbr': 'CWS',
#             'ab': 83,
#             'runs': 11,
#             's': 13,
#             'd': 4,
#             't': 1,
#             'hr': 5,
#             'rbi': 17,
#             'bb': 4,
#             'ibb': 1,
#             'hbp': 0,
#             'sb': 2,
#             'cs': 0,
#             'obp': 0.318,
#             'slg': 0.53,
#             'ops': 0.848,
#             'h': 23,
#             'ktotal': 18,
#             'avg': '.277'},
#            {'id': 'a09ec676-f887-43dc-bbb3-cf4bbaee9a18',
#             'name': 'Yankees',
#             'market': 'New York',
#             'abbr': 'NYY',
#             'ab': 23,
#             'runs': 4,
#             's': 6,
#             'd': 0,
#             't': 0,
#             'hr': 1,
#             'rbi': 2,
#             'bb': 4,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 1,
#             'cs': 1,
#             'obp': 0.407,
#             'slg': 0.435,
#             'ops': 0.842,
#             'h': 7,
#             'ktotal': 7,
#             'avg': '.304'},
#            {'id': 'd99f919b-1534-4516-8e8a-9cd106c6d8cd',
#             'name': 'Rangers',
#             'market': 'Texas',
#             'abbr': 'TEX',
#             'ab': 24,
#             'runs': 6,
#             's': 0,
#             'd': 4,
#             't': 0,
#             'hr': 2,
#             'rbi': 4,
#             'bb': 4,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.357,
#             'slg': 0.667,
#             'ops': 1.024,
#             'h': 6,
#             'ktotal': 4,
#             'avg': '.250'},
#            {'id': '27a59d3b-ff7c-48ea-b016-4798f560f5e1',
#             'name': 'Athletics',
#             'market': 'Oakland',
#             'abbr': 'OAK',
#             'ab': 25,
#             'runs': 6,
#             's': 3,
#             'd': 3,
#             't': 0,
#             'hr': 1,
#             'rbi': 4,
#             'bb': 3,
#             'ibb': 0,
#             'hbp': 1,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.379,
#             'slg': 0.52,
#             'ops': 0.899,
#             'h': 7,
#             'ktotal': 6,
#             'avg': '.280'},
#            {'id': 'c874a065-c115-4e7d-b0f0-235584fb0e6f',
#             'name': 'Reds',
#             'market': 'Cincinnati',
#             'abbr': 'CIN',
#             'ab': 14,
#             'runs': 4,
#             's': 1,
#             'd': 2,
#             't': 0,
#             'hr': 1,
#             'rbi': 3,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.286,
#             'slg': 0.643,
#             'ops': 0.929,
#             'h': 4,
#             'ktotal': 6,
#             'avg': '.286'},
#            {'id': '43a39081-52b4-4f93-ad29-da7f329ea960',
#             'name': 'Mariners',
#             'market': 'Seattle',
#             'abbr': 'SEA',
#             'ab': 29,
#             'runs': 5,
#             's': 2,
#             'd': 1,
#             't': 0,
#             'hr': 2,
#             'rbi': 3,
#             'bb': 4,
#             'ibb': 1,
#             'hbp': 0,
#             'sb': 1,
#             'cs': 0,
#             'obp': 0.294,
#             'slg': 0.414,
#             'ops': 0.708,
#             'h': 5,
#             'ktotal': 10,
#             'avg': '.172'},
#            {'id': '833a51a9-0d84-410f-bd77-da08c3e5e26e',
#             'name': 'Royals',
#             'market': 'Kansas City',
#             'abbr': 'KC',
#             'ab': 67,
#             'runs': 8,
#             's': 8,
#             'd': 4,
#             't': 0,
#             'hr': 0,
#             'rbi': 4,
#             'bb': 8,
#             'ibb': 0,
#             'hbp': 2,
#             'sb': 2,
#             'cs': 1,
#             'obp': 0.282,
#             'slg': 0.239,
#             'ops': 0.521,
#             'h': 12,
#             'ktotal': 12,
#             'avg': '.179'},
#            {'id': '55714da8-fcaf-4574-8443-59bfb511a524',
#             'name': 'Cubs',
#             'market': 'Chicago',
#             'abbr': 'CHC',
#             'ab': 13,
#             'runs': 2,
#             's': 2,
#             'd': 1,
#             't': 0,
#             'hr': 0,
#             'rbi': 0,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 1,
#             'cs': 0,
#             'obp': 0.231,
#             'slg': 0.308,
#             'ops': 0.539,
#             'h': 3,
#             'ktotal': 1,
#             'avg': '.231'},
#            {'id': '575c19b7-4052-41c2-9f0a-1c5813d02f99',
#             'name': 'Tigers',
#             'market': 'Detroit',
#             'abbr': 'DET',
#             'ab': 73,
#             'runs': 10,
#             's': 11,
#             'd': 3,
#             't': 1,
#             'hr': 1,
#             'rbi': 9,
#             'bb': 5,
#             'ibb': 0,
#             'hbp': 2,
#             'sb': 1,
#             'cs': 0,
#             'obp': 0.277,
#             'slg': 0.329,
#             'ops': 0.606,
#             'h': 16,
#             'ktotal': 12,
#             'avg': '.219'},
#            {'id': '80715d0d-0d2a-450f-a970-1b9a3b18c7e7',
#             'name': 'Indians',
#             'market': 'Cleveland',
#             'abbr': 'CLE',
#             'ab': 70,
#             'runs': 10,
#             's': 6,
#             'd': 4,
#             't': 0,
#             'hr': 5,
#             'rbi': 8,
#             'bb': 7,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.282,
#             'slg': 0.486,
#             'ops': 0.768,
#             'h': 15,
#             'ktotal': 17,
#             'avg': '.214'},
#            {'id': '481dfe7e-5dab-46ab-a49f-9dcc2b6e2cfd',
#             'name': 'Pirates',
#             'market': 'Pittsburgh',
#             'abbr': 'PIT',
#             'ab': 18,
#             'runs': 3,
#             's': 0,
#             'd': 1,
#             't': 0,
#             'hr': 1,
#             'rbi': 1,
#             'bb': 3,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.238,
#             'slg': 0.333,
#             'ops': 0.571,
#             'h': 2,
#             'ktotal': 6,
#             'avg': '.111'},
#            {'id': '44671792-dc02-4fdd-a5ad-f5f17edaa9d7',
#             'name': 'Cardinals',
#             'market': 'St. Louis',
#             'abbr': 'STL',
#             'ab': 12,
#             'runs': 1,
#             's': 1,
#             'd': 1,
#             't': 0,
#             'hr': 0,
#             'rbi': 1,
#             'bb': 2,
#             'ibb': 0,
#             'hbp': 1,
#             'sb': 1,
#             'cs': 0,
#             'obp': 0.313,
#             'slg': 0.25,
#             'ops': 0.563,
#             'h': 2,
#             'ktotal': 2,
#             'avg': '.167'},
#            {'id': '1d678440-b4b1-4954-9b39-70afb3ebbcfa',
#             'name': 'Blue Jays',
#             'market': 'Toronto',
#             'abbr': 'TOR',
#             'ab': 29,
#             'runs': 5,
#             's': 3,
#             'd': 3,
#             't': 1,
#             'hr': 0,
#             'rbi': 1,
#             'bb': 0,
#             'ibb': 0,
#             'hbp': 0,
#             'sb': 0,
#             'cs': 0,
#             'obp': 0.241,
#             'slg': 0.414,
#             'ops': 0.655,
#             'h': 7,
#             'ktotal': 10,
#             'avg': '.241'},
#            {'id': 'bdc11650-6f74-49c4-875e-778aeb7632d9',
#             'name': 'Rays',
#             'market': 'Tampa Bay',
#             'abbr': 'TB',
#             'ab': 21,
#             'runs': 6,
#             's': 3,
#             'd': 0,
#             't': 0,
#             'hr': 3,
#             'rbi': 6,
#             'bb': 4,
#             'ibb': 0,
#             'hbp': 1,
#             'sb': 0,
#             'cs': 1,
#             'obp': 0.407,
#             'slg': 0.714,
#             'ops': 1.121,
#             'h': 6,
#             'ktotal': 2,
#             'avg': '.286'}]}]}}}]},
#    {'id': '8f4e3a30-8444-11e3-808c-22000a904a71',
#     'year': 2014,
#     'type': 'REG',
#     'totals': {'statistics': {'hitting': {'overall': {'ab': 598,
#         'lob': 234,
#         'rbi': 71,
#         'abhr': 26.0,
#         'abk': 4.636,
#         'bip': 454,
#         'babip': 0.269,
#         'bbk': 0.69,
#         'bbpa': 0.126,
#         'iso': 0.174,
#         'obp': 0.345,
#         'ops': 0.761,
#         'seca': 0.346,
#         'slg': 0.416,
#         'xbh': 57,
#         'pitch_count': 2956,
#         'ap': 707,
#         'avg': '.242',
#         'gofo': 0.72,
#         'onbase': {'s': 88,
#          'd': 33,
#          't': 1,
#          'hr': 23,
#          'tb': 249,
#          'bb': 88,
#          'ibb': 1,
#          'hbp': 9,
#          'fc': 14,
#          'roe': 6,
#          'h': 145,
#          'cycle': 0},
#         'runs': {'total': 112},
#         'outcome': {'klook': 643,
#          'kswing': 105,
#          'ktotal': 748,
#          'ball': 961,
#          'iball': 0,
#          'dirtball': 71,
#          'foul': 0},
#         'outs': {'po': 55,
#          'fo': 105,
#          'fidp': 1,
#          'lo': 31,
#          'lidp': 0,
#          'go': 144,
#          'gidp': 8,
#          'klook': 28,
#          'kswing': 101,
#          'ktotal': 129,
#          'sacfly': 8,
#          'sachit': 3},
#         'steal': {'caught': 7, 'stolen': 21, 'pct': 0.75, 'pickoff': 3},
#         'games': {'start': 155, 'play': 156, 'finish': 1, 'complete': 150}}},
#       'fielding': {'overall': {'po': 261,
#         'a': 475,
#         'dp': 98,
#         'tp': 0,
#         'error': 15,
#         'tc': 751,
#         'fpct': 0.98,
#         'rf': 4.718,
#         'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#         'errors': {'throwing': 0,
#          'fielding': 0,
#          'interference': 0,
#          'total': 15},
#         'games': {'start': 155, 'play': 156, 'finish': 1, 'complete': 0}}}}},
#     'teams': [{'name': 'Twins',
#       'market': 'Minnesota',
#       'abbr': 'MIN',
#       'id': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d',
#       'statistics': {'hitting': {'overall': {'ab': 598,
#          'lob': 234,
#          'rbi': 71,
#          'abhr': 26.0,
#          'abk': 4.636,
#          'bip': 454,
#          'babip': 0.269,
#          'bbk': 0.69,
#          'bbpa': 0.126,
#          'iso': 0.174,
#          'obp': 0.345,
#          'ops': 0.761,
#          'seca': 0.346,
#          'slg': 0.416,
#          'xbh': 57,
#          'pitch_count': 2956,
#          'ap': 707,
#          'avg': '.242',
#          'gofo': 0.72,
#          'onbase': {'s': 88,
#           'd': 33,
#           't': 1,
#           'hr': 23,
#           'tb': 249,
#           'bb': 88,
#           'ibb': 1,
#           'hbp': 9,
#           'fc': 14,
#           'roe': 6,
#           'h': 145,
#           'cycle': 0},
#          'runs': {'total': 112},
#          'outcome': {'klook': 643,
#           'kswing': 105,
#           'ktotal': 748,
#           'ball': 961,
#           'iball': 0,
#           'dirtball': 71,
#           'foul': 0},
#          'outs': {'po': 55,
#           'fo': 105,
#           'fidp': 1,
#           'lo': 31,
#           'lidp': 0,
#           'go': 144,
#           'gidp': 8,
#           'klook': 28,
#           'kswing': 101,
#           'ktotal': 129,
#           'sacfly': 8,
#           'sachit': 3},
#          'steal': {'caught': 7, 'stolen': 21, 'pct': 0.75, 'pickoff': 3},
#          'games': {'start': 155, 'play': 156, 'finish': 1, 'complete': 150}}},
#        'fielding': {'overall': {'po': 261,
#          'a': 475,
#          'dp': 98,
#          'tp': 0,
#          'error': 15,
#          'tc': 751,
#          'fpct': 0.98,
#          'rf': 4.718,
#          'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#          'errors': {'throwing': 0,
#           'fielding': 0,
#           'interference': 0,
#           'total': 15},
#          'games': {'start': 155,
#           'play': 156,
#           'finish': 1,
#           'complete': 0}}}}}]},
#    {'id': '58dd9a81-4a38-4a66-8cd7-32ae4d567ba8',
#     'year': 2013,
#     'type': 'REG',
#     'totals': {'statistics': {'hitting': {'overall': {'ab': 540,
#         'lob': 182,
#         'rbi': 58,
#         'abhr': 33.75,
#         'abk': 4.576,
#         'bip': 410,
#         'babip': 0.273,
#         'bbk': 0.415,
#         'bbpa': 0.082,
#         'iso': 0.157,
#         'obp': 0.304,
#         'ops': 0.698,
#         'seca': 0.261,
#         'slg': 0.394,
#         'xbh': 49,
#         'pitch_count': 2511,
#         'ap': 601,
#         'avg': '.237',
#         'gofo': 0.66,
#         'onbase': {'s': 79,
#          'd': 29,
#          't': 4,
#          'hr': 16,
#          'tb': 213,
#          'bb': 49,
#          'ibb': 0,
#          'hbp': 5,
#          'fc': 8,
#          'roe': 6,
#          'h': 128,
#          'cycle': 0},
#         'runs': {'total': 69},
#         'outcome': {'klook': 556,
#          'kswing': 87,
#          'ktotal': 643,
#          'ball': 807,
#          'iball': 0,
#          'dirtball': 45,
#          'foul': 0},
#         'outs': {'po': 46,
#          'fo': 106,
#          'fidp': 0,
#          'lo': 24,
#          'lidp': 0,
#          'go': 118,
#          'gidp': 13,
#          'klook': 32,
#          'kswing': 86,
#          'ktotal': 118,
#          'sacfly': 4,
#          'sachit': 3},
#         'steal': {'caught': 7, 'stolen': 14, 'pct': 0.667, 'pickoff': 0},
#         'games': {'start': 136,
#          'play': 142,
#          'finish': 136,
#          'complete': 130}}}}},
#     'teams': [{'name': 'Twins',
#       'market': 'Minnesota',
#       'abbr': 'MIN',
#       'id': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d',
#       'statistics': {'hitting': {'overall': {'ab': 540,
#          'lob': 182,
#          'rbi': 58,
#          'abhr': 33.75,
#          'abk': 4.576,
#          'bip': 410,
#          'babip': 0.273,
#          'bbk': 0.415,
#          'bbpa': 0.082,
#          'iso': 0.157,
#          'obp': 0.304,
#          'ops': 0.698,
#          'seca': 0.261,
#          'slg': 0.394,
#          'xbh': 49,
#          'pitch_count': 2511,
#          'ap': 601,
#          'avg': '.237',
#          'gofo': 0.66,
#          'onbase': {'s': 79,
#           'd': 29,
#           't': 4,
#           'hr': 16,
#           'tb': 213,
#           'bb': 49,
#           'ibb': 0,
#           'hbp': 5,
#           'fc': 8,
#           'roe': 6,
#           'h': 128,
#           'cycle': 0},
#          'runs': {'total': 69},
#          'outcome': {'klook': 556,
#           'kswing': 87,
#           'ktotal': 643,
#           'ball': 807,
#           'iball': 0,
#           'dirtball': 45,
#           'foul': 0},
#          'outs': {'po': 46,
#           'fo': 106,
#           'fidp': 0,
#           'lo': 24,
#           'lidp': 0,
#           'go': 118,
#           'gidp': 13,
#           'klook': 32,
#           'kswing': 86,
#           'ktotal': 118,
#           'sacfly': 4,
#           'sachit': 3},
#          'steal': {'caught': 7, 'stolen': 14, 'pct': 0.667, 'pickoff': 0},
#          'games': {'start': 136,
#           'play': 142,
#           'finish': 136,
#           'complete': 130}}},
#        'fielding': {'overall': {'po': 0,
#          'a': 0,
#          'dp': 0,
#          'tp': 0,
#          'error': 0,
#          'tc': 0,
#          'fpct': 0.0,
#          'rf': 0.0,
#          'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#          'errors': {'throwing': 0,
#           'fielding': 0,
#           'interference': 0,
#           'total': 0},
#          'games': {'start': 5, 'play': 5, 'finish': 0, 'complete': 0}}}}}]}]},
#  '_comment': 'Generation started @ 2021-01-17 17:17:53 UTC ended @ 2021-01-17 17:17:53 UTC'}

# %%
geez= response1['player']['seasons']
geez
# Out:
# [{'id': '7f533168-b22c-4d8f-9593-0dacb2f0e84a',
#   'year': 2019,
#   'type': 'REG',
#   'totals': {'statistics': {'hitting': {'overall': {'ab': 89,
#       'lob': 53,
#       'rbi': 9,
#       'abhr': 89.0,
#       'abk': 2.871,
#       'bip': 58,
#       'babip': 0.259,
#       'bbk': 0.226,
#       'bbpa': 0.071,
#       'iso': 0.078,
#       'obp': 0.245,
#       'ops': 0.503,
#       'seca': 0.157,
#       'slg': 0.258,
#       'xbh': 5,
#       'pitch_count': 441,
#       'lob_risp_2out': 10,
#       'team_lob': 25,
#       'ab_risp': 23,
#       'hit_risp': 3,
#       'rbi_2out': 2,
#       'linedrive': 16,
#       'groundball': 25,
#       'popup': 5,
#       'flyball': 13,
#       'ap': 99,
#       'avg': '.180',
#       'gofo': 1.09,
#       'onbase': {'s': 11,
#        'd': 4,
#        't': 0,
#        'hr': 1,
#        'tb': 23,
#        'bb': 7,
#        'ibb': 0,
#        'hbp': 1,
#        'fc': 2,
#        'roe': 2,
#        'h': 16,
#        'cycle': 0},
#       'runs': {'total': 9},
#       'outcome': {'klook': 73,
#        'kswing': 66,
#        'ktotal': 139,
#        'ball': 136,
#        'iball': 0,
#        'dirtball': 20,
#        'foul': 85},
#       'outs': {'po': 4,
#        'fo': 11,
#        'fidp': 0,
#        'lo': 8,
#        'lidp': 0,
#        'go': 25,
#        'gidp': 5,
#        'klook': 7,
#        'kswing': 24,
#        'ktotal': 31,
#        'sacfly': 1,
#        'sachit': 0},
#       'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#       'pitches': {'count': 441, 'btotal': 158, 'ktotal': 283},
#       'games': {'start': 23, 'play': 29, 'finish': 6, 'complete': 17}}},
#     'fielding': {'overall': {'po': 100,
#       'a': 10,
#       'dp': 10,
#       'tp': 0,
#       'error': 3,
#       'tc': 113,
#       'fpct': 0.973,
#       'c_wp': 0,
#       'pb': 0,
#       'rf': 4.783,
#       'inn_1': 495,
#       'inn_2': 165.0,
#       'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#       'errors': {'throwing': 1, 'fielding': 2, 'interference': 0, 'total': 3},
#       'assists': {'outfield': 1, 'total': 10},
#       'games': {'start': 18, 'play': 23, 'finish': 5, 'complete': 0}},
#      'positions': [{'po': 97,
#        'a': 9,
#        'dp': 9,
#        'tp': 0,
#        'error': 3,
#        'tc': 109,
#        'fpct': 0.972,
#        'c_wp': 0,
#        'pb': 0,
#        'rf': 5.579,
#        'inn_1': 390,
#        'inn_2': 130.0,
#        'position': '1B',
#        'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#        'errors': {'throwing': 1, 'fielding': 2, 'interference': 0, 'total': 3},
#        'assists': {'outfield': 0, 'total': 9},
#        'games': {'start': 15, 'play': 19, 'finish': 4, 'complete': 0}},
#       {'po': 3,
#        'a': 1,
#        'dp': 1,
#        'tp': 0,
#        'error': 0,
#        'tc': 4,
#        'fpct': 1.0,
#        'c_wp': 0,
#        'pb': 0,
#        'rf': 1.0,
#        'inn_1': 105,
#        'inn_2': 35.0,
#        'position': 'LF',
#        'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#        'errors': {'throwing': 0, 'fielding': 0, 'interference': 0, 'total': 0},
#        'assists': {'outfield': 1, 'total': 1},
#        'games': {'start': 3, 'play': 4, 'finish': 1, 'complete': 0}}]}},
#    'splits': {'hitting': {'overall': [{'total': [{'ab': 89,
#          'runs': 9,
#          's': 11,
#          'd': 4,
#          't': 0,
#          'hr': 1,
#          'rbi': 9,
#          'bb': 7,
#          'ibb': 0,
#          'hbp': 1,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.245,
#          'slg': 0.258,
#          'ops': 0.503,
#          'h': 16,
#          'ktotal': 31,
#          'avg': '.180'}],
#        'day_night': [{'value': 'day',
#          'ab': 48,
#          'runs': 5,
#          's': 6,
#          'd': 1,
#          't': 0,
#          'hr': 1,
#          'rbi': 5,
#          'bb': 3,
#          'ibb': 0,
#          'hbp': 1,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.226,
#          'slg': 0.25,
#          'ops': 0.476,
#          'h': 8,
#          'ktotal': 17,
#          'avg': '.167'},
#         {'value': 'night',
#          'ab': 41,
#          'runs': 4,
#          's': 5,
#          'd': 3,
#          't': 0,
#          'hr': 0,
#          'rbi': 4,
#          'bb': 4,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.267,
#          'slg': 0.268,
#          'ops': 0.535,
#          'h': 8,
#          'ktotal': 14,
#          'avg': '.195'}],
#        'venue': [{'id': 'f0600f04-1386-4c61-a412-804960c46cb1',
#          'name': 'Minute Maid Park',
#          'market': 'Houston',
#          'surface': 'grass',
#          'ab': 8,
#          'runs': 1,
#          's': 2,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 0,
#          'bb': 0,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.25,
#          'slg': 0.25,
#          'ops': 0.5,
#          'h': 2,
#          'ktotal': 3,
#          'avg': '.250'},
#         {'id': '4a550fc1-c03d-4294-b63a-30ff197bedc4',
#          'name': 'Guaranteed Rate Field',
#          'market': 'Chicago',
#          'surface': 'grass',
#          'ab': 12,
#          'runs': 2,
#          's': 2,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 2,
#          'bb': 2,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.286,
#          'slg': 0.167,
#          'ops': 0.453,
#          'h': 2,
#          'ktotal': 5,
#          'avg': '.167'},
#         {'id': 'bf05de0d-7ced-4a19-8e17-2bbd985f8a92',
#          'name': 'Chase Field',
#          'market': 'Arizona',
#          'surface': 'turf',
#          'ab': 3,
#          'runs': 0,
#          's': 0,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 0,
#          'bb': 0,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.0,
#          'slg': 0.0,
#          'ops': 0.0,
#          'h': 0,
#          'ktotal': 1,
#          'avg': '.000'},
#         {'id': '706e9828-6687-4ac8-a409-3fb972e8bae9',
#          'name': 'Yankee Stadium',
#          'market': 'New York',
#          'surface': 'grass',
#          'ab': 9,
#          'runs': 0,
#          's': 1,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 0,
#          'bb': 0,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.111,
#          'slg': 0.111,
#          'ops': 0.222,
#          'h': 1,
#          'ktotal': 3,
#          'avg': '.111'},
#         {'id': '3aaaf4af-0f8c-49c1-8bf1-1780bb5a5f5c',
#          'name': 'Tropicana Field',
#          'market': 'Tampa Bay',
#          'surface': 'turf',
#          'ab': 5,
#          'runs': 1,
#          's': 0,
#          'd': 1,
#          't': 0,
#          'hr': 0,
#          'rbi': 0,
#          'bb': 1,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.333,
#          'slg': 0.4,
#          'ops': 0.733,
#          'h': 1,
#          'ktotal': 2,
#          'avg': '.200'},
#         {'id': '84d72338-2173-4a90-9d25-99adc6c86f4b',
#          'name': 'Rogers Centre',
#          'market': 'Toronto',
#          'surface': 'turf',
#          'ab': 10,
#          'runs': 2,
#          's': 3,
#          'd': 1,
#          't': 0,
#          'hr': 1,
#          'rbi': 4,
#          'bb': 3,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.571,
#          'slg': 0.9,
#          'ops': 1.471,
#          'h': 5,
#          'ktotal': 2,
#          'avg': '.500'},
#         {'id': '48cbd35a-d932-4a75-beab-067bfbacfc26',
#          'name': 'Oakland Coliseum',
#          'market': 'Oakland',
#          'surface': 'grass',
#          'ab': 4,
#          'runs': 0,
#          's': 1,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 0,
#          'bb': 0,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.25,
#          'slg': 0.25,
#          'ops': 0.5,
#          'h': 1,
#          'ktotal': 3,
#          'avg': '.250'},
#         {'id': 'b27b0dc5-c2c5-401d-b8b9-a6a2dbc225e5',
#          'name': 'Fenway Park',
#          'market': 'Boston',
#          'surface': 'grass',
#          'ab': 35,
#          'runs': 3,
#          's': 2,
#          'd': 2,
#          't': 0,
#          'hr': 0,
#          'rbi': 3,
#          'bb': 1,
#          'ibb': 0,
#          'hbp': 1,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.162,
#          'slg': 0.171,
#          'ops': 0.333,
#          'h': 4,
#          'ktotal': 12,
#          'avg': '.114'},
#         {'id': '434aa63c-1049-4a54-a6bc-3790c7772ee1',
#          'name': 'Oriole Park at Camden Yards',
#          'market': 'Baltimore',
#          'surface': 'grass',
#          'ab': 3,
#          'runs': 0,
#          's': 0,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 0,
#          'bb': 0,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.0,
#          'slg': 0.0,
#          'ops': 0.0,
#          'h': 0,
#          'ktotal': 0,
#          'avg': '.000'}],
#        'surface': [{'value': 'grass',
#          'ab': 74,
#          'runs': 6,
#          's': 8,
#          'd': 2,
#          't': 0,
#          'hr': 0,
#          'rbi': 5,
#          'bb': 3,
#          'ibb': 0,
#          'hbp': 1,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.179,
#          'slg': 0.162,
#          'ops': 0.341,
#          'h': 10,
#          'ktotal': 27,
#          'avg': '.135'},
#         {'value': 'turf',
#          'ab': 15,
#          'runs': 3,
#          's': 3,
#          'd': 2,
#          't': 0,
#          'hr': 1,
#          'rbi': 4,
#          'bb': 4,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.5,
#          'slg': 0.733,
#          'ops': 1.233,
#          'h': 6,
#          'ktotal': 4,
#          'avg': '.400'}],
#        'month': [{'value': '4',
#          'ab': 39,
#          'runs': 2,
#          's': 3,
#          'd': 1,
#          't': 0,
#          'hr': 0,
#          'rbi': 1,
#          'bb': 2,
#          'ibb': 0,
#          'hbp': 1,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.167,
#          'slg': 0.128,
#          'ops': 0.295,
#          'h': 4,
#          'ktotal': 17,
#          'avg': '.103'},
#         {'value': '5',
#          'ab': 50,
#          'runs': 7,
#          's': 8,
#          'd': 3,
#          't': 0,
#          'hr': 1,
#          'rbi': 8,
#          'bb': 5,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.304,
#          'slg': 0.36,
#          'ops': 0.664,
#          'h': 12,
#          'ktotal': 14,
#          'avg': '.240'}],
#        'home_away': [{'value': 'away',
#          'ab': 54,
#          'runs': 6,
#          's': 9,
#          'd': 2,
#          't': 0,
#          'hr': 1,
#          'rbi': 6,
#          'bb': 6,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.295,
#          'slg': 0.315,
#          'ops': 0.61,
#          'h': 12,
#          'ktotal': 19,
#          'avg': '.222'},
#         {'value': 'home',
#          'ab': 35,
#          'runs': 3,
#          's': 2,
#          'd': 2,
#          't': 0,
#          'hr': 0,
#          'rbi': 3,
#          'bb': 1,
#          'ibb': 0,
#          'hbp': 1,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.162,
#          'slg': 0.171,
#          'ops': 0.333,
#          'h': 4,
#          'ktotal': 12,
#          'avg': '.114'}],
#        'pitcher_hand': [{'value': 'L',
#          'ab': 40,
#          'runs': 5,
#          's': 6,
#          'd': 1,
#          't': 0,
#          'hr': 1,
#          'rbi': 3,
#          'bb': 2,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.238,
#          'slg': 0.3,
#          'ops': 0.538,
#          'h': 8,
#          'ktotal': 16,
#          'avg': '.200'},
#         {'value': 'R',
#          'ab': 49,
#          'runs': 4,
#          's': 5,
#          'd': 3,
#          't': 0,
#          'hr': 0,
#          'rbi': 6,
#          'bb': 5,
#          'ibb': 0,
#          'hbp': 1,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.25,
#          'slg': 0.224,
#          'ops': 0.474,
#          'h': 8,
#          'ktotal': 15,
#          'avg': '.163'}],
#        'opponent': [{'id': '29dd9a87-5bcc-4774-80c3-7f50d985068b',
#          'name': 'Rockies',
#          'market': 'Colorado',
#          'abbr': 'COL',
#          'ab': 3,
#          'runs': 0,
#          's': 0,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 0,
#          'bb': 0,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.0,
#          'slg': 0.0,
#          'ops': 0.0,
#          'h': 0,
#          'ktotal': 1,
#          'avg': '.000'},
#         {'id': '43a39081-52b4-4f93-ad29-da7f329ea960',
#          'name': 'Mariners',
#          'market': 'Seattle',
#          'abbr': 'SEA',
#          'ab': 6,
#          'runs': 2,
#          's': 0,
#          'd': 1,
#          't': 0,
#          'hr': 0,
#          'rbi': 1,
#          'bb': 0,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.167,
#          'slg': 0.333,
#          'ops': 0.5,
#          'h': 1,
#          'ktotal': 2,
#          'avg': '.167'},
#         {'id': '80715d0d-0d2a-450f-a970-1b9a3b18c7e7',
#          'name': 'Indians',
#          'market': 'Cleveland',
#          'abbr': 'CLE',
#          'ab': 4,
#          'runs': 0,
#          's': 0,
#          'd': 1,
#          't': 0,
#          'hr': 0,
#          'rbi': 1,
#          'bb': 0,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.25,
#          'slg': 0.5,
#          'ops': 0.75,
#          'h': 1,
#          'ktotal': 1,
#          'avg': '.250'},
#         {'id': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107',
#          'name': 'Astros',
#          'market': 'Houston',
#          'abbr': 'HOU',
#          'ab': 11,
#          'runs': 1,
#          's': 3,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 0,
#          'bb': 0,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.273,
#          'slg': 0.273,
#          'ops': 0.546,
#          'h': 3,
#          'ktotal': 3,
#          'avg': '.273'},
#         {'id': '47f490cd-2f58-4ef7-9dfd-2ad6ba6c1ae8',
#          'name': 'White Sox',
#          'market': 'Chicago',
#          'abbr': 'CWS',
#          'ab': 12,
#          'runs': 2,
#          's': 2,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 2,
#          'bb': 2,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.286,
#          'slg': 0.167,
#          'ops': 0.453,
#          'h': 2,
#          'ktotal': 5,
#          'avg': '.167'},
#         {'id': '27a59d3b-ff7c-48ea-b016-4798f560f5e1',
#          'name': 'Athletics',
#          'market': 'Oakland',
#          'abbr': 'OAK',
#          'ab': 4,
#          'runs': 0,
#          's': 1,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 0,
#          'bb': 0,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.25,
#          'slg': 0.25,
#          'ops': 0.5,
#          'h': 1,
#          'ktotal': 3,
#          'avg': '.250'},
#         {'id': '575c19b7-4052-41c2-9f0a-1c5813d02f99',
#          'name': 'Tigers',
#          'market': 'Detroit',
#          'abbr': 'DET',
#          'ab': 3,
#          'runs': 0,
#          's': 0,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 0,
#          'bb': 0,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.0,
#          'slg': 0.0,
#          'ops': 0.0,
#          'h': 0,
#          'ktotal': 2,
#          'avg': '.000'},
#         {'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#          'name': 'Orioles',
#          'market': 'Baltimore',
#          'abbr': 'BAL',
#          'ab': 12,
#          'runs': 1,
#          's': 1,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 1,
#          'bb': 0,
#          'ibb': 0,
#          'hbp': 1,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.154,
#          'slg': 0.083,
#          'ops': 0.237,
#          'h': 1,
#          'ktotal': 4,
#          'avg': '.083'},
#         {'id': 'a09ec676-f887-43dc-bbb3-cf4bbaee9a18',
#          'name': 'Yankees',
#          'market': 'New York',
#          'abbr': 'NYY',
#          'ab': 9,
#          'runs': 0,
#          's': 1,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 0,
#          'bb': 0,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.111,
#          'slg': 0.111,
#          'ops': 0.222,
#          'h': 1,
#          'ktotal': 3,
#          'avg': '.111'},
#         {'id': 'bdc11650-6f74-49c4-875e-778aeb7632d9',
#          'name': 'Rays',
#          'market': 'Tampa Bay',
#          'abbr': 'TB',
#          'ab': 12,
#          'runs': 1,
#          's': 0,
#          'd': 1,
#          't': 0,
#          'hr': 0,
#          'rbi': 0,
#          'bb': 2,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.214,
#          'slg': 0.167,
#          'ops': 0.381,
#          'h': 1,
#          'ktotal': 4,
#          'avg': '.083'},
#         {'id': '25507be1-6a68-4267-bd82-e097d94b359b',
#          'name': 'Diamondbacks',
#          'market': 'Arizona',
#          'abbr': 'ARI',
#          'ab': 3,
#          'runs': 0,
#          's': 0,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 0,
#          'bb': 0,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.0,
#          'slg': 0.0,
#          'ops': 0.0,
#          'h': 0,
#          'ktotal': 1,
#          'avg': '.000'},
#         {'id': '1d678440-b4b1-4954-9b39-70afb3ebbcfa',
#          'name': 'Blue Jays',
#          'market': 'Toronto',
#          'abbr': 'TOR',
#          'ab': 10,
#          'runs': 2,
#          's': 3,
#          'd': 1,
#          't': 0,
#          'hr': 1,
#          'rbi': 4,
#          'bb': 3,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.571,
#          'slg': 0.9,
#          'ops': 1.471,
#          'h': 5,
#          'ktotal': 2,
#          'avg': '.500'}]}]}},
#    'statcast_metrics': {'hitting': {'overall': [{'travel_distance': {'min': 4.18,
#         'avg': 171.06,
#         'max': 376.36,
#         'count': 53}},
#       {'barreled_ball': {'min': 0.0, 'avg': 0.06, 'max': 1.0, 'count': 54}},
#       {'travel_time': {'min': 0.04, 'avg': 2.12, 'max': 5.2, 'count': 53}},
#       {'homerun_distance': {'min': 398.93,
#         'avg': 398.93,
#         'max': 398.93,
#         'count': 1}},
#       {'max_height': {'min': 1.67, 'avg': 44.6, 'max': 153.37, 'count': 54}},
#       {'generated_speed': {'min': 27.09,
#         'avg': 73.1,
#         'max': 91.92,
#         'count': 54}},
#       {'launch_speed': {'min': 43.66,
#         'avg': 88.52,
#         'max': 107.32,
#         'count': 59}},
#       {'launch_angle': {'min': -48.41,
#         'avg': 12.8,
#         'max': 70.68,
#         'count': 59}},
#       {'hang_time': {'min': 0.03, 'avg': 2.58, 'max': 6.4, 'count': 54}},
#       {'launch_spin_rate': {'min': 1009.78,
#         'avg': 2960.74,
#         'max': 5657.41,
#         'count': 34}},
#       {'distance': {'min': 3.68,
#         'avg': 168.12,
#         'max': 377.24,
#         'count': 53}}]}}},
#   'teams': [{'name': 'Red Sox',
#     'market': 'Boston',
#     'abbr': 'BOS',
#     'id': '93941372-eb4c-4c40-aced-fe3267174393',
#     'statistics': {'hitting': {'overall': {'ab': 89,
#        'lob': 53,
#        'rbi': 9,
#        'abhr': 89.0,
#        'abk': 2.871,
#        'bip': 58,
#        'babip': 0.259,
#        'bbk': 0.226,
#        'bbpa': 0.071,
#        'iso': 0.078,
#        'obp': 0.245,
#        'ops': 0.503,
#        'seca': 0.157,
#        'slg': 0.258,
#        'xbh': 5,
#        'pitch_count': 441,
#        'lob_risp_2out': 10,
#        'team_lob': 25,
#        'ab_risp': 23,
#        'hit_risp': 3,
#        'rbi_2out': 2,
#        'linedrive': 16,
#        'groundball': 25,
#        'popup': 5,
#        'flyball': 13,
#        'ap': 99,
#        'avg': '.180',
#        'gofo': 1.09,
#        'onbase': {'s': 11,
#         'd': 4,
#         't': 0,
#         'hr': 1,
#         'tb': 23,
#         'bb': 7,
#         'ibb': 0,
#         'hbp': 1,
#         'fc': 2,
#         'roe': 2,
#         'h': 16,
#         'cycle': 0},
#        'runs': {'total': 9},
#        'outcome': {'klook': 73,
#         'kswing': 66,
#         'ktotal': 139,
#         'ball': 136,
#         'iball': 0,
#         'dirtball': 20,
#         'foul': 85},
#        'outs': {'po': 4,
#         'fo': 11,
#         'fidp': 0,
#         'lo': 8,
#         'lidp': 0,
#         'go': 25,
#         'gidp': 5,
#         'klook': 7,
#         'kswing': 24,
#         'ktotal': 31,
#         'sacfly': 1,
#         'sachit': 0},
#        'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#        'pitches': {'count': 441, 'btotal': 158, 'ktotal': 283},
#        'games': {'start': 23, 'play': 29, 'finish': 6, 'complete': 17}}},
#      'fielding': {'overall': {'po': 100,
#        'a': 10,
#        'dp': 10,
#        'tp': 0,
#        'error': 3,
#        'tc': 113,
#        'fpct': 0.973,
#        'c_wp': 0,
#        'pb': 0,
#        'rf': 4.783,
#        'inn_1': 495,
#        'inn_2': 165.0,
#        'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#        'errors': {'throwing': 1, 'fielding': 2, 'interference': 0, 'total': 3},
#        'assists': {'outfield': 1, 'total': 10},
#        'games': {'start': 18, 'play': 23, 'finish': 5, 'complete': 0}},
#       'positions': [{'po': 97,
#         'a': 9,
#         'dp': 9,
#         'tp': 0,
#         'error': 3,
#         'tc': 109,
#         'fpct': 0.972,
#         'c_wp': 0,
#         'pb': 0,
#         'rf': 5.579,
#         'inn_1': 390,
#         'inn_2': 130.0,
#         'position': '1B',
#         'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#         'errors': {'throwing': 1,
#          'fielding': 2,
#          'interference': 0,
#          'total': 3},
#         'assists': {'outfield': 0, 'total': 9},
#         'games': {'start': 15, 'play': 19, 'finish': 4, 'complete': 0}},
#        {'po': 3,
#         'a': 1,
#         'dp': 1,
#         'tp': 0,
#         'error': 0,
#         'tc': 4,
#         'fpct': 1.0,
#         'c_wp': 0,
#         'pb': 0,
#         'rf': 1.0,
#         'inn_1': 105,
#         'inn_2': 35.0,
#         'position': 'LF',
#         'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#         'errors': {'throwing': 0,
#          'fielding': 0,
#          'interference': 0,
#          'total': 0},
#         'assists': {'outfield': 1, 'total': 1},
#         'games': {'start': 3, 'play': 4, 'finish': 1, 'complete': 0}}]}},
#     'splits': {'hitting': {'overall': [{'total': [{'ab': 89,
#           'runs': 9,
#           's': 11,
#           'd': 4,
#           't': 0,
#           'hr': 1,
#           'rbi': 9,
#           'bb': 7,
#           'ibb': 0,
#           'hbp': 1,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.245,
#           'slg': 0.258,
#           'ops': 0.503,
#           'h': 16,
#           'ktotal': 31,
#           'avg': '.180'}],
#         'day_night': [{'value': 'day',
#           'ab': 48,
#           'runs': 5,
#           's': 6,
#           'd': 1,
#           't': 0,
#           'hr': 1,
#           'rbi': 5,
#           'bb': 3,
#           'ibb': 0,
#           'hbp': 1,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.226,
#           'slg': 0.25,
#           'ops': 0.476,
#           'h': 8,
#           'ktotal': 17,
#           'avg': '.167'},
#          {'value': 'night',
#           'ab': 41,
#           'runs': 4,
#           's': 5,
#           'd': 3,
#           't': 0,
#           'hr': 0,
#           'rbi': 4,
#           'bb': 4,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.267,
#           'slg': 0.268,
#           'ops': 0.535,
#           'h': 8,
#           'ktotal': 14,
#           'avg': '.195'}],
#         'venue': [{'id': 'f0600f04-1386-4c61-a412-804960c46cb1',
#           'name': 'Minute Maid Park',
#           'market': 'Houston',
#           'surface': 'grass',
#           'ab': 8,
#           'runs': 1,
#           's': 2,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.25,
#           'slg': 0.25,
#           'ops': 0.5,
#           'h': 2,
#           'ktotal': 3,
#           'avg': '.250'},
#          {'id': '4a550fc1-c03d-4294-b63a-30ff197bedc4',
#           'name': 'Guaranteed Rate Field',
#           'market': 'Chicago',
#           'surface': 'grass',
#           'ab': 12,
#           'runs': 2,
#           's': 2,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 2,
#           'bb': 2,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.286,
#           'slg': 0.167,
#           'ops': 0.453,
#           'h': 2,
#           'ktotal': 5,
#           'avg': '.167'},
#          {'id': 'bf05de0d-7ced-4a19-8e17-2bbd985f8a92',
#           'name': 'Chase Field',
#           'market': 'Arizona',
#           'surface': 'turf',
#           'ab': 3,
#           'runs': 0,
#           's': 0,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.0,
#           'slg': 0.0,
#           'ops': 0.0,
#           'h': 0,
#           'ktotal': 1,
#           'avg': '.000'},
#          {'id': '706e9828-6687-4ac8-a409-3fb972e8bae9',
#           'name': 'Yankee Stadium',
#           'market': 'New York',
#           'surface': 'grass',
#           'ab': 9,
#           'runs': 0,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.111,
#           'slg': 0.111,
#           'ops': 0.222,
#           'h': 1,
#           'ktotal': 3,
#           'avg': '.111'},
#          {'id': '3aaaf4af-0f8c-49c1-8bf1-1780bb5a5f5c',
#           'name': 'Tropicana Field',
#           'market': 'Tampa Bay',
#           'surface': 'turf',
#           'ab': 5,
#           'runs': 1,
#           's': 0,
#           'd': 1,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.333,
#           'slg': 0.4,
#           'ops': 0.733,
#           'h': 1,
#           'ktotal': 2,
#           'avg': '.200'},
#          {'id': '84d72338-2173-4a90-9d25-99adc6c86f4b',
#           'name': 'Rogers Centre',
#           'market': 'Toronto',
#           'surface': 'turf',
#           'ab': 10,
#           'runs': 2,
#           's': 3,
#           'd': 1,
#           't': 0,
#           'hr': 1,
#           'rbi': 4,
#           'bb': 3,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.571,
#           'slg': 0.9,
#           'ops': 1.471,
#           'h': 5,
#           'ktotal': 2,
#           'avg': '.500'},
#          {'id': '48cbd35a-d932-4a75-beab-067bfbacfc26',
#           'name': 'Oakland Coliseum',
#           'market': 'Oakland',
#           'surface': 'grass',
#           'ab': 4,
#           'runs': 0,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.25,
#           'slg': 0.25,
#           'ops': 0.5,
#           'h': 1,
#           'ktotal': 3,
#           'avg': '.250'},
#          {'id': 'b27b0dc5-c2c5-401d-b8b9-a6a2dbc225e5',
#           'name': 'Fenway Park',
#           'market': 'Boston',
#           'surface': 'grass',
#           'ab': 35,
#           'runs': 3,
#           's': 2,
#           'd': 2,
#           't': 0,
#           'hr': 0,
#           'rbi': 3,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 1,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.162,
#           'slg': 0.171,
#           'ops': 0.333,
#           'h': 4,
#           'ktotal': 12,
#           'avg': '.114'},
#          {'id': '434aa63c-1049-4a54-a6bc-3790c7772ee1',
#           'name': 'Oriole Park at Camden Yards',
#           'market': 'Baltimore',
#           'surface': 'grass',
#           'ab': 3,
#           'runs': 0,
#           's': 0,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.0,
#           'slg': 0.0,
#           'ops': 0.0,
#           'h': 0,
#           'ktotal': 0,
#           'avg': '.000'}],
#         'surface': [{'value': 'grass',
#           'ab': 74,
#           'runs': 6,
#           's': 8,
#           'd': 2,
#           't': 0,
#           'hr': 0,
#           'rbi': 5,
#           'bb': 3,
#           'ibb': 0,
#           'hbp': 1,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.179,
#           'slg': 0.162,
#           'ops': 0.341,
#           'h': 10,
#           'ktotal': 27,
#           'avg': '.135'},
#          {'value': 'turf',
#           'ab': 15,
#           'runs': 3,
#           's': 3,
#           'd': 2,
#           't': 0,
#           'hr': 1,
#           'rbi': 4,
#           'bb': 4,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.5,
#           'slg': 0.733,
#           'ops': 1.233,
#           'h': 6,
#           'ktotal': 4,
#           'avg': '.400'}],
#         'month': [{'value': '4',
#           'ab': 39,
#           'runs': 2,
#           's': 3,
#           'd': 1,
#           't': 0,
#           'hr': 0,
#           'rbi': 1,
#           'bb': 2,
#           'ibb': 0,
#           'hbp': 1,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.167,
#           'slg': 0.128,
#           'ops': 0.295,
#           'h': 4,
#           'ktotal': 17,
#           'avg': '.103'},
#          {'value': '5',
#           'ab': 50,
#           'runs': 7,
#           's': 8,
#           'd': 3,
#           't': 0,
#           'hr': 1,
#           'rbi': 8,
#           'bb': 5,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.304,
#           'slg': 0.36,
#           'ops': 0.664,
#           'h': 12,
#           'ktotal': 14,
#           'avg': '.240'}],
#         'home_away': [{'value': 'away',
#           'ab': 54,
#           'runs': 6,
#           's': 9,
#           'd': 2,
#           't': 0,
#           'hr': 1,
#           'rbi': 6,
#           'bb': 6,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.295,
#           'slg': 0.315,
#           'ops': 0.61,
#           'h': 12,
#           'ktotal': 19,
#           'avg': '.222'},
#          {'value': 'home',
#           'ab': 35,
#           'runs': 3,
#           's': 2,
#           'd': 2,
#           't': 0,
#           'hr': 0,
#           'rbi': 3,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 1,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.162,
#           'slg': 0.171,
#           'ops': 0.333,
#           'h': 4,
#           'ktotal': 12,
#           'avg': '.114'}],
#         'pitcher_hand': [{'value': 'L',
#           'ab': 40,
#           'runs': 5,
#           's': 6,
#           'd': 1,
#           't': 0,
#           'hr': 1,
#           'rbi': 3,
#           'bb': 2,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.238,
#           'slg': 0.3,
#           'ops': 0.538,
#           'h': 8,
#           'ktotal': 16,
#           'avg': '.200'},
#          {'value': 'R',
#           'ab': 49,
#           'runs': 4,
#           's': 5,
#           'd': 3,
#           't': 0,
#           'hr': 0,
#           'rbi': 6,
#           'bb': 5,
#           'ibb': 0,
#           'hbp': 1,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.25,
#           'slg': 0.224,
#           'ops': 0.474,
#           'h': 8,
#           'ktotal': 15,
#           'avg': '.163'}],
#         'opponent': [{'id': '29dd9a87-5bcc-4774-80c3-7f50d985068b',
#           'name': 'Rockies',
#           'market': 'Colorado',
#           'abbr': 'COL',
#           'ab': 3,
#           'runs': 0,
#           's': 0,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.0,
#           'slg': 0.0,
#           'ops': 0.0,
#           'h': 0,
#           'ktotal': 1,
#           'avg': '.000'},
#          {'id': '43a39081-52b4-4f93-ad29-da7f329ea960',
#           'name': 'Mariners',
#           'market': 'Seattle',
#           'abbr': 'SEA',
#           'ab': 6,
#           'runs': 2,
#           's': 0,
#           'd': 1,
#           't': 0,
#           'hr': 0,
#           'rbi': 1,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.167,
#           'slg': 0.333,
#           'ops': 0.5,
#           'h': 1,
#           'ktotal': 2,
#           'avg': '.167'},
#          {'id': '80715d0d-0d2a-450f-a970-1b9a3b18c7e7',
#           'name': 'Indians',
#           'market': 'Cleveland',
#           'abbr': 'CLE',
#           'ab': 4,
#           'runs': 0,
#           's': 0,
#           'd': 1,
#           't': 0,
#           'hr': 0,
#           'rbi': 1,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.25,
#           'slg': 0.5,
#           'ops': 0.75,
#           'h': 1,
#           'ktotal': 1,
#           'avg': '.250'},
#          {'id': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107',
#           'name': 'Astros',
#           'market': 'Houston',
#           'abbr': 'HOU',
#           'ab': 11,
#           'runs': 1,
#           's': 3,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.273,
#           'slg': 0.273,
#           'ops': 0.546,
#           'h': 3,
#           'ktotal': 3,
#           'avg': '.273'},
#          {'id': '47f490cd-2f58-4ef7-9dfd-2ad6ba6c1ae8',
#           'name': 'White Sox',
#           'market': 'Chicago',
#           'abbr': 'CWS',
#           'ab': 12,
#           'runs': 2,
#           's': 2,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 2,
#           'bb': 2,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.286,
#           'slg': 0.167,
#           'ops': 0.453,
#           'h': 2,
#           'ktotal': 5,
#           'avg': '.167'},
#          {'id': '27a59d3b-ff7c-48ea-b016-4798f560f5e1',
#           'name': 'Athletics',
#           'market': 'Oakland',
#           'abbr': 'OAK',
#           'ab': 4,
#           'runs': 0,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.25,
#           'slg': 0.25,
#           'ops': 0.5,
#           'h': 1,
#           'ktotal': 3,
#           'avg': '.250'},
#          {'id': '575c19b7-4052-41c2-9f0a-1c5813d02f99',
#           'name': 'Tigers',
#           'market': 'Detroit',
#           'abbr': 'DET',
#           'ab': 3,
#           'runs': 0,
#           's': 0,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.0,
#           'slg': 0.0,
#           'ops': 0.0,
#           'h': 0,
#           'ktotal': 2,
#           'avg': '.000'},
#          {'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#           'name': 'Orioles',
#           'market': 'Baltimore',
#           'abbr': 'BAL',
#           'ab': 12,
#           'runs': 1,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 1,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 1,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.154,
#           'slg': 0.083,
#           'ops': 0.237,
#           'h': 1,
#           'ktotal': 4,
#           'avg': '.083'},
#          {'id': 'a09ec676-f887-43dc-bbb3-cf4bbaee9a18',
#           'name': 'Yankees',
#           'market': 'New York',
#           'abbr': 'NYY',
#           'ab': 9,
#           'runs': 0,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.111,
#           'slg': 0.111,
#           'ops': 0.222,
#           'h': 1,
#           'ktotal': 3,
#           'avg': '.111'},
#          {'id': 'bdc11650-6f74-49c4-875e-778aeb7632d9',
#           'name': 'Rays',
#           'market': 'Tampa Bay',
#           'abbr': 'TB',
#           'ab': 12,
#           'runs': 1,
#           's': 0,
#           'd': 1,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 2,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.214,
#           'slg': 0.167,
#           'ops': 0.381,
#           'h': 1,
#           'ktotal': 4,
#           'avg': '.083'},
#          {'id': '25507be1-6a68-4267-bd82-e097d94b359b',
#           'name': 'Diamondbacks',
#           'market': 'Arizona',
#           'abbr': 'ARI',
#           'ab': 3,
#           'runs': 0,
#           's': 0,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.0,
#           'slg': 0.0,
#           'ops': 0.0,
#           'h': 0,
#           'ktotal': 1,
#           'avg': '.000'},
#          {'id': '1d678440-b4b1-4954-9b39-70afb3ebbcfa',
#           'name': 'Blue Jays',
#           'market': 'Toronto',
#           'abbr': 'TOR',
#           'ab': 10,
#           'runs': 2,
#           's': 3,
#           'd': 1,
#           't': 0,
#           'hr': 1,
#           'rbi': 4,
#           'bb': 3,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.571,
#           'slg': 0.9,
#           'ops': 1.471,
#           'h': 5,
#           'ktotal': 2,
#           'avg': '.500'}]}]}}}]},
#  {'id': '00cd4d28-e638-4ae7-9824-6dbbfba50d4a',
#   'year': 2018,
#   'type': 'REG',
#   'totals': {'statistics': {'hitting': {'overall': {'ab': 215,
#       'lob': 85,
#       'rbi': 42,
#       'abhr': 19.545,
#       'abk': 5.244,
#       'bip': 165,
#       'babip': 0.303,
#       'bbk': 0.707,
#       'bbpa': 0.116,
#       'iso': 0.228,
#       'obp': 0.378,
#       'ops': 0.89,
#       'seca': 0.363,
#       'slg': 0.512,
#       'xbh': 26,
#       'pitch_count': 1047,
#       'lob_risp_2out': 26,
#       'team_lob': 46,
#       'ab_risp': 57,
#       'hit_risp': 21,
#       'rbi_2out': 18,
#       'linedrive': 46,
#       'groundball': 77,
#       'popup': 12,
#       'flyball': 41,
#       'ap': 251,
#       'avg': '.284',
#       'gofo': 1.05,
#       'onbase': {'s': 35,
#        'd': 14,
#        't': 1,
#        'hr': 11,
#        'tb': 110,
#        'bb': 29,
#        'ibb': 0,
#        'hbp': 5,
#        'fc': 8,
#        'roe': 4,
#        'h': 61,
#        'cycle': 0},
#       'runs': {'total': 35},
#       'outcome': {'klook': 165,
#        'kswing': 111,
#        'ktotal': 276,
#        'ball': 398,
#        'iball': 0,
#        'dirtball': 27,
#        'foul': 165},
#       'outs': {'po': 12,
#        'fo': 28,
#        'fidp': 0,
#        'lo': 17,
#        'lidp': 1,
#        'go': 60,
#        'gidp': 2,
#        'klook': 11,
#        'kswing': 30,
#        'ktotal': 41,
#        'sacfly': 2,
#        'sachit': 0},
#       'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#       'pitches': {'count': 1047, 'btotal': 430, 'ktotal': 617},
#       'games': {'start': 55, 'play': 76, 'finish': 19, 'complete': 37}}},
#     'fielding': {'overall': {'po': 200,
#       'a': 15,
#       'dp': 13,
#       'tp': 0,
#       'error': 1,
#       'tc': 216,
#       'fpct': 0.995,
#       'c_wp': 0,
#       'pb': 0,
#       'rf': 4.388,
#       'inn_1': 945,
#       'inn_2': 315.0,
#       'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#       'errors': {'throwing': 0, 'fielding': 1, 'interference': 0, 'total': 1},
#       'assists': {'outfield': 0, 'total': 15},
#       'games': {'start': 37, 'play': 49, 'finish': 11, 'complete': 0}},
#      'positions': [{'po': 182,
#        'a': 15,
#        'dp': 13,
#        'tp': 0,
#        'error': 1,
#        'tc': 198,
#        'fpct': 0.995,
#        'c_wp': 0,
#        'pb': 0,
#        'rf': 5.794,
#        'inn_1': 708,
#        'inn_2': 236.0,
#        'position': '1B',
#        'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#        'errors': {'throwing': 0, 'fielding': 1, 'interference': 0, 'total': 1},
#        'assists': {'outfield': 0, 'total': 15},
#        'games': {'start': 28, 'play': 34, 'finish': 6, 'complete': 0}},
#       {'po': 15,
#        'a': 0,
#        'dp': 0,
#        'tp': 0,
#        'error': 0,
#        'tc': 15,
#        'fpct': 1.0,
#        'c_wp': 0,
#        'pb': 0,
#        'rf': 1.364,
#        'inn_1': 171,
#        'inn_2': 57.0,
#        'position': 'LF',
#        'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#        'errors': {'throwing': 0, 'fielding': 0, 'interference': 0, 'total': 0},
#        'assists': {'outfield': 0, 'total': 0},
#        'games': {'start': 7, 'play': 11, 'finish': 4, 'complete': 0}},
#       {'po': 3,
#        'a': 0,
#        'dp': 0,
#        'tp': 0,
#        'error': 0,
#        'tc': 3,
#        'fpct': 1.0,
#        'c_wp': 0,
#        'pb': 0,
#        'rf': 0.75,
#        'inn_1': 66,
#        'inn_2': 22.0,
#        'position': 'RF',
#        'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#        'errors': {'throwing': 0, 'fielding': 0, 'interference': 0, 'total': 0},
#        'assists': {'outfield': 0, 'total': 0},
#        'games': {'start': 2, 'play': 4, 'finish': 1, 'complete': 0}}]}},
#    'splits': {'hitting': {'overall': [{'total': [{'ab': 215,
#          'runs': 35,
#          's': 35,
#          'd': 14,
#          't': 1,
#          'hr': 11,
#          'rbi': 42,
#          'bb': 29,
#          'ibb': 0,
#          'hbp': 5,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.378,
#          'slg': 0.512,
#          'ops': 0.89,
#          'h': 61,
#          'ktotal': 41,
#          'avg': '.284'}],
#        'day_night': [{'value': 'night',
#          'ab': 150,
#          'runs': 24,
#          's': 21,
#          'd': 12,
#          't': 1,
#          'hr': 9,
#          'rbi': 35,
#          'bb': 19,
#          'ibb': 0,
#          'hbp': 4,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.382,
#          'slg': 0.56,
#          'ops': 0.942,
#          'h': 43,
#          'ktotal': 25,
#          'avg': '.287'},
#         {'value': 'day',
#          'ab': 65,
#          'runs': 11,
#          's': 14,
#          'd': 2,
#          't': 0,
#          'hr': 2,
#          'rbi': 7,
#          'bb': 10,
#          'ibb': 0,
#          'hbp': 1,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.372,
#          'slg': 0.4,
#          'ops': 0.772,
#          'h': 18,
#          'ktotal': 16,
#          'avg': '.277'}],
#        'venue': [{'id': 'f0600f04-1386-4c61-a412-804960c46cb1',
#          'name': 'Minute Maid Park',
#          'market': 'Houston',
#          'surface': 'grass',
#          'ab': 2,
#          'runs': 1,
#          's': 0,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 0,
#          'bb': 1,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.333,
#          'slg': 0.0,
#          'ops': 0.333,
#          'h': 0,
#          'ktotal': 1,
#          'avg': '.000'},
#         {'id': '60732da9-ad03-4feb-9a36-aee3e98c7a2b',
#          'name': 'Angel Stadium of Anaheim',
#          'market': 'Los Angeles',
#          'surface': 'grass',
#          'ab': 11,
#          'runs': 1,
#          's': 3,
#          'd': 1,
#          't': 0,
#          'hr': 1,
#          'rbi': 3,
#          'bb': 0,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.455,
#          'slg': 0.818,
#          'ops': 1.273,
#          'h': 5,
#          'ktotal': 2,
#          'avg': '.455'},
#         {'id': '706e9828-6687-4ac8-a409-3fb972e8bae9',
#          'name': 'Yankee Stadium',
#          'market': 'New York',
#          'surface': 'grass',
#          'ab': 15,
#          'runs': 0,
#          's': 3,
#          'd': 1,
#          't': 0,
#          'hr': 0,
#          'rbi': 1,
#          'bb': 3,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.389,
#          'slg': 0.333,
#          'ops': 0.722,
#          'h': 4,
#          'ktotal': 3,
#          'avg': '.267'},
#         {'id': '3f47c1c6-b059-4fa2-9d85-5d37b7000992',
#          'name': 'Globe Life Park in Arlington',
#          'surface': 'grass',
#          'ab': 10,
#          'runs': 3,
#          's': 0,
#          'd': 0,
#          't': 0,
#          'hr': 2,
#          'rbi': 2,
#          'bb': 2,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.333,
#          'slg': 0.8,
#          'ops': 1.133,
#          'h': 2,
#          'ktotal': 1,
#          'avg': '.200'},
#         {'id': '434aa63c-1049-4a54-a6bc-3790c7772ee1',
#          'name': 'Oriole Park at Camden Yards',
#          'market': 'Baltimore',
#          'surface': 'grass',
#          'ab': 18,
#          'runs': 5,
#          's': 2,
#          'd': 0,
#          't': 0,
#          'hr': 2,
#          'rbi': 3,
#          'bb': 3,
#          'ibb': 0,
#          'hbp': 1,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.364,
#          'slg': 0.556,
#          'ops': 0.92,
#          'h': 4,
#          'ktotal': 3,
#          'avg': '.222'},
#         {'id': '2b0ccd49-4d87-4996-ac4d-27ffc7ee4c16',
#          'name': 'Progressive Field',
#          'market': 'Cleveland',
#          'surface': 'grass',
#          'ab': 15,
#          'runs': 2,
#          's': 2,
#          'd': 1,
#          't': 0,
#          'hr': 0,
#          'rbi': 2,
#          'bb': 1,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.25,
#          'slg': 0.267,
#          'ops': 0.517,
#          'h': 3,
#          'ktotal': 1,
#          'avg': '.200'},
#         {'id': '84d72338-2173-4a90-9d25-99adc6c86f4b',
#          'name': 'Rogers Centre',
#          'market': 'Toronto',
#          'surface': 'turf',
#          'ab': 35,
#          'runs': 8,
#          's': 6,
#          'd': 4,
#          't': 0,
#          'hr': 0,
#          'rbi': 6,
#          'bb': 3,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.342,
#          'slg': 0.4,
#          'ops': 0.742,
#          'h': 10,
#          'ktotal': 7,
#          'avg': '.286'},
#         {'id': 'b27b0dc5-c2c5-401d-b8b9-a6a2dbc225e5',
#          'name': 'Fenway Park',
#          'market': 'Boston',
#          'surface': 'grass',
#          'ab': 62,
#          'runs': 8,
#          's': 6,
#          'd': 3,
#          't': 1,
#          'hr': 6,
#          'rbi': 16,
#          'bb': 10,
#          'ibb': 0,
#          'hbp': 3,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.387,
#          'slg': 0.629,
#          'ops': 1.016,
#          'h': 16,
#          'ktotal': 17,
#          'avg': '.258'},
#         {'id': '3aaaf4af-0f8c-49c1-8bf1-1780bb5a5f5c',
#          'name': 'Tropicana Field',
#          'market': 'Tampa Bay',
#          'surface': 'turf',
#          'ab': 11,
#          'runs': 1,
#          's': 2,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 0,
#          'bb': 2,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.308,
#          'slg': 0.182,
#          'ops': 0.49,
#          'h': 2,
#          'ktotal': 1,
#          'avg': '.182'},
#         {'id': '4a550fc1-c03d-4294-b63a-30ff197bedc4',
#          'name': 'Guaranteed Rate Field',
#          'market': 'Chicago',
#          'surface': 'grass',
#          'ab': 4,
#          'runs': 0,
#          's': 1,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 1,
#          'bb': 0,
#          'ibb': 0,
#          'hbp': 1,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.4,
#          'slg': 0.25,
#          'ops': 0.65,
#          'h': 1,
#          'ktotal': 0,
#          'avg': '.250'},
#         {'id': '3ca8b577-5844-42ed-81a5-bd5d5cbe350c',
#          'name': 'Truist Park',
#          'market': 'Atlanta',
#          'surface': 'grass',
#          'ab': 5,
#          'runs': 0,
#          's': 3,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'rbi': 4,
#          'bb': 1,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.571,
#          'slg': 0.6,
#          'ops': 1.171,
#          'h': 3,
#          'ktotal': 2,
#          'avg': '.600'},
#         {'id': '6fca95c9-7f2c-4acb-a9f3-02ef96340d2a',
#          'name': 'Kauffman Stadium',
#          'market': 'Kansas City',
#          'surface': 'grass',
#          'ab': 7,
#          'runs': 3,
#          's': 3,
#          'd': 2,
#          't': 0,
#          'hr': 0,
#          'rbi': 2,
#          'bb': 2,
#          'ibb': 0,
#          'hbp': 0,
#          'sb': 0,
#          'cs': 0,
#          'obp': 0.7,
# ...
#          {'id': 'd89bed32-3aee-4407-99e3-4103641b999a',
#           'name': 'Nationals',
#           'market': 'Washington',
#           'abbr': 'WSH',
#           'ab': 18,
#           'runs': 3,
#           's': 1,
#           'd': 2,
#           't': 0,
#           'hr': 2,
#           'rbi': 4,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.316,
#           'slg': 0.722,
#           'ops': 1.038,
#           'h': 5,
#           'ktotal': 4,
#           'avg': '.278'},
#          {'id': '47f490cd-2f58-4ef7-9dfd-2ad6ba6c1ae8',
#           'name': 'White Sox',
#           'market': 'Chicago',
#           'abbr': 'CWS',
#           'ab': 10,
#           'runs': 2,
#           's': 5,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 1,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.545,
#           'slg': 0.5,
#           'ops': 1.045,
#           'h': 5,
#           'ktotal': 1,
#           'avg': '.500'},
#          {'id': 'd99f919b-1534-4516-8e8a-9cd106c6d8cd',
#           'name': 'Rangers',
#           'market': 'Texas',
#           'abbr': 'TEX',
#           'ab': 15,
#           'runs': 1,
#           's': 0,
#           'd': 1,
#           't': 0,
#           'hr': 1,
#           'rbi': 1,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.188,
#           'slg': 0.4,
#           'ops': 0.588,
#           'h': 2,
#           'ktotal': 4,
#           'avg': '.133'},
#          {'id': 'f246a5e5-afdb-479c-9aaa-c68beeda7af6',
#           'name': 'Mets',
#           'market': 'New York',
#           'abbr': 'NYM',
#           'ab': 1,
#           'runs': 0,
#           's': 0,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.0,
#           'slg': 0.0,
#           'ops': 0.0,
#           'h': 0,
#           'ktotal': 1,
#           'avg': '.000'},
#          {'id': '2142e1ba-3b40-445c-b8bb-f1f8b1054220',
#           'name': 'Phillies',
#           'market': 'Philadelphia',
#           'abbr': 'PHI',
#           'ab': 1,
#           'runs': 0,
#           's': 0,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.0,
#           'slg': 0.0,
#           'ops': 0.0,
#           'h': 0,
#           'ktotal': 0,
#           'avg': '.000'},
#          {'id': '43a39081-52b4-4f93-ad29-da7f329ea960',
#           'name': 'Mariners',
#           'market': 'Seattle',
#           'abbr': 'SEA',
#           'ab': 11,
#           'runs': 2,
#           's': 2,
#           'd': 0,
#           't': 0,
#           'hr': 1,
#           'rbi': 5,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.333,
#           'slg': 0.545,
#           'ops': 0.878,
#           'h': 3,
#           'ktotal': 2,
#           'avg': '.273'},
#          {'id': '93941372-eb4c-4c40-aced-fe3267174393',
#           'name': 'Red Sox',
#           'market': 'Boston',
#           'abbr': 'BOS',
#           'ab': 47,
#           'runs': 6,
#           's': 7,
#           'd': 3,
#           't': 0,
#           'hr': 1,
#           'rbi': 7,
#           'bb': 5,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 1,
#           'cs': 0,
#           'obp': 0.302,
#           'slg': 0.362,
#           'ops': 0.664,
#           'h': 11,
#           'ktotal': 7,
#           'avg': '.234'},
#          {'id': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107',
#           'name': 'Astros',
#           'market': 'Houston',
#           'abbr': 'HOU',
#           'ab': 22,
#           'runs': 4,
#           's': 3,
#           'd': 0,
#           't': 0,
#           'hr': 2,
#           'rbi': 5,
#           'bb': 2,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.292,
#           'slg': 0.5,
#           'ops': 0.792,
#           'h': 5,
#           'ktotal': 9,
#           'avg': '.227'},
#          {'id': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d',
#           'name': 'Twins',
#           'market': 'Minnesota',
#           'abbr': 'MIN',
#           'ab': 5,
#           'runs': 1,
#           's': 0,
#           'd': 0,
#           't': 1,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.2,
#           'slg': 0.6,
#           'ops': 0.8,
#           'h': 1,
#           'ktotal': 1,
#           'avg': '.200'},
#          {'id': '575c19b7-4052-41c2-9f0a-1c5813d02f99',
#           'name': 'Tigers',
#           'market': 'Detroit',
#           'abbr': 'DET',
#           'ab': 5,
#           'runs': 0,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.2,
#           'slg': 0.2,
#           'ops': 0.4,
#           'h': 1,
#           'ktotal': 2,
#           'avg': '.200'},
#          {'id': 'bdc11650-6f74-49c4-875e-778aeb7632d9',
#           'name': 'Rays',
#           'market': 'Tampa Bay',
#           'abbr': 'TB',
#           'ab': 43,
#           'runs': 9,
#           's': 2,
#           'd': 3,
#           't': 0,
#           'hr': 4,
#           'rbi': 8,
#           'bb': 4,
#           'ibb': 0,
#           'hbp': 2,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.306,
#           'slg': 0.558,
#           'ops': 0.864,
#           'h': 9,
#           'ktotal': 10,
#           'avg': '.209'},
#          {'id': '833a51a9-0d84-410f-bd77-da08c3e5e26e',
#           'name': 'Royals',
#           'market': 'Kansas City',
#           'abbr': 'KC',
#           'ab': 16,
#           'runs': 4,
#           's': 4,
#           'd': 1,
#           't': 0,
#           'hr': 1,
#           'rbi': 2,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 1,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.444,
#           'slg': 0.625,
#           'ops': 1.069,
#           'h': 6,
#           'ktotal': 4,
#           'avg': '.375'},
#          {'id': '80715d0d-0d2a-450f-a970-1b9a3b18c7e7',
#           'name': 'Indians',
#           'market': 'Cleveland',
#           'abbr': 'CLE',
#           'ab': 5,
#           'runs': 0,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 1,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.333,
#           'slg': 0.2,
#           'ops': 0.533,
#           'h': 1,
#           'ktotal': 3,
#           'avg': '.200'}]}]}}}]},
#  {'id': '8f4e3a30-8444-11e3-808c-22000a904a71',
#   'year': 2014,
#   'type': 'PST',
#   'totals': {'statistics': {'hitting': {'overall': {'ab': 27,
#       'lob': 12,
#       'rbi': 1,
#       'abhr': 0,
#       'abk': 9.0,
#       'bip': 24,
#       'babip': 0.167,
#       'bbk': 0.667,
#       'bbpa': 0.067,
#       'iso': 0.037,
#       'obp': 0.233,
#       'ops': 0.418,
#       'seca': 0.111,
#       'slg': 0.185,
#       'xbh': 1,
#       'pitch_count': 100,
#       'ap': 30,
#       'avg': '.148',
#       'gofo': 0.33,
#       'onbase': {'s': 3,
#        'd': 1,
#        't': 0,
#        'hr': 0,
#        'tb': 5,
#        'bb': 2,
#        'ibb': 0,
#        'hbp': 1,
#        'fc': 1,
#        'roe': 0,
#        'h': 4,
#        'cycle': 0},
#       'runs': {'total': 4},
#       'outcome': {'klook': 5,
#        'kswing': 16,
#        'ktotal': 21,
#        'ball': 26,
#        'iball': 0,
#        'dirtball': 2,
#        'foul': 0},
#       'outs': {'po': 3,
#        'fo': 7,
#        'fidp': 0,
#        'lo': 5,
#        'lidp': 0,
#        'go': 5,
#        'gidp': 0,
#        'klook': 1,
#        'kswing': 2,
#        'ktotal': 3,
#        'sacfly': 0,
#        'sachit': 0},
#       'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#       'games': {'start': 7, 'play': 7, 'finish': 0, 'complete': 7}}},
#     'fielding': {'overall': {'po': 59,
#       'a': 4,
#       'dp': 7,
#       'tp': 0,
#       'error': 0,
#       'tc': 63,
#       'fpct': 1.0,
#       'rf': 9.0,
#       'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#       'errors': {'throwing': 0, 'fielding': 0, 'interference': 0, 'total': 0},
#       'games': {'start': 7, 'play': 7, 'finish': 0, 'complete': 0}}}}},
#   'teams': [{'name': 'Orioles',
#     'market': 'Baltimore',
#     'abbr': 'BAL',
#     'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#     'statistics': {'hitting': {'overall': {'ab': 27,
#        'lob': 12,
#        'rbi': 1,
#        'abhr': 0,
#        'abk': 9.0,
#        'bip': 24,
#        'babip': 0.167,
#        'bbk': 0.667,
#        'bbpa': 0.067,
#        'iso': 0.037,
#        'obp': 0.233,
#        'ops': 0.418,
#        'seca': 0.111,
#        'slg': 0.185,
#        'xbh': 1,
#        'pitch_count': 100,
#        'ap': 30,
#        'avg': '.148',
#        'gofo': 0.33,
#        'onbase': {'s': 3,
#         'd': 1,
#         't': 0,
#         'hr': 0,
#         'tb': 5,
#         'bb': 2,
#         'ibb': 0,
#         'hbp': 1,
#         'fc': 1,
#         'roe': 0,
#         'h': 4,
#         'cycle': 0},
#        'runs': {'total': 4},
#        'outcome': {'klook': 5,
#         'kswing': 16,
#         'ktotal': 21,
#         'ball': 26,
#         'iball': 0,
#         'dirtball': 2,
#         'foul': 0},
#        'outs': {'po': 3,
#         'fo': 7,
#         'fidp': 0,
#         'lo': 5,
#         'lidp': 0,
#         'go': 5,
#         'gidp': 0,
#         'klook': 1,
#         'kswing': 2,
#         'ktotal': 3,
#         'sacfly': 0,
#         'sachit': 0},
#        'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#        'games': {'start': 7, 'play': 7, 'finish': 0, 'complete': 7}}},
#      'fielding': {'overall': {'po': 59,
#        'a': 4,
#        'dp': 7,
#        'tp': 0,
#        'error': 0,
#        'tc': 63,
#        'fpct': 1.0,
#        'rf': 9.0,
#        'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#        'errors': {'throwing': 0, 'fielding': 0, 'interference': 0, 'total': 0},
#        'games': {'start': 7, 'play': 7, 'finish': 0, 'complete': 0}}}}}]},
#  {'id': '8f4e3a30-8444-11e3-808c-22000a904a71',
#   'year': 2014,
#   'type': 'REG',
#   'totals': {'statistics': {'hitting': {'overall': {'ab': 338,
#       'lob': 117,
#       'rbi': 49,
#       'abhr': 16.095,
#       'abk': 4.447,
#       'bip': 242,
#       'babip': 0.322,
#       'bbk': 0.526,
#       'bbpa': 0.104,
#       'iso': 0.263,
#       'obp': 0.373,
#       'ops': 0.929,
#       'seca': 0.396,
#       'slg': 0.556,
#       'xbh': 47,
#       'pitch_count': 1525,
#       'ap': 383,
#       'avg': '.293',
#       'gofo': 0.79,
#       'onbase': {'s': 52,
#        'd': 26,
#        't': 0,
#        'hr': 21,
#        'tb': 188,
#        'bb': 39,
#        'ibb': 1,
#        'hbp': 4,
#        'fc': 8,
#        'roe': 4,
#        'h': 99,
#        'cycle': 0},
#       'runs': {'total': 51},
#       'outcome': {'klook': 216,
#        'kswing': 124,
#        'ktotal': 340,
#        'ball': 513,
#        'iball': 3,
#        'dirtball': 23,
#        'foul': 0},
#       'outs': {'po': 23,
#        'fo': 64,
#        'fidp': 0,
#        'lo': 6,
#        'lidp': 0,
#        'go': 74,
#        'gidp': 4,
#        'klook': 14,
#        'kswing': 62,
#        'ktotal': 76,
#        'sacfly': 1,
#        'sachit': 0},
#       'steal': {'caught': 0, 'stolen': 5, 'pct': 1.0, 'pickoff': 0},
#       'games': {'start': 86, 'play': 102, 'finish': 14, 'complete': 62}}},
#     'fielding': {'overall': {'po': 474,
#       'a': 42,
#       'dp': 35,
#       'tp': 0,
#       'error': 1,
#       'tc': 517,
#       'fpct': 0.998,
#       'rf': 5.489,
#       'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#       'errors': {'throwing': 0, 'fielding': 0, 'interference': 0, 'total': 1},
#       'games': {'start': 78, 'play': 94, 'finish': 14, 'complete': 6}}}}},
#   'teams': [{'name': 'Orioles',
#     'market': 'Baltimore',
#     'abbr': 'BAL',
#     'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#     'statistics': {'hitting': {'overall': {'ab': 338,
#        'lob': 117,
#        'rbi': 49,
#        'abhr': 16.095,
#        'abk': 4.447,
#        'bip': 242,
#        'babip': 0.322,
#        'bbk': 0.526,
#        'bbpa': 0.104,
#        'iso': 0.263,
#        'obp': 0.373,
#        'ops': 0.929,
#        'seca': 0.396,
#        'slg': 0.556,
#        'xbh': 47,
#        'pitch_count': 1525,
#        'ap': 383,
#        'avg': '.293',
#        'gofo': 0.79,
#        'onbase': {'s': 52,
#         'd': 26,
#         't': 0,
#         'hr': 21,
#         'tb': 188,
#         'bb': 39,
#         'ibb': 1,
#         'hbp': 4,
#         'fc': 8,
#         'roe': 4,
#         'h': 99,
#         'cycle': 0},
#        'runs': {'total': 51},
#        'outcome': {'klook': 216,
#         'kswing': 124,
#         'ktotal': 340,
#         'ball': 513,
#         'iball': 3,
#         'dirtball': 23,
#         'foul': 0},
#        'outs': {'po': 23,
#         'fo': 64,
#         'fidp': 0,
#         'lo': 6,
#         'lidp': 0,
#         'go': 74,
#         'gidp': 4,
#         'klook': 14,
#         'kswing': 62,
#         'ktotal': 76,
#         'sacfly': 1,
#         'sachit': 0},
#        'steal': {'caught': 0, 'stolen': 5, 'pct': 1.0, 'pickoff': 0},
#        'games': {'start': 86, 'play': 102, 'finish': 14, 'complete': 62}}},
#      'fielding': {'overall': {'po': 474,
#        'a': 42,
#        'dp': 35,
#        'tp': 0,
#        'error': 1,
#        'tc': 517,
#        'fpct': 0.998,
#        'rf': 5.489,
#        'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#        'errors': {'throwing': 0, 'fielding': 0, 'interference': 0, 'total': 1},
#        'games': {'start': 78, 'play': 94, 'finish': 14, 'complete': 6}}}}}]},
#  {'id': '58dd9a81-4a38-4a66-8cd7-32ae4d567ba8',
#   'year': 2013,
#   'type': 'REG',
#   'totals': {'statistics': {'hitting': {'overall': {'ab': 119,
#       'lob': 50,
#       'rbi': 13,
#       'abhr': 29.75,
#       'abk': 4.76,
#       'bip': 90,
#       'babip': 0.3,
#       'bbk': 0.6,
#       'bbpa': 0.109,
#       'iso': 0.159,
#       'obp': 0.362,
#       'ops': 0.782,
#       'seca': 0.294,
#       'slg': 0.42,
#       'xbh': 11,
#       'pitch_count': 562,
#       'ap': 138,
#       'avg': '.261',
#       'gofo': 0.51,
#       'onbase': {'s': 20,
#        'd': 7,
#        't': 0,
#        'hr': 4,
#        'tb': 50,
#        'bb': 14,
#        'ibb': 1,
#        'hbp': 4,
#        'fc': 6,
#        'roe': 1,
#        'h': 31,
#        'cycle': 0},
#       'runs': {'total': 14},
#       'outcome': {'klook': 98,
#        'kswing': 37,
#        'ktotal': 135,
#        'ball': 181,
#        'iball': 3,
#        'dirtball': 13,
#        'foul': 0},
#       'outs': {'po': 10,
#        'fo': 24,
#        'fidp': 0,
#        'lo': 3,
#        'lidp': 0,
#        'go': 19,
#        'gidp': 0,
#        'klook': 2,
#        'kswing': 23,
#        'ktotal': 25,
#        'sacfly': 0,
#        'sachit': 0},
#       'steal': {'caught': 0, 'stolen': 1, 'pct': 1.0, 'pickoff': 0},
#       'games': {'start': 37, 'play': 44, 'finish': 27, 'complete': 22}}}}},
#   'teams': [{'name': 'Orioles',
#     'market': 'Baltimore',
#     'abbr': 'BAL',
#     'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#     'statistics': {'hitting': {'overall': {'ab': 119,
#        'lob': 50,
#        'rbi': 13,
#        'abhr': 29.75,
#        'abk': 4.76,
#        'bip': 90,
#        'babip': 0.3,
#        'bbk': 0.6,
#        'bbpa': 0.109,
#        'iso': 0.159,
#        'obp': 0.362,
#        'ops': 0.782,
#        'seca': 0.294,
#        'slg': 0.42,
#        'xbh': 11,
#        'pitch_count': 562,
#        'ap': 138,
#        'avg': '.261',
#        'gofo': 0.51,
#        'onbase': {'s': 20,
#         'd': 7,
#         't': 0,
#         'hr': 4,
#         'tb': 50,
#         'bb': 14,
#         'ibb': 1,
#         'hbp': 4,
#         'fc': 6,
#         'roe': 1,
#         'h': 31,
#         'cycle': 0},
#        'runs': {'total': 14},
#        'outcome': {'klook': 98,
#         'kswing': 37,
#         'ktotal': 135,
#         'ball': 181,
#         'iball': 3,
#         'dirtball': 13,
#         'foul': 0},
#        'outs': {'po': 10,
#         'fo': 24,
#         'fidp': 0,
#         'lo': 3,
#         'lidp': 0,
#         'go': 19,
#         'gidp': 0,
#         'klook': 2,
#         'kswing': 23,
#         'ktotal': 25,
#         'sacfly': 0,
#         'sachit': 0},
#        'steal': {'caught': 0, 'stolen': 1, 'pct': 1.0, 'pickoff': 0},
#        'games': {'start': 37, 'play': 44, 'finish': 27, 'complete': 22}}}}}]}]

# %%
# Save config information.
url2 = "http://api.sportradar.us/mlb/trial/v7/en/players/"
# Build partial query URL
query_url = f"{url2}{id}/profile.json?api_key={api_key}"
print(query_url)
# Out:
# http://api.sportradar.us/mlb/trial/v7/en/players/<built-in function id>/profile.json?api_key=aqqw53drpuemy2dfq4u7sypp

# %%
# #test response to get data out of json
response3 = requests.get(query_url).json()
response3
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-7-4fad56647940> in <module>
#       1 # #test response to get data out of json
# ----> 2 response3 = requests.get(query_url).json()
#       3 response3
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
geez= response2['player']['seasons']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8c1dfe7a4b58> in <module>
# ----> 1 geez= response2['player']['seasons']
#
# NameError: name 'response2' is not defined

# %%
len(geez)
# Out:
# 9

# %%
def getseasonByYear(seasons,year,seasonType ='REG'):
    for season in seasons:
        if(season.get('year',0) == year and season.get('type','N/A') == seasonType):
            return season;
    return 'season not found'

# %%
def getseasonAllseasons(seasons):
    seasonsYears = []
    for season in seasons:
        seasonsYears.append([season.get('year','N/A'),season.get('type','N/A')])
    return seasonsYears

# %%
getseasonAllseasons(geez)
# Out:
# [[2019, 'REG'],
#  [2018, 'REG'],
#  [2018, 'PST'],
#  [2017, 'REG'],
#  [2016, 'REG'],
#  [2015, 'REG'],
#  [2014, 'PST'],
#  [2014, 'REG'],
#  [2013, 'REG']]

# %%
getseasonByYear(geez,2014)
# Out:
# {'id': '8f4e3a30-8444-11e3-808c-22000a904a71',
#  'year': 2014,
#  'type': 'REG',
#  'totals': {'statistics': {'hitting': {'overall': {'ab': 338,
#      'lob': 117,
#      'rbi': 49,
#      'abhr': 16.095,
#      'abk': 4.447,
#      'bip': 242,
#      'babip': 0.322,
#      'bbk': 0.526,
#      'bbpa': 0.104,
#      'iso': 0.263,
#      'obp': 0.373,
#      'ops': 0.929,
#      'seca': 0.396,
#      'slg': 0.556,
#      'xbh': 47,
#      'pitch_count': 1525,
#      'ap': 383,
#      'avg': '.293',
#      'gofo': 0.79,
#      'onbase': {'s': 52,
#       'd': 26,
#       't': 0,
#       'hr': 21,
#       'tb': 188,
#       'bb': 39,
#       'ibb': 1,
#       'hbp': 4,
#       'fc': 8,
#       'roe': 4,
#       'h': 99,
#       'cycle': 0},
#      'runs': {'total': 51},
#      'outcome': {'klook': 216,
#       'kswing': 124,
#       'ktotal': 340,
#       'ball': 513,
#       'iball': 3,
#       'dirtball': 23,
#       'foul': 0},
#      'outs': {'po': 23,
#       'fo': 64,
#       'fidp': 0,
#       'lo': 6,
#       'lidp': 0,
#       'go': 74,
#       'gidp': 4,
#       'klook': 14,
#       'kswing': 62,
#       'ktotal': 76,
#       'sacfly': 1,
#       'sachit': 0},
#      'steal': {'caught': 0, 'stolen': 5, 'pct': 1.0, 'pickoff': 0},
#      'games': {'start': 86, 'play': 102, 'finish': 14, 'complete': 62}}},
#    'fielding': {'overall': {'po': 474,
#      'a': 42,
#      'dp': 35,
#      'tp': 0,
#      'error': 1,
#      'tc': 517,
#      'fpct': 0.998,
#      'rf': 5.489,
#      'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#      'errors': {'throwing': 0, 'fielding': 0, 'interference': 0, 'total': 1},
#      'games': {'start': 78, 'play': 94, 'finish': 14, 'complete': 6}}}}},
#  'teams': [{'name': 'Orioles',
#    'market': 'Baltimore',
#    'abbr': 'BAL',
#    'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#    'statistics': {'hitting': {'overall': {'ab': 338,
#       'lob': 117,
#       'rbi': 49,
#       'abhr': 16.095,
#       'abk': 4.447,
#       'bip': 242,
#       'babip': 0.322,
#       'bbk': 0.526,
#       'bbpa': 0.104,
#       'iso': 0.263,
#       'obp': 0.373,
#       'ops': 0.929,
#       'seca': 0.396,
#       'slg': 0.556,
#       'xbh': 47,
#       'pitch_count': 1525,
#       'ap': 383,
#       'avg': '.293',
#       'gofo': 0.79,
#       'onbase': {'s': 52,
#        'd': 26,
#        't': 0,
#        'hr': 21,
#        'tb': 188,
#        'bb': 39,
#        'ibb': 1,
#        'hbp': 4,
#        'fc': 8,
#        'roe': 4,
#        'h': 99,
#        'cycle': 0},
#       'runs': {'total': 51},
#       'outcome': {'klook': 216,
#        'kswing': 124,
#        'ktotal': 340,
#        'ball': 513,
#        'iball': 3,
#        'dirtball': 23,
#        'foul': 0},
#       'outs': {'po': 23,
#        'fo': 64,
#        'fidp': 0,
#        'lo': 6,
#        'lidp': 0,
#        'go': 74,
#        'gidp': 4,
#        'klook': 14,
#        'kswing': 62,
#        'ktotal': 76,
#        'sacfly': 1,
#        'sachit': 0},
#       'steal': {'caught': 0, 'stolen': 5, 'pct': 1.0, 'pickoff': 0},
#       'games': {'start': 86, 'play': 102, 'finish': 14, 'complete': 62}}},
#     'fielding': {'overall': {'po': 474,
#       'a': 42,
#       'dp': 35,
#       'tp': 0,
#       'error': 1,
#       'tc': 517,
#       'fpct': 0.998,
#       'rf': 5.489,
#       'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#       'errors': {'throwing': 0, 'fielding': 0, 'interference': 0, 'total': 1},
#       'games': {'start': 78, 'play': 94, 'finish': 14, 'complete': 6}}}}}]}

# %%
geez[0]['totals']['statistics']['hitting']['overall']['ap']
# Out:
# 99

# %%
geez[0]['totals']['statcast_metrics']['hitting']['overall'][1]['barreled_ball']['count']
# Out:
# 54

# %%
geez[0]['totals']['statcast_metrics']['hitting']['overall'][6]['launch_speed']['max']
# Out:
# 107.32

# %%
import json
import pandas as pd
data = json.load(open('depth_charts.json'))

# %%
data["teams"]
# Out:
# [{'name': 'Blue Jays',
#   'market': 'Toronto',
#   'abbr': 'TOR',
#   'id': '1d678440-b4b1-4954-9b39-70afb3ebbcfa',
#   'positions': [{'name': 'LF',
#     'desc': 'Left Field',
#     'players': [{'id': '20e7bd6e-fb56-4e86-ad2d-b50bc5477371',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Lourdes',
#       'last_name': 'Gurriel Jr.',
#       'preferred_name': 'Lourdes',
#       'jersey_number': '13',
#       'depth': 1},
#      {'id': 'a7d910e1-4815-42b6-9d1e-6af7fa8c3be4',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Santiago',
#       'last_name': 'Espinal',
#       'preferred_name': 'Santiago',
#       'jersey_number': '5',
#       'depth': 2}]},
#    {'name': 'CF',
#     'desc': 'Center Field',
#     'players': [{'id': '5a1ba87b-8ec6-4588-97c8-79db8d044cca',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'CF',
#       'first_name': 'Randal',
#       'last_name': 'Grichuk',
#       'preferred_name': 'Randal',
#       'jersey_number': '15',
#       'depth': 1},
#      {'id': '13385fa8-ec77-44fa-854c-b8c372503b54',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'CF',
#       'first_name': 'Jonathan',
#       'last_name': 'Davis',
#       'preferred_name': 'Jonathan',
#       'jersey_number': '49',
#       'depth': 2},
#      {'id': '88fe9848-7bce-4047-a62f-27f2775a0f5e',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'CF',
#       'first_name': 'Joshua',
#       'last_name': 'Palacios',
#       'preferred_name': 'Josh',
#       'jersey_number': '77',
#       'depth': 3}]},
#    {'name': 'RF',
#     'desc': 'Right Field',
#     'players': [{'id': '19dc4d37-db3d-4289-bf15-4705ddb56d30',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'RF',
#       'first_name': 'Teoscar',
#       'last_name': 'Hernández',
#       'preferred_name': 'Teoscar',
#       'jersey_number': '37',
#       'depth': 1},
#      {'id': 'a0d999b0-5021-4f17-8082-e842e9e63ce4',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Cavan',
#       'last_name': 'Biggio',
#       'preferred_name': 'Cavan',
#       'jersey_number': '8',
#       'depth': 2},
#      {'id': '13385fa8-ec77-44fa-854c-b8c372503b54',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'CF',
#       'first_name': 'Jonathan',
#       'last_name': 'Davis',
#       'preferred_name': 'Jonathan',
#       'jersey_number': '49',
#       'depth': 3}]},
#    {'name': '3B',
#     'desc': 'Third Base',
#     'players': [{'id': 'a9ad5859-6769-4349-bd41-3ea2dcae4c78',
#       'status': 'FA',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Travis',
#       'last_name': 'Shaw',
#       'preferred_name': 'Travis',
#       'depth': 1}]},
#    {'name': 'SS',
#     'desc': 'Shortstop',
#     'players': [{'id': '88344347-d02f-4bb0-ab54-81f26f13e5b1',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': 'SS',
#       'first_name': 'Bo',
#       'last_name': 'Bichette',
#       'preferred_name': 'Bo',
#       'jersey_number': '11',
#       'depth': 1}]},
#    {'name': '2B',
#     'desc': 'Second Base',
#     'players': [{'id': 'a0d999b0-5021-4f17-8082-e842e9e63ce4',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Cavan',
#       'last_name': 'Biggio',
#       'preferred_name': 'Cavan',
#       'jersey_number': '8',
#       'depth': 1},
#      {'id': 'a7d910e1-4815-42b6-9d1e-6af7fa8c3be4',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Santiago',
#       'last_name': 'Espinal',
#       'preferred_name': 'Santiago',
#       'jersey_number': '5',
#       'depth': 2},
#      {'id': '0aa84249-5138-41b3-a086-799cf294bc8a',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Otto',
#       'last_name': 'Lopez',
#       'preferred_name': 'Otto',
#       'depth': 3}]},
#    {'name': '1B',
#     'desc': 'First Base',
#     'players': [{'id': 'fa26a373-a427-4558-ba5e-6d6c0f0148c5',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '1B',
#       'first_name': 'Vladimir',
#       'last_name': 'Guerrero Jr.',
#       'preferred_name': 'Vladimir',
#       'jersey_number': '27',
#       'depth': 1},
#      {'id': '3959d7a0-04fc-4772-b9d2-65f97ec4ccb6',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '1B',
#       'first_name': 'Ryan',
#       'last_name': 'Tellez',
#       'preferred_name': 'Rowdy',
#       'jersey_number': '44',
#       'depth': 2},
#      {'id': 'a9ad5859-6769-4349-bd41-3ea2dcae4c78',
#       'status': 'FA',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Travis',
#       'last_name': 'Shaw',
#       'preferred_name': 'Travis',
#       'depth': 3},
#      {'id': 'a0d999b0-5021-4f17-8082-e842e9e63ce4',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Cavan',
#       'last_name': 'Biggio',
#       'preferred_name': 'Cavan',
#       'jersey_number': '8',
#       'depth': 4}]},
#    {'name': 'SP',
#     'desc': 'Starting Pitcher',
#     'players': [{'id': '01d71849-6f8e-4394-ae98-155bd61c68e8',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Hyun Jin',
#       'last_name': 'Ryu',
#       'preferred_name': 'Hyun Jin',
#       'jersey_number': '99',
#       'depth': 1},
#      {'id': '9deda06b-1928-4c58-acf0-717538f576f4',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Robert',
#       'last_name': 'Ray',
#       'preferred_name': 'Robbie',
#       'depth': 2},
#      {'id': '47fdc2c1-b694-4674-ae7c-5cdf1c96babf',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Anthony',
#       'last_name': 'Castro',
#       'preferred_name': 'Anthony',
#       'depth': 3}]},
#    {'name': 'C',
#     'desc': 'Catcher',
#     'players': [{'id': '8d777ecb-4ab5-4c35-9daa-a1124a200b11',
#       'status': 'A',
#       'position': 'C',
#       'primary_position': 'C',
#       'first_name': 'Daniel',
#       'last_name': 'Jansen',
#       'preferred_name': 'Danny',
#       'jersey_number': '9',
#       'depth': 1},
#      {'id': '717333c5-59e0-41f4-a1d9-dd58ad2661ef',
#       'status': 'A',
#       'position': 'C',
#       'primary_position': 'C',
#       'first_name': 'Alejandro',
#       'last_name': 'Kirk',
#       'preferred_name': 'Alejandro',
#       'jersey_number': '85',
#       'depth': 2},
#      {'id': 'a7f1b8e8-1040-4b51-9eb9-ef3ede3ea8bd',
#       'status': 'A',
#       'position': 'C',
#       'primary_position': 'C',
#       'first_name': 'Reese',
#       'last_name': 'McGuire',
#       'preferred_name': 'Reese',
#       'jersey_number': '10',
#       'depth': 3},
#      {'id': '3f65cd94-9f29-4dbf-b7f6-4d8aa51d05a2',
#       'status': 'A',
#       'position': 'C',
#       'primary_position': 'C',
#       'first_name': 'Riley',
#       'last_name': 'Adams',
#       'preferred_name': 'Riley',
#       'jersey_number': '76',
#       'depth': 4},
#      {'id': '47bbd747-6edc-4d0e-a976-5228f5003fbd',
#       'status': 'A',
#       'position': 'C',
#       'primary_position': 'C',
#       'first_name': 'Gabriel',
#       'last_name': 'Moreno',
#       'preferred_name': 'Gabriel',
#       'depth': 5}]},
#    {'name': 'DH',
#     'desc': 'Designated Hitter',
#     'players': [{'id': '3959d7a0-04fc-4772-b9d2-65f97ec4ccb6',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '1B',
#       'first_name': 'Ryan',
#       'last_name': 'Tellez',
#       'preferred_name': 'Rowdy',
#       'jersey_number': '44',
#       'depth': 1},
#      {'id': 'fa26a373-a427-4558-ba5e-6d6c0f0148c5',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '1B',
#       'first_name': 'Vladimir',
#       'last_name': 'Guerrero Jr.',
#       'preferred_name': 'Vladimir',
#       'jersey_number': '27',
#       'depth': 2},
#      {'id': '19dc4d37-db3d-4289-bf15-4705ddb56d30',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'RF',
#       'first_name': 'Teoscar',
#       'last_name': 'Hernández',
#       'preferred_name': 'Teoscar',
#       'jersey_number': '37',
#       'depth': 3},
#      {'id': '717333c5-59e0-41f4-a1d9-dd58ad2661ef',
#       'status': 'A',
#       'position': 'C',
#       'primary_position': 'C',
#       'first_name': 'Alejandro',
#       'last_name': 'Kirk',
#       'preferred_name': 'Alejandro',
#       'jersey_number': '85',
#       'depth': 4}]},
#    {'name': 'BP',
#     'desc': 'Bullpen',
#     'players': [{'id': 'f15abf11-e9c6-4f90-a16d-59a14176dff3',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Nathan',
#       'last_name': 'Pearson',
#       'preferred_name': 'Nate',
#       'jersey_number': '24',
#       'depth': 1},
#      {'id': 'bc359d03-e510-4c24-acc2-d2964bb36693',
#       'status': 'NRI',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Andrew',
#       'last_name': 'Cole',
#       'preferred_name': 'A.J.',
#       'depth': 2},
#      {'id': '2945b9fb-77ed-4e60-a63d-0c4eb2feb458',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Ryan',
#       'last_name': 'Borucki',
#       'preferred_name': 'Ryan',
#       'jersey_number': '56',
#       'depth': 3},
#      {'id': 'b2fdb7e8-a700-408c-b238-a077165c4745',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Thomas',
#       'last_name': 'Stripling',
#       'preferred_name': 'Ross',
#       'jersey_number': '48',
#       'depth': 4},
#      {'id': '38fe7a7d-c990-4440-ad2a-6b7c60a98ae6',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Thomas',
#       'last_name': 'Hatch',
#       'preferred_name': 'Tom',
#       'jersey_number': '31',
#       'depth': 5},
#      {'id': '6de93a68-31cd-4278-b933-e43cbcee5d98',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Anthony',
#       'last_name': 'Kay',
#       'preferred_name': 'Anthony',
#       'jersey_number': '47',
#       'depth': 6},
#      {'id': '1d22a1ac-b954-49c8-bed8-eb868078bcc0',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Ty',
#       'last_name': 'Tice',
#       'preferred_name': 'Ty',
#       'jersey_number': '73',
#       'depth': 7}]},
#    {'name': 'CL',
#     'desc': 'Closer',
#     'players': [{'id': 'e7081cad-4d39-4805-82f6-ae0d933ac0fb',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Rafael',
#       'last_name': 'Dolis',
#       'preferred_name': 'Rafael',
#       'jersey_number': '41',
#       'depth': 1}]}]},
#  {'name': 'Rays',
#   'market': 'Tampa Bay',
#   'abbr': 'TB',
#   'id': 'bdc11650-6f74-49c4-875e-778aeb7632d9',
#   'positions': [{'name': 'LF',
#     'desc': 'Left Field',
#     'players': [{'id': '7057e7fa-6d96-451e-9546-2e43d5e116d6',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Randy',
#       'last_name': 'Arozarena',
#       'preferred_name': 'Randy',
#       'jersey_number': '56',
#       'depth': 1},
#      {'id': '0b34eac2-fe40-49b6-b6ae-89826d8059da',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Yoshitomo',
#       'last_name': 'Tsutsugo',
#       'preferred_name': 'Yoshi',
#       'jersey_number': '25',
#       'depth': 2},
#      {'id': 'ca0f384f-9c57-43eb-89dc-dd8797fcb0ca',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'RF',
#       'first_name': 'Austin',
#       'last_name': 'Meadows',
#       'preferred_name': 'Austin',
#       'jersey_number': '17',
#       'depth': 3},
#      {'id': 'cafd29c0-91ac-4472-819c-c6dfb04bad71',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Brandon',
#       'last_name': 'Lowe',
#       'preferred_name': 'Brandon',
#       'jersey_number': '8',
#       'depth': 4}]},
#    {'name': 'CF',
#     'desc': 'Center Field',
#     'players': [{'id': '908cf3f8-d7a4-4346-b39e-1f4f66a21864',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'CF',
#       'first_name': 'Kevin',
#       'last_name': 'Kiermaier',
#       'preferred_name': 'Kevin',
#       'jersey_number': '39',
#       'depth': 1},
#      {'id': 'bffe5dfd-13f9-457c-a5f8-4ac8c2009ebd',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'RF',
#       'first_name': 'Manuel',
#       'last_name': 'Margot',
#       'preferred_name': 'Manuel',
#       'jersey_number': '13',
#       'depth': 2},
#      {'id': '1ec2eeb7-01f2-428d-a9bf-8ffb9178759f',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'CF',
#       'first_name': 'Brett',
#       'last_name': 'Phillips',
#       'preferred_name': 'Brett',
#       'jersey_number': '14',
#       'depth': 3}]},
#    {'name': 'RF',
#     'desc': 'Right Field',
#     'players': [{'id': 'bffe5dfd-13f9-457c-a5f8-4ac8c2009ebd',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'RF',
#       'first_name': 'Manuel',
#       'last_name': 'Margot',
#       'preferred_name': 'Manuel',
#       'jersey_number': '13',
#       'depth': 1},
#      {'id': 'ca0f384f-9c57-43eb-89dc-dd8797fcb0ca',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'RF',
#       'first_name': 'Austin',
#       'last_name': 'Meadows',
#       'preferred_name': 'Austin',
#       'jersey_number': '17',
#       'depth': 2},
#      {'id': '7057e7fa-6d96-451e-9546-2e43d5e116d6',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Randy',
#       'last_name': 'Arozarena',
#       'preferred_name': 'Randy',
#       'jersey_number': '56',
#       'depth': 3}]},
#    {'name': '3B',
#     'desc': 'Third Base',
#     'players': [{'id': '9550b18e-bb43-4c41-bac6-1d242f29ca41',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Joseph',
#       'last_name': 'Wendle',
#       'preferred_name': 'Joey',
#       'jersey_number': '18',
#       'depth': 1},
#      {'id': '0b34eac2-fe40-49b6-b6ae-89826d8059da',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Yoshitomo',
#       'last_name': 'Tsutsugo',
#       'preferred_name': 'Yoshi',
#       'jersey_number': '25',
#       'depth': 2},
#      {'id': 'd44ce1a2-abea-46d1-a2cc-950c27983aba',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Michael',
#       'last_name': 'Brosseau',
#       'preferred_name': 'Mike',
#       'jersey_number': '43',
#       'depth': 3}]},
#    {'name': 'SS',
#     'desc': 'Shortstop',
#     'players': [{'id': '81af51ef-1387-495a-bef2-57f219415370',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': 'SS',
#       'first_name': 'Willy',
#       'last_name': 'Adames',
#       'preferred_name': 'Willy',
#       'jersey_number': '1',
#       'depth': 1},
#      {'id': '9550b18e-bb43-4c41-bac6-1d242f29ca41',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Joseph',
#       'last_name': 'Wendle',
#       'preferred_name': 'Joey',
#       'jersey_number': '18',
#       'depth': 2}]},
#    {'name': '2B',
#     'desc': 'Second Base',
#     'players': [{'id': 'cafd29c0-91ac-4472-819c-c6dfb04bad71',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Brandon',
#       'last_name': 'Lowe',
#       'preferred_name': 'Brandon',
#       'jersey_number': '8',
#       'depth': 1},
#      {'id': '9550b18e-bb43-4c41-bac6-1d242f29ca41',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Joseph',
#       'last_name': 'Wendle',
#       'preferred_name': 'Joey',
#       'jersey_number': '18',
#       'depth': 2},
#      {'id': 'd44ce1a2-abea-46d1-a2cc-950c27983aba',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Michael',
#       'last_name': 'Brosseau',
#       'preferred_name': 'Mike',
#       'jersey_number': '43',
#       'depth': 3}]},
#    {'name': '1B',
#     'desc': 'First Base',
#     'players': [{'id': '116ddf3b-e590-429f-a7c0-3493f83a5b87',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '1B',
#       'first_name': 'Ji-Man',
#       'last_name': 'Choi',
#       'preferred_name': 'Ji-Man',
#       'jersey_number': '26',
#       'depth': 1},
#      {'id': 'c91b7458-14bf-4a62-b147-c47ad2f19396',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Yandy',
#       'last_name': 'Díaz',
#       'preferred_name': 'Yandy',
#       'jersey_number': '2',
#       'depth': 2},
#      {'id': 'd44ce1a2-abea-46d1-a2cc-950c27983aba',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Michael',
#       'last_name': 'Brosseau',
#       'preferred_name': 'Mike',
#       'jersey_number': '43',
#       'depth': 3}]},
#    {'name': 'SP',
#     'desc': 'Starting Pitcher',
#     'players': [{'id': '81125861-72f8-461c-b7c2-46fc460a7115',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Tyler',
#       'last_name': 'Glasnow',
#       'preferred_name': 'Tyler',
#       'jersey_number': '20',
#       'depth': 1},
#      {'id': 'dae38ebc-f1dc-4b47-a8b6-9bee0fc2a2dd',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Ryan',
#       'last_name': 'Yarbrough',
#       'preferred_name': 'Ryan',
#       'jersey_number': '48',
#       'depth': 2},
#      {'id': 'db6ced3d-7838-4a7c-92a5-50d0b63dac3b',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Michael',
#       'last_name': 'Wacha',
#       'preferred_name': 'Michael',
#       'depth': 3},
#      {'id': 'fb58e481-089f-44e5-abd4-f66646b3811a',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Josh',
#       'last_name': 'Fleming',
#       'preferred_name': 'Josh',
#       'jersey_number': '61',
#       'depth': 4}]},
#    {'name': 'C',
#     'desc': 'Catcher',
#     'players': [{'id': 'a2c6cf2d-e796-4b45-900d-7db1bd6d39f7',
#       'status': 'A',
#       'position': 'C',
#       'primary_position': 'C',
#       'first_name': 'Michael',
#       'last_name': 'Zunino',
#       'preferred_name': 'Mike',
#       'jersey_number': '10',
#       'depth': 1},
#      {'id': '00d70364-1c07-464f-bd34-f571f7d7ae10',
#       'status': 'A',
#       'position': 'C',
#       'primary_position': 'C',
#       'first_name': 'Ronaldo',
#       'last_name': 'Hernández',
#       'preferred_name': 'Ronaldo',
#       'jersey_number': '55',
#       'depth': 2},
#      {'id': '7d494bf9-a3ce-4e7c-a122-bc8e8c13c87b',
#       'status': 'A',
#       'position': 'C',
#       'primary_position': 'C',
#       'first_name': 'Francisco',
#       'last_name': 'Mejía',
#       'preferred_name': 'Francisco',
#       'depth': 3}]},
#    {'name': 'DH',
#     'desc': 'Designated Hitter',
#     'players': [{'id': 'ca0f384f-9c57-43eb-89dc-dd8797fcb0ca',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'RF',
#       'first_name': 'Austin',
#       'last_name': 'Meadows',
#       'preferred_name': 'Austin',
#       'jersey_number': '17',
#       'depth': 1},
#      {'id': '0b34eac2-fe40-49b6-b6ae-89826d8059da',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Yoshitomo',
#       'last_name': 'Tsutsugo',
#       'preferred_name': 'Yoshi',
#       'jersey_number': '25',
#       'depth': 2},
#      {'id': '116ddf3b-e590-429f-a7c0-3493f83a5b87',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '1B',
#       'first_name': 'Ji-Man',
#       'last_name': 'Choi',
#       'preferred_name': 'Ji-Man',
#       'jersey_number': '26',
#       'depth': 3}]},
#    {'name': 'BP',
#     'desc': 'Bullpen',
#     'players': [{'id': '276cbbde-fb0e-43ff-99be-355a6ebb531c',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Peter',
#       'last_name': 'Fairbanks',
#       'preferred_name': 'Pete',
#       'jersey_number': '29',
#       'depth': 1},
#      {'id': '780e8c91-53d2-4d3a-ae24-ac7a7717e01e',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Nick',
#       'last_name': 'Anderson',
#       'preferred_name': 'Nick',
#       'jersey_number': '70',
#       'depth': 2},
#      {'id': '80411944-bd62-46cf-8794-06a837b1c21c',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Diego',
#       'last_name': 'Castillo',
#       'preferred_name': 'Diego',
#       'jersey_number': '63',
#       'depth': 3},
#      {'id': '05b5805b-3b4e-40f6-982b-03081465c961',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Ryan',
#       'last_name': 'Thompson',
#       'preferred_name': 'Ryan',
#       'jersey_number': '81',
#       'depth': 4},
#      {'id': '97f72e12-2dab-4976-87bf-377f4b3be400',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'John',
#       'last_name': 'Curtiss',
#       'preferred_name': 'John',
#       'jersey_number': '84',
#       'depth': 5},
#      {'id': '9babdf5b-fa9c-4169-b9af-4d8b8dff93a0',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Cody',
#       'last_name': 'Reed',
#       'preferred_name': 'Cody',
#       'jersey_number': '21',
#       'depth': 6},
#      {'id': '71948aff-effa-49e9-a040-396bc6b22f31',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Trevor',
#       'last_name': 'Richards',
#       'preferred_name': 'Trevor',
#       'jersey_number': '34',
#       'depth': 7}]},
#    {'name': 'CL', 'desc': 'Closer'}]},
#  {'name': 'Orioles',
#   'market': 'Baltimore',
#   'abbr': 'BAL',
#   'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#   'positions': [{'name': 'LF',
#     'desc': 'Left Field',
#     'players': [{'id': '0f626ddc-1c79-43af-9407-12aa1381d420',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Austin',
#       'last_name': 'Hays',
#       'preferred_name': 'Austin',
#       'jersey_number': '21',
#       'depth': 1},
#      {'id': '135505bb-4541-4ca6-8d2e-80febcf830bd',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Patrick',
#       'last_name': 'Valaika',
#       'preferred_name': 'Pat',
#       'jersey_number': '74',
#       'depth': 2},
#      {'id': '96600e21-d075-440d-8762-5d48a466b053',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'RF',
#       'first_name': 'Demetrius',
#       'last_name': 'Stewart',
#       'preferred_name': 'DJ',
#       'jersey_number': '24',
#       'depth': 3}]},
#    {'name': 'CF',
#     'desc': 'Center Field',
#     'players': [{'id': 'faf93f6f-b60e-4c9e-a83f-5ba8b0aca02c',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'CF',
#       'first_name': 'Boyce',
#       'last_name': 'Mullins',
#       'preferred_name': 'Cedric',
#       'jersey_number': '31',
#       'depth': 1},
#      {'id': '0f626ddc-1c79-43af-9407-12aa1381d420',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Austin',
#       'last_name': 'Hays',
#       'preferred_name': 'Austin',
#       'jersey_number': '21',
#       'depth': 2},
#      {'id': 'b93bec13-df83-4d67-98f6-81d2b4d4da1f',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'CF',
#       'first_name': 'Yusniel',
#       'last_name': 'Diaz',
#       'preferred_name': 'Yusniel',
#       'jersey_number': '80',
#       'depth': 3}]},
#    {'name': 'RF',
#     'desc': 'Right Field',
#     'players': [{'id': 'e26d31f5-1199-4edf-a154-a8ed209ac971',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'RF',
#       'first_name': 'Joseph',
#       'last_name': 'Mancini',
#       'preferred_name': 'Trey',
#       'jersey_number': '16',
#       'depth': 1},
#      {'id': '96600e21-d075-440d-8762-5d48a466b053',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'RF',
#       'first_name': 'Demetrius',
#       'last_name': 'Stewart',
#       'preferred_name': 'DJ',
#       'jersey_number': '24',
#       'depth': 2},
#      {'id': 'd4bc8879-c7dc-430f-bcb8-e932b21a2e7c',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'RF',
#       'first_name': 'Anthony',
#       'last_name': 'Santander',
#       'preferred_name': 'Anthony',
#       'jersey_number': '25',
#       'depth': 3},
#      {'id': '135505bb-4541-4ca6-8d2e-80febcf830bd',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Patrick',
#       'last_name': 'Valaika',
#       'preferred_name': 'Pat',
#       'jersey_number': '74',
#       'depth': 4}]},
#    {'name': '3B',
#     'desc': 'Third Base',
#     'players': [{'id': 'b42351bd-4834-47f0-bc95-612eb5fa9669',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Rio',
#       'last_name': 'Ruiz',
#       'preferred_name': 'Rio',
#       'jersey_number': '14',
#       'depth': 1},
#      {'id': '17c0c208-3c37-4553-b37f-a99ba885a206',
#       'status': 'FA',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Hanser',
#       'last_name': 'Alberto',
#       'preferred_name': 'Hanser',
#       'depth': 2},
#      {'id': 'f4923e5e-7d80-4d32-b226-c1d67345a270',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Rylan',
#       'last_name': 'Bannon',
#       'preferred_name': 'Rylan',
#       'depth': 3}]},
#    {'name': 'SS',
#     'desc': 'Shortstop',
#     'players': [{'id': 'cf9815a7-220b-45f9-bbdf-9c6c8b792154',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': 'SS',
#       'first_name': 'José',
#       'last_name': 'Iglesias',
#       'preferred_name': 'José',
#       'jersey_number': '4',
#       'depth': 1},
#      {'id': '2412a017-f7ec-4b7b-a19f-e441554cf49a',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': 'SS',
#       'first_name': 'Richard',
#       'last_name': 'Martin',
#       'preferred_name': 'Richie',
#       'jersey_number': '1',
#       'depth': 2},
#      {'id': '135505bb-4541-4ca6-8d2e-80febcf830bd',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Patrick',
#       'last_name': 'Valaika',
#       'preferred_name': 'Pat',
#       'jersey_number': '74',
#       'depth': 3},
#      {'id': '0672f3d5-5781-47bb-b111-abec96c38355',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Ramón',
#       'last_name': 'Urías',
#       'preferred_name': 'Ramón',
#       'jersey_number': '87',
#       'depth': 4}]},
#    {'name': '2B',
#     'desc': 'Second Base',
#     'players': [{'id': '17c0c208-3c37-4553-b37f-a99ba885a206',
#       'status': 'FA',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Hanser',
#       'last_name': 'Alberto',
#       'preferred_name': 'Hanser',
#       'depth': 1},
#      {'id': '135505bb-4541-4ca6-8d2e-80febcf830bd',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Patrick',
#       'last_name': 'Valaika',
#       'preferred_name': 'Pat',
#       'jersey_number': '74',
#       'depth': 2},
#      {'id': '0672f3d5-5781-47bb-b111-abec96c38355',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Ramón',
#       'last_name': 'Urías',
#       'preferred_name': 'Ramón',
#       'jersey_number': '87',
#       'depth': 3}]},
#    {'name': '1B',
#     'desc': 'First Base',
#     'players': [{'id': '9fc34f7c-7d68-4d82-9460-0b12f3e728b5',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Ryan',
#       'last_name': 'Mountcastle',
#       'preferred_name': 'Ryan',
#       'jersey_number': '6',
#       'depth': 1},
#      {'id': 'ddfbc667-95d8-49fc-8e77-a8e4e452d820',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '1B',
#       'first_name': 'Christopher',
#       'last_name': 'Davis',
#       'preferred_name': 'Chris',
#       'jersey_number': '19',
#       'depth': 2},
#      {'id': '135505bb-4541-4ca6-8d2e-80febcf830bd',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Patrick',
#       'last_name': 'Valaika',
#       'preferred_name': 'Pat',
#       'jersey_number': '74',
#       'depth': 3}]},
#    {'name': 'SP',
#     'desc': 'Starting Pitcher',
#     'players': [{'id': 'd2c5e643-fe5d-4ece-8f1e-560d6b2048ed',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Alexander',
#       'last_name': 'Cobb',
#       'preferred_name': 'Alex',
#       'jersey_number': '17',
#       'depth': 1},
#      {'id': 'b9766398-e982-43a6-a3a0-f7f8e24061c6',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Jorge',
#       'last_name': 'López',
#       'preferred_name': 'Jorge',
#       'jersey_number': '48',
#       'depth': 2},
#      {'id': 'd6c41179-8aef-407c-843d-225a397935f0',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'John',
#       'last_name': 'Means',
#       'preferred_name': 'John',
#       'jersey_number': '47',
#       'depth': 3},
#      {'id': '7960a26a-3ee0-4c7a-bc10-585cf71b02a5',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Keegan',
#       'last_name': 'Akin',
#       'preferred_name': 'Keegan',
#       'jersey_number': '45',
#       'depth': 4},
#      {'id': 'b289c3a7-e653-4fa1-931f-733d1a8ba26c',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Michael',
#       'last_name': 'Baumann',
#       'preferred_name': 'Michael',
#       'jersey_number': '0',
#       'depth': 5},
#      {'id': '11c4591d-a21d-45b9-8e3a-cbba1d633646',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Zacary',
#       'last_name': 'Lowther',
#       'preferred_name': 'Zac',
#       'depth': 6},
#      {'id': '29ab0dc1-7fa9-4fd2-920c-d88fd00edb48',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Alexander',
#       'last_name': 'Wells',
#       'preferred_name': 'Alexander',
#       'depth': 7}]},
#    {'name': 'C',
#     'desc': 'Catcher',
#     'players': [{'id': 'a68b7a2e-0eae-4ab1-ba02-ee1c9cca5850',
#       'status': 'A',
#       'position': 'C',
#       'primary_position': 'C',
#       'first_name': 'Pedro',
#       'last_name': 'Severino',
#       'preferred_name': 'Pedro',
#       'jersey_number': '28',
#       'depth': 1},
#      {'id': 'a370e82a-6bdd-438b-9c20-89fbffa80050',
#       'status': 'A',
#       'position': 'C',
#       'primary_position': 'C',
#       'first_name': 'Chance',
#       'last_name': 'Sisco',
#       'preferred_name': 'Chance',
#       'jersey_number': '15',
#       'depth': 2}]},
#    {'name': 'DH',
#     'desc': 'Designated Hitter',
#     'players': [{'id': '9fc34f7c-7d68-4d82-9460-0b12f3e728b5',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Ryan',
#       'last_name': 'Mountcastle',
#       'preferred_name': 'Ryan',
#       'jersey_number': '6',
#       'depth': 1},
#      {'id': 'a370e82a-6bdd-438b-9c20-89fbffa80050',
#       'status': 'A',
#       'position': 'C',
#       'primary_position': 'C',
#       'first_name': 'Chance',
#       'last_name': 'Sisco',
#       'preferred_name': 'Chance',
#       'jersey_number': '15',
#       'depth': 2}]},
#    {'name': 'BP',
#     'desc': 'Bullpen',
#     'players': [{'id': '9e883466-7d2d-45a0-a509-44c14aeff967',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Tanner',
#       'last_name': 'Scott',
#       'preferred_name': 'Tanner',
#       'jersey_number': '66',
#       'depth': 1},
#      {'id': '0daadfb1-9f92-4ecf-87c4-bbfc0a232e6c',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Hunter',
#       'last_name': 'Harvey',
#       'preferred_name': 'Hunter',
#       'jersey_number': '56',
#       'depth': 2},
#      {'id': '4925447b-7d3f-43c0-8092-6c0d54cef288',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Travis',
#       'last_name': 'Lakins Sr.',
#       'preferred_name': 'Travis',
#       'jersey_number': '70',
#       'depth': 3},
#      {'id': '9ceccdf6-6eb7-464e-bc7d-3eaa49cbcbe2',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Paul',
#       'last_name': 'Fry',
#       'preferred_name': 'Paul',
#       'jersey_number': '51',
#       'depth': 4},
#      {'id': '636653db-659f-46b4-a672-fcc478fc5be5',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Shawn',
#       'last_name': 'Armstrong',
#       'preferred_name': 'Shawn',
#       'jersey_number': '43',
#       'depth': 5},
#      {'id': 'e7fbf15a-c6d6-4d32-b191-bbafc25bb8a4',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Cole',
#       'last_name': 'Sulser',
#       'preferred_name': 'Cole',
#       'jersey_number': '54',
#       'depth': 6},
#      {'id': 'd954e80f-b7c3-46a6-b75c-15038552c138',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Bruce',
#       'last_name': 'Zimmermann',
#       'preferred_name': 'Bruce',
#       'jersey_number': '85',
#       'depth': 7},
#      {'id': 'a845cf84-1aa5-43f1-a25d-21c98bbfde3a',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Isaac',
#       'last_name': 'Mattson',
#       'preferred_name': 'Isaac',
#       'jersey_number': '0',
#       'depth': 8}]},
#    {'name': 'CL',
#     'desc': 'Closer',
#     'players': [{'id': 'd5dc9502-ff51-4345-b714-0c0b6636ae08',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Cesar',
#       'last_name': 'Valdez',
#       'preferred_name': 'Cesar',
#       'jersey_number': '62',
#       'depth': 1}]}]},
#  {'name': 'Red Sox',
#   'market': 'Boston',
#   'abbr': 'BOS',
#   'id': '93941372-eb4c-4c40-aced-fe3267174393',
#   'positions': [{'name': 'LF',
#     'desc': 'Left Field',
#     'players': [{'id': '0e5244cd-9226-4ee1-bb63-d022a9240ca0',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Andrew',
#       'last_name': 'Benintendi',
#       'preferred_name': 'Andrew',
#       'jersey_number': '16',
#       'depth': 1},
#      {'id': '6f7a2f3c-0341-47be-a60a-f6c15d7a9a0b',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'CF',
#       'first_name': 'Alex',
#       'last_name': 'Verdugo',
#       'preferred_name': 'Alex',
#       'jersey_number': '99',
#       'depth': 2},
#      {'id': 'f423faea-d0e3-49b6-b347-52ec5cfac66a',
#       'status': 'A',
#       'position': 'DH',
#       'primary_position': 'DH',
#       'first_name': 'Julio',
#       'last_name': 'Martinez',
#       'preferred_name': 'J.D.',
#       'jersey_number': '28',
#       'depth': 3},
#      {'id': '0199150d-29c1-49d2-bb85-027921a33c8e',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Michael',
#       'last_name': 'Chavis',
#       'preferred_name': 'Michael',
#       'jersey_number': '23',
#       'depth': 4}]},
#    {'name': 'CF',
#     'desc': 'Center Field',
#     'players': [{'id': '6f7a2f3c-0341-47be-a60a-f6c15d7a9a0b',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'CF',
#       'first_name': 'Alex',
#       'last_name': 'Verdugo',
#       'preferred_name': 'Alex',
#       'jersey_number': '99',
#       'depth': 1},
#      {'id': '8279fb7a-866f-4c8f-8a4d-f55d81202185',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'CF',
#       'first_name': 'Jeisson',
#       'last_name': 'Rosario',
#       'preferred_name': 'Jeisson',
#       'depth': 2}]},
#    {'name': 'RF',
#     'desc': 'Right Field',
#     'players': [{'id': '89bab4bd-0fb6-41a6-88d6-0fd6307ae072',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'RF',
#       'first_name': 'Dustin',
#       'last_name': 'Renfroe',
#       'preferred_name': 'Hunter',
#       'depth': 1},
#      {'id': '6f7a2f3c-0341-47be-a60a-f6c15d7a9a0b',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'CF',
#       'first_name': 'Alex',
#       'last_name': 'Verdugo',
#       'preferred_name': 'Alex',
#       'jersey_number': '99',
#       'depth': 2},
#      {'id': 'f423faea-d0e3-49b6-b347-52ec5cfac66a',
#       'status': 'A',
#       'position': 'DH',
#       'primary_position': 'DH',
#       'first_name': 'Julio',
#       'last_name': 'Martinez',
#       'preferred_name': 'J.D.',
#       'jersey_number': '28',
#       'depth': 3}]},
#    {'name': '3B',
#     'desc': 'Third Base',
#     'players': [{'id': 'fe966998-15e1-4022-89d5-6b4750516176',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Rafael',
#       'last_name': 'Devers',
#       'preferred_name': 'Rafael',
#       'jersey_number': '11',
#       'depth': 1},
#      {'id': 'ac760643-fe40-475e-8cf0-5b7faa47c5a1',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '1B',
#       'first_name': 'Robert',
#       'last_name': 'Dalbec',
#       'preferred_name': 'Bobby',
#       'jersey_number': '29',
#       'depth': 2},
#      {'id': '5fe17998-9821-41ca-af92-2f78ab89ac61',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': 'SS',
#       'first_name': 'Jonathan',
#       'last_name': 'Araúz',
#       'preferred_name': 'Jonathan',
#       'jersey_number': '36',
#       'depth': 3},
#      {'id': '0199150d-29c1-49d2-bb85-027921a33c8e',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Michael',
#       'last_name': 'Chavis',
#       'preferred_name': 'Michael',
#       'jersey_number': '23',
#       'depth': 4}]},
#    {'name': 'SS',
#     'desc': 'Shortstop',
#     'players': [{'id': '272abdba-ae99-4137-a6dd-5615f234adfc',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': 'SS',
#       'first_name': 'Xander',
#       'last_name': 'Bogaerts',
#       'preferred_name': 'Xander',
#       'jersey_number': '2',
#       'depth': 1},
#      {'id': '5fe17998-9821-41ca-af92-2f78ab89ac61',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': 'SS',
#       'first_name': 'Jonathan',
#       'last_name': 'Araúz',
#       'preferred_name': 'Jonathan',
#       'jersey_number': '36',
#       'depth': 2}]},
#    {'name': '2B',
#     'desc': 'Second Base',
#     'players': [{'id': '1d6fc3c6-7172-4189-bf35-dfafd17e37e6',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Christian',
#       'last_name': 'Arroyo',
#       'preferred_name': 'Christian',
#       'jersey_number': '39',
#       'depth': 1},
#      {'id': '0199150d-29c1-49d2-bb85-027921a33c8e',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Michael',
#       'last_name': 'Chavis',
#       'preferred_name': 'Michael',
#       'jersey_number': '23',
#       'depth': 2},
#      {'id': '40085c05-fa06-4eec-9f41-f0245980f6a0',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Dustin',
#       'last_name': 'Pedroia',
#       'preferred_name': 'Dustin',
#       'jersey_number': '15',
#       'depth': 3}]},
#    {'name': '1B',
#     'desc': 'First Base',
#     'players': [{'id': 'ac760643-fe40-475e-8cf0-5b7faa47c5a1',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '1B',
#       'first_name': 'Robert',
#       'last_name': 'Dalbec',
#       'preferred_name': 'Bobby',
#       'jersey_number': '29',
#       'depth': 1},
#      {'id': '0199150d-29c1-49d2-bb85-027921a33c8e',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Michael',
#       'last_name': 'Chavis',
#       'preferred_name': 'Michael',
#       'jersey_number': '23',
#       'depth': 2}]},
#    {'name': 'SP',
#     'desc': 'Starting Pitcher',
#     'players': [{'id': '6dd571bc-b26c-4efc-87da-7b501c96faf1',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Nathan',
#       'last_name': 'Eovaldi',
#       'preferred_name': 'Nathan',
#       'jersey_number': '17',
#       'depth': 1},
#      {'id': '66c43b7f-760a-446c-9f50-671915570227',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Christopher',
#       'last_name': 'Sale',
#       'preferred_name': 'Chris',
#       'jersey_number': '41',
#       'depth': 2},
#      {'id': '93413a68-2c05-405a-a38c-9ee983b36913',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Eduardo',
#       'last_name': 'Rodríguez',
#       'preferred_name': 'Eduardo',
#       'jersey_number': '57',
#       'depth': 3},
#      {'id': '1b0ad742-0bc5-49b0-abe0-005e8581b1d3',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Tanner',
#       'last_name': 'Houck',
#       'preferred_name': 'Tanner',
#       'jersey_number': '89',
#       'depth': 4},
#      {'id': 'd49a253f-518e-4a86-9dcf-c91497c29d92',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Nicholas',
#       'last_name': 'Pivetta',
#       'preferred_name': 'Nick',
#       'jersey_number': '37',
#       'depth': 5},
#      {'id': '24322a1d-4b4b-4c18-9ef4-1bdefe6abae8',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Chris',
#       'last_name': 'Mazza',
#       'preferred_name': 'Chris',
#       'jersey_number': '22',
#       'depth': 6}]},
#    {'name': 'C',
#     'desc': 'Catcher',
#     'players': [{'id': '0d7a27a9-f41c-4fce-930e-113aa4cf4c52',
#       'status': 'A',
#       'position': 'C',
#       'primary_position': 'C',
#       'first_name': 'Christian',
#       'last_name': 'Vázquez',
#       'preferred_name': 'Christian',
#       'jersey_number': '7',
#       'depth': 1},
#      {'id': 'b1f6fc22-f38e-4d77-a7e7-6a2ffdcf77f2',
#       'status': 'A',
#       'position': 'C',
#       'primary_position': 'C',
#       'first_name': 'Kevin',
#       'last_name': 'Plawecki',
#       'preferred_name': 'Kevin',
#       'jersey_number': '25',
#       'depth': 2}]},
#    {'name': 'DH',
#     'desc': 'Designated Hitter',
#     'players': [{'id': 'f423faea-d0e3-49b6-b347-52ec5cfac66a',
#       'status': 'A',
#       'position': 'DH',
#       'primary_position': 'DH',
#       'first_name': 'Julio',
#       'last_name': 'Martinez',
#       'preferred_name': 'J.D.',
#       'jersey_number': '28',
#       'depth': 1},
#      {'id': '6f7a2f3c-0341-47be-a60a-f6c15d7a9a0b',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'CF',
#       'first_name': 'Alex',
#       'last_name': 'Verdugo',
#       'preferred_name': 'Alex',
#       'jersey_number': '99',
#       'depth': 2}]},
#    {'name': 'BP',
#     'desc': 'Bullpen',
#     'players': [{'id': '6426ad53-44d1-4ae9-b14c-b068106f5949',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Ryan',
#       'last_name': 'Brasier',
#       'preferred_name': 'Ryan',
#       'jersey_number': '70',
#       'depth': 1},
#      {'id': '65cf79ea-c3bf-409a-8b86-a5e334a186dc',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Phillips',
#       'last_name': 'Valdez',
#       'preferred_name': 'Phillips',
#       'jersey_number': '71',
#       'depth': 2},
#      {'id': '29311663-0a56-451d-a9fa-7c8ff207013c',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Darwinzon',
#       'last_name': 'Hernandez',
#       'preferred_name': 'Darwinzon',
#       'jersey_number': '63',
#       'depth': 3},
#      {'id': '58831505-e236-4871-9f20-1e9d8bb0fa60',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Austin',
#       'last_name': 'Brice',
#       'preferred_name': 'Austin',
#       'jersey_number': '31',
#       'depth': 4},
#      {'id': 'ad2422c3-0323-4ac1-b1cf-ddc109c1747b',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Matthew',
#       'last_name': 'Andriese',
#       'preferred_name': 'Matt',
#       'depth': 5},
#      {'id': 'b25f0afc-4671-43a9-90e0-61bd7bd08604',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Josh',
#       'last_name': 'Taylor',
#       'preferred_name': 'Josh',
#       'jersey_number': '72',
#       'depth': 6},
#      {'id': 'e2bb2600-ed84-4223-b829-cacddcbfa193',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Colten',
#       'last_name': 'Brewer',
#       'preferred_name': 'Colten',
#       'jersey_number': '48',
#       'depth': 7},
#      {'id': '61bc96e6-dbb3-4dc0-972d-0c85d49f37ca',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Garrett',
#       'last_name': 'Whitlock',
#       'preferred_name': 'Garrett',
#       'depth': 8}]},
#    {'name': 'CL',
#     'desc': 'Closer',
#     'players': [{'id': 'db6334d5-f34a-4db9-8e6b-5cb843617550',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Matthew',
#       'last_name': 'Barnes',
#       'preferred_name': 'Matt',
#       'jersey_number': '32',
#       'depth': 1}]}]},
#  {'name': 'Yankees',
#   'market': 'New York',
#   'abbr': 'NYY',
#   'id': 'a09ec676-f887-43dc-bbb3-cf4bbaee9a18',
#   'positions': [{'name': 'LF',
#     'desc': 'Left Field',
#     'players': [{'id': '1e346b4f-2348-4a1c-9887-45ba04d91e7b',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Clint',
#       'last_name': 'Frazier',
#       'preferred_name': 'Clint',
#       'jersey_number': '77',
#       'depth': 1},
#      {'id': '24a794bb-adde-4f27-abb9-a762a6a4da2f',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'RF',
#       'first_name': 'Michael',
#       'last_name': 'Tauchman',
#       'preferred_name': 'Mike',
#       'jersey_number': '39',
#       'depth': 2},
#      {'id': 'caa6a930-ebf6-41a5-8a3b-93e0280e8077',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Tyler',
#       'last_name': 'Wade',
#       'preferred_name': 'Tyler',
#       'jersey_number': '14',
#       'depth': 3}]},
#    {'name': 'CF',
#     'desc': 'Center Field',
#     'players': [{'id': '4ea710f8-d2b5-42d4-ba58-5cb6e4517dfa',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'CF',
#       'first_name': 'Aaron',
#       'last_name': 'Hicks',
#       'preferred_name': 'Aaron',
#       'jersey_number': '31',
#       'depth': 1},
#      {'id': '24a794bb-adde-4f27-abb9-a762a6a4da2f',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'RF',
#       'first_name': 'Michael',
#       'last_name': 'Tauchman',
#       'preferred_name': 'Mike',
#       'jersey_number': '39',
#       'depth': 2},
#      {'id': 'caa6a930-ebf6-41a5-8a3b-93e0280e8077',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Tyler',
#       'last_name': 'Wade',
#       'preferred_name': 'Tyler',
#       'jersey_number': '14',
#       'depth': 3}]},
#    {'name': 'RF',
#     'desc': 'Right Field',
#     'players': [{'id': '86f7390e-61bd-4556-8325-a6705c7f693b',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'RF',
#       'first_name': 'Aaron',
#       'last_name': 'Judge',
#       'preferred_name': 'Aaron',
#       'jersey_number': '99',
#       'depth': 1},
#      {'id': '24a794bb-adde-4f27-abb9-a762a6a4da2f',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'RF',
#       'first_name': 'Michael',
#       'last_name': 'Tauchman',
#       'preferred_name': 'Mike',
#       'jersey_number': '39',
#       'depth': 2},
#      {'id': '1e346b4f-2348-4a1c-9887-45ba04d91e7b',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Clint',
#       'last_name': 'Frazier',
#       'preferred_name': 'Clint',
#       'jersey_number': '77',
#       'depth': 3},
#      {'id': 'caa6a930-ebf6-41a5-8a3b-93e0280e8077',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Tyler',
#       'last_name': 'Wade',
#       'preferred_name': 'Tyler',
#       'jersey_number': '14',
# ...
#       'jersey_number': '13',
#       'depth': 1},
#      {'id': '97188cb3-5f03-40c4-a10e-5a4a8083ad31',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'CF',
#       'first_name': 'Cristian',
#       'last_name': 'Pache',
#       'preferred_name': 'Cristian',
#       'jersey_number': '14',
#       'depth': 2}]},
#    {'name': 'RF',
#     'desc': 'Right Field',
#     'players': [{'id': '860100f5-6b7a-40da-ace9-fc6805ed8744',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'CF',
#       'first_name': 'Ronald',
#       'last_name': 'Acuña Jr.',
#       'preferred_name': 'Ronald',
#       'jersey_number': '13',
#       'depth': 1}]},
#    {'name': '3B',
#     'desc': 'Third Base',
#     'players': [{'id': '4ee9e14f-2436-4ca4-a9c2-6557d8d86769',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Michael',
#       'last_name': 'Riley',
#       'preferred_name': 'Austin',
#       'jersey_number': '27',
#       'depth': 1}]},
#    {'name': 'SS',
#     'desc': 'Shortstop',
#     'players': [{'id': '5773d9a2-dfc1-458a-acac-67528d6618b3',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': 'SS',
#       'first_name': 'Dansby',
#       'last_name': 'Swanson',
#       'preferred_name': 'Dansby',
#       'jersey_number': '7',
#       'depth': 1}]},
#    {'name': '2B',
#     'desc': 'Second Base',
#     'players': [{'id': '35c471e8-d43a-46c7-ac59-1cbee21222f6',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Ozhanio',
#       'last_name': 'Albies',
#       'preferred_name': 'Ozzie',
#       'jersey_number': '1',
#       'depth': 1},
#      {'id': '95f92bcf-9ad3-4948-acdd-24c4b938d706',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Johan',
#       'last_name': 'Camargo',
#       'preferred_name': 'Johan',
#       'jersey_number': '17',
#       'depth': 2},
#      {'id': '1cd96fa8-c5f0-4e44-85a4-cc968754b3c6',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'David',
#       'last_name': 'Mayfield',
#       'preferred_name': 'Jack',
#       'depth': 3}]},
#    {'name': '1B',
#     'desc': 'First Base',
#     'players': [{'id': 'ea1a2111-44cc-4996-babb-9439465e6760',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '1B',
#       'first_name': 'Frederick',
#       'last_name': 'Freeman',
#       'preferred_name': 'Freddie',
#       'jersey_number': '5',
#       'depth': 1},
#      {'id': '4ee9e14f-2436-4ca4-a9c2-6557d8d86769',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Michael',
#       'last_name': 'Riley',
#       'preferred_name': 'Austin',
#       'jersey_number': '27',
#       'depth': 2}]},
#    {'name': 'SP',
#     'desc': 'Starting Pitcher',
#     'players': [{'id': '3686f2a5-7144-4bd0-95c8-12ceb78fe192',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Ian',
#       'last_name': 'Anderson',
#       'preferred_name': 'Ian',
#       'jersey_number': '48',
#       'depth': 1},
#      {'id': 'f7d2d621-f361-4e1b-b61e-b0f184d5ba74',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Michael',
#       'last_name': 'Soroka',
#       'preferred_name': 'Mike',
#       'jersey_number': '40',
#       'depth': 2},
#      {'id': '1c6ebbc7-2df6-432f-960d-0e7162f3dd6d',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Todd',
#       'last_name': 'Smyly',
#       'preferred_name': 'Drew',
#       'depth': 3},
#      {'id': 'ff772241-8fdd-488c-a81e-49b44ce600fc',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Charles',
#       'last_name': 'Morton',
#       'preferred_name': 'Charlie',
#       'depth': 4},
#      {'id': '1e6d6727-0aec-48da-b880-d38a8178c5db',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Max',
#       'last_name': 'Fried',
#       'preferred_name': 'Max',
#       'jersey_number': '54',
#       'depth': 5},
#      {'id': '6281e4c9-20e9-4b39-9f21-165b54b1f2f7',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Kyle',
#       'last_name': 'Wright',
#       'preferred_name': 'Kyle',
#       'jersey_number': '30',
#       'depth': 6},
#      {'id': '3a29bbbe-f5b6-429e-9979-7aab01210c82',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Joshua',
#       'last_name': 'Tomlin',
#       'preferred_name': 'Josh',
#       'depth': 7},
#      {'id': 'a7c82f82-a77a-44af-b973-771f84226804',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Kyle',
#       'last_name': 'Muller',
#       'preferred_name': 'Kyle',
#       'jersey_number': '80',
#       'depth': 8}]},
#    {'name': 'C',
#     'desc': 'Catcher',
#     'players': [{'id': '6cc35dbd-458e-48a5-a187-99abccbc1abf',
#       'status': 'A',
#       'position': 'C',
#       'primary_position': 'C',
#       'first_name': 'Travis',
#       'last_name': "d'Arnaud",
#       'preferred_name': 'Travis',
#       'jersey_number': '16',
#       'depth': 1}]},
#    {'name': 'DH',
#     'desc': 'Designated Hitter',
#     'players': [{'id': '4ee9e14f-2436-4ca4-a9c2-6557d8d86769',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Michael',
#       'last_name': 'Riley',
#       'preferred_name': 'Austin',
#       'jersey_number': '27',
#       'depth': 1}]},
#    {'name': 'BP',
#     'desc': 'Bullpen',
#     'players': [{'id': '19a3dd28-85dd-4ae0-969e-f4f33419ea5b',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'William',
#       'last_name': 'Smith',
#       'preferred_name': 'Will',
#       'jersey_number': '51',
#       'depth': 1},
#      {'id': '4e52e687-a91b-40ca-9ebd-1bf8006a6d53',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Christopher',
#       'last_name': 'Martin',
#       'preferred_name': 'Chris',
#       'jersey_number': '55',
#       'depth': 2},
#      {'id': '5eb0d6d2-8307-4f44-9401-328f793ae4cb',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Tyler',
#       'last_name': 'Matzek',
#       'preferred_name': 'Tyler',
#       'jersey_number': '68',
#       'depth': 3},
#      {'id': 'e1cbb2df-986d-4fab-bf1e-7192c54bdae9',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Alex',
#       'last_name': 'Minter',
#       'preferred_name': 'A.J.',
#       'jersey_number': '33',
#       'depth': 4},
#      {'id': '526a1205-0c3c-4c93-916d-5beeca478bb6',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Jacob',
#       'last_name': 'Webb',
#       'preferred_name': 'Jacob',
#       'jersey_number': '71',
#       'depth': 5},
#      {'id': 'afebcbd0-fe00-4d21-99c5-6cee7e5eea02',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Bryse',
#       'last_name': 'Wilson',
#       'preferred_name': 'Bryse',
#       'jersey_number': '46',
#       'depth': 6},
#      {'id': '3804d56d-bea8-4a2f-a276-3489e2965f65',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Huascar',
#       'last_name': 'Ynoa',
#       'preferred_name': 'Huascar',
#       'jersey_number': '73',
#       'depth': 7},
#      {'id': 'fb365be0-51ac-4b55-9b4f-2d1ef838ad32',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Grant',
#       'last_name': 'Dayton',
#       'preferred_name': 'Grant',
#       'jersey_number': '75',
#       'depth': 8}]},
#    {'name': 'CL', 'desc': 'Closer'}]},
#  {'name': 'Nationals',
#   'market': 'Washington',
#   'abbr': 'WSH',
#   'id': 'd89bed32-3aee-4407-99e3-4103641b999a',
#   'positions': [{'name': 'LF',
#     'desc': 'Left Field',
#     'players': [{'id': 'c3d9c2d5-8100-409b-a7ea-d5bf7931fc14',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Kyle',
#       'last_name': 'Schwarber',
#       'preferred_name': 'Kyle',
#       'depth': 1},
#      {'id': '3c1db7ff-64bb-4e14-b449-0a5d11b88a2a',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Andrew',
#       'last_name': 'Stevenson',
#       'preferred_name': 'Andrew',
#       'jersey_number': '17',
#       'depth': 2}]},
#    {'name': 'CF',
#     'desc': 'Center Field',
#     'players': [{'id': 'de342f88-03b5-4dcf-9107-9e5527cd4bde',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'CF',
#       'first_name': 'Victor',
#       'last_name': 'Robles',
#       'preferred_name': 'Victor',
#       'jersey_number': '16',
#       'depth': 1},
#      {'id': 'e53374ec-9695-4372-bd19-22a30b88b1d0',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Yadiel',
#       'last_name': 'Hernandez',
#       'preferred_name': 'Yadiel',
#       'jersey_number': '29',
#       'depth': 2}]},
#    {'name': 'RF',
#     'desc': 'Right Field',
#     'players': [{'id': '2aadd7c6-eaea-4975-934e-e504fe9903a2',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'RF',
#       'first_name': 'Juan',
#       'last_name': 'Soto',
#       'preferred_name': 'Juan',
#       'jersey_number': '22',
#       'depth': 1},
#      {'id': '3c1db7ff-64bb-4e14-b449-0a5d11b88a2a',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Andrew',
#       'last_name': 'Stevenson',
#       'preferred_name': 'Andrew',
#       'jersey_number': '17',
#       'depth': 2}]},
#    {'name': '3B',
#     'desc': 'Third Base',
#     'players': [{'id': '0e762dec-639f-497f-a65b-af0eaa8be39f',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Joshua',
#       'last_name': 'Harrison',
#       'preferred_name': 'Josh',
#       'jersey_number': '5',
#       'depth': 1},
#      {'id': 'c80c0b78-69b1-4b62-bb92-7c77d3f6ea9d',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Carter',
#       'last_name': 'Kieboom',
#       'preferred_name': 'Carter',
#       'jersey_number': '8',
#       'depth': 2}]},
#    {'name': 'SS',
#     'desc': 'Shortstop',
#     'players': [{'id': '67dc86a1-cc03-41ae-ba7d-e5b8434c83e8',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': 'SS',
#       'first_name': 'Trea',
#       'last_name': 'Turner',
#       'preferred_name': 'Trea',
#       'jersey_number': '7',
#       'depth': 1},
#      {'id': 'd49868ce-d62b-449e-9025-e400fb9226a8',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Luis',
#       'last_name': 'García',
#       'preferred_name': 'Luis',
#       'jersey_number': '62',
#       'depth': 2}]},
#    {'name': '2B',
#     'desc': 'Second Base',
#     'players': [{'id': 'd49868ce-d62b-449e-9025-e400fb9226a8',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '2B',
#       'first_name': 'Luis',
#       'last_name': 'García',
#       'preferred_name': 'Luis',
#       'jersey_number': '62',
#       'depth': 1},
#      {'id': '0e762dec-639f-497f-a65b-af0eaa8be39f',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '3B',
#       'first_name': 'Joshua',
#       'last_name': 'Harrison',
#       'preferred_name': 'Josh',
#       'jersey_number': '5',
#       'depth': 2}]},
#    {'name': '1B',
#     'desc': 'First Base',
#     'players': [{'id': '49edaec4-ea7c-455b-ac2c-92961b4261f0',
#       'status': 'A',
#       'position': 'IF',
#       'primary_position': '1B',
#       'first_name': 'Joshua',
#       'last_name': 'Bell',
#       'preferred_name': 'Josh',
#       'depth': 1}]},
#    {'name': 'SP',
#     'desc': 'Starting Pitcher',
#     'players': [{'id': '0764772b-e8ab-42b3-9ee4-2b61af785e75',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Patrick',
#       'last_name': 'Corbin',
#       'preferred_name': 'Patrick',
#       'jersey_number': '46',
#       'depth': 1},
#      {'id': '2527770b-cf48-42b9-81fa-9323756fb311',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Maxwell',
#       'last_name': 'Scherzer',
#       'preferred_name': 'Max',
#       'jersey_number': '31',
#       'depth': 2},
#      {'id': 'c3fa97e2-1ea0-4178-b4c3-3d33ac7444d5',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Austin',
#       'last_name': 'Voth',
#       'preferred_name': 'Austin',
#       'jersey_number': '50',
#       'depth': 3},
#      {'id': 'b484880b-790e-45a7-a751-2a03c01ec7ea',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Erick',
#       'last_name': 'Fedde',
#       'preferred_name': 'Erick',
#       'jersey_number': '23',
#       'depth': 4},
#      {'id': 'cf26108f-871a-4448-a3c4-90b1e84e98c8',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'SP',
#       'first_name': 'Samuel',
#       'last_name': 'Clay',
#       'preferred_name': 'Sam',
#       'depth': 5}]},
#    {'name': 'C',
#     'desc': 'Catcher',
#     'players': [{'id': 'd8f12737-4e3e-41ec-a306-fe49cf0a18e2',
#       'status': 'A',
#       'position': 'C',
#       'primary_position': 'C',
#       'first_name': 'Yan',
#       'last_name': 'Gomes',
#       'preferred_name': 'Yan',
#       'jersey_number': '10',
#       'depth': 1},
#      {'id': '96f75024-d2cb-4c0e-a887-82fd1455c1bb',
#       'status': 'A',
#       'position': 'C',
#       'primary_position': 'C',
#       'first_name': 'Felipe',
#       'last_name': 'Barrera',
#       'preferred_name': 'Tres',
#       'jersey_number': '73',
#       'depth': 2}]},
#    {'name': 'DH',
#     'desc': 'Designated Hitter',
#     'players': [{'id': 'e53374ec-9695-4372-bd19-22a30b88b1d0',
#       'status': 'A',
#       'position': 'OF',
#       'primary_position': 'LF',
#       'first_name': 'Yadiel',
#       'last_name': 'Hernandez',
#       'preferred_name': 'Yadiel',
#       'jersey_number': '29',
#       'depth': 1}]},
#    {'name': 'BP',
#     'desc': 'Bullpen',
#     'players': [{'id': '99a4e02c-6349-4031-ac5e-88a64934c9dc',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Wander',
#       'last_name': 'Suero',
#       'preferred_name': 'Wander',
#       'jersey_number': '51',
#       'depth': 1},
#      {'id': 'c1bcfcf2-39e1-49ee-9529-cba60703a041',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Kyle',
#       'last_name': 'McGowin',
#       'preferred_name': 'Kyle',
#       'jersey_number': '61',
#       'depth': 2},
#      {'id': 'a788bab0-4d9b-4e90-806c-80736d0221c4',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'William',
#       'last_name': 'Harris',
#       'preferred_name': 'Will',
#       'jersey_number': '36',
#       'depth': 3},
#      {'id': 'f14f29a3-5e4a-45c2-890b-ec02ed30e5b8',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Kyle',
#       'last_name': 'Finnegan',
#       'preferred_name': 'Kyle',
#       'jersey_number': '67',
#       'depth': 4},
#      {'id': 'b3571fac-289e-40be-b985-193cfc1a13ee',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Ryne',
#       'last_name': 'Harper',
#       'preferred_name': 'Ryne',
#       'jersey_number': '33',
#       'depth': 5},
#      {'id': 'b16cd8a8-4d74-4b77-b8c2-bbc55312cdbc',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Benjamin',
#       'last_name': 'Braymer',
#       'preferred_name': 'Ben',
#       'jersey_number': '70',
#       'depth': 6}]},
#    {'name': 'CL',
#     'desc': 'Closer',
#     'players': [{'id': '3d6aef45-a71b-43dc-87ed-85483cd241a3',
#       'status': 'A',
#       'position': 'P',
#       'primary_position': 'RP',
#       'first_name': 'Daniel',
#       'last_name': 'Hudson',
#       'preferred_name': 'Daniel',
#       'jersey_number': '44',
#       'depth': 1}]}]}]

# %%
def get_All_the_ids_1(teams):
    player_id_only =[]
    for team in teams:
        for position in team.get("positions",[]):
            for player in position.get("players",{}):
                player_id_only.append((player.get("id","N/A")))

    return player_id_only

# %%
just_id = get_All_the_ids_1(data['teams'])
Just_A_sliiiiice = just_id[0:9]
print(Just_A_sliiiiice)
# Out:
# ['20e7bd6e-fb56-4e86-ad2d-b50bc5477371', 'a7d910e1-4815-42b6-9d1e-6af7fa8c3be4', '5a1ba87b-8ec6-4588-97c8-79db8d044cca', '13385fa8-ec77-44fa-854c-b8c372503b54', '88fe9848-7bce-4047-a62f-27f2775a0f5e', '19dc4d37-db3d-4289-bf15-4705ddb56d30', 'a0d999b0-5021-4f17-8082-e842e9e63ce4', '13385fa8-ec77-44fa-854c-b8c372503b54', 'a9ad5859-6769-4349-bd41-3ea2dcae4c78']

# %%
len(Just_A_sliiiiice)
# Out:
# 9

# %%
import time

# %%
for id in Just_A_sliiiiice:
    try: 
        url2 = "http://api.sportradar.us/mlb/trial/v7/en/players/"
        # Build partial query URL
        query_url = f"{url2}{id}/profile.json?api_key={api_key}"
        response = requests.get(query_url)
        response_json = response.json()
        file_name = f"TopTen{id}.json"
      
        with open(f"TopTen{id}.json", 'w', encoding='utf-8') as f:
            json.dump(response_json, f, ensure_ascii=False, indent=4)
        print(f"file {file_name} created")
        time.sleep(5)
    except: 
        print("I found an error")
        print(id)
        print(response)
# Out:
# file TopTen20e7bd6e-fb56-4e86-ad2d-b50bc5477371.json created
# file TopTena7d910e1-4815-42b6-9d1e-6af7fa8c3be4.json created
# file TopTen5a1ba87b-8ec6-4588-97c8-79db8d044cca.json created
# file TopTen13385fa8-ec77-44fa-854c-b8c372503b54.json created
# file TopTen88fe9848-7bce-4047-a62f-27f2775a0f5e.json created
# file TopTen19dc4d37-db3d-4289-bf15-4705ddb56d30.json created
# file TopTena0d999b0-5021-4f17-8082-e842e9e63ce4.json created
# file TopTen13385fa8-ec77-44fa-854c-b8c372503b54.json created
# file TopTena9ad5859-6769-4349-bd41-3ea2dcae4c78.json created

# %%
Bigger_slice = just_id[9:120]
set(Bigger_slice)
len(Bigger_slice)
# Out:
# 111

# %%
for id in Bigger_slice:
    try: 
        url2 = "http://api.sportradar.us/mlb/trial/v7/en/players/"
        # Build partial query URL
        query_url = f"{url2}{id}/profile.json?api_key={api_key}"
        response = requests.get(query_url)
        response_json = response.json()
        file_name = f"TopTen{id}.json"
      
        with open(f"TopTen{id}.json", 'w', encoding='utf-8') as f:
            json.dump(response_json, f, ensure_ascii=False, indent=4)
        print(f"file {file_name} created")
        time.sleep(5)
    except: 
        print("I found an error")
        print(id)
        print(response)
# Out:
# file TopTen88344347-d02f-4bb0-ab54-81f26f13e5b1.json created
# file TopTena0d999b0-5021-4f17-8082-e842e9e63ce4.json created
# file TopTena7d910e1-4815-42b6-9d1e-6af7fa8c3be4.json created
# file TopTen0aa84249-5138-41b3-a086-799cf294bc8a.json created
# file TopTenfa26a373-a427-4558-ba5e-6d6c0f0148c5.json created
# file TopTen3959d7a0-04fc-4772-b9d2-65f97ec4ccb6.json created
# file TopTena9ad5859-6769-4349-bd41-3ea2dcae4c78.json created
# file TopTena0d999b0-5021-4f17-8082-e842e9e63ce4.json created
# file TopTen01d71849-6f8e-4394-ae98-155bd61c68e8.json created
# file TopTen9deda06b-1928-4c58-acf0-717538f576f4.json created
# file TopTen47fdc2c1-b694-4674-ae7c-5cdf1c96babf.json created
# file TopTen8d777ecb-4ab5-4c35-9daa-a1124a200b11.json created
# file TopTen717333c5-59e0-41f4-a1d9-dd58ad2661ef.json created
# file TopTena7f1b8e8-1040-4b51-9eb9-ef3ede3ea8bd.json created
# file TopTen3f65cd94-9f29-4dbf-b7f6-4d8aa51d05a2.json created
# file TopTen47bbd747-6edc-4d0e-a976-5228f5003fbd.json created
# file TopTen3959d7a0-04fc-4772-b9d2-65f97ec4ccb6.json created
# file TopTenfa26a373-a427-4558-ba5e-6d6c0f0148c5.json created
# file TopTen19dc4d37-db3d-4289-bf15-4705ddb56d30.json created
# file TopTen717333c5-59e0-41f4-a1d9-dd58ad2661ef.json created
# file TopTenf15abf11-e9c6-4f90-a16d-59a14176dff3.json created
# file TopTenbc359d03-e510-4c24-acc2-d2964bb36693.json created
# file TopTen2945b9fb-77ed-4e60-a63d-0c4eb2feb458.json created
# file TopTenb2fdb7e8-a700-408c-b238-a077165c4745.json created
# file TopTen38fe7a7d-c990-4440-ad2a-6b7c60a98ae6.json created
# file TopTen6de93a68-31cd-4278-b933-e43cbcee5d98.json created
# file TopTen1d22a1ac-b954-49c8-bed8-eb868078bcc0.json created
# file TopTene7081cad-4d39-4805-82f6-ae0d933ac0fb.json created
# file TopTen7057e7fa-6d96-451e-9546-2e43d5e116d6.json created
# file TopTen0b34eac2-fe40-49b6-b6ae-89826d8059da.json created
# file TopTenca0f384f-9c57-43eb-89dc-dd8797fcb0ca.json created
# file TopTencafd29c0-91ac-4472-819c-c6dfb04bad71.json created
# file TopTen908cf3f8-d7a4-4346-b39e-1f4f66a21864.json created
# file TopTenbffe5dfd-13f9-457c-a5f8-4ac8c2009ebd.json created
# file TopTen1ec2eeb7-01f2-428d-a9bf-8ffb9178759f.json created
# file TopTenbffe5dfd-13f9-457c-a5f8-4ac8c2009ebd.json created
# file TopTenca0f384f-9c57-43eb-89dc-dd8797fcb0ca.json created
# file TopTen7057e7fa-6d96-451e-9546-2e43d5e116d6.json created
# file TopTen9550b18e-bb43-4c41-bac6-1d242f29ca41.json created
# file TopTen0b34eac2-fe40-49b6-b6ae-89826d8059da.json created
# file TopTend44ce1a2-abea-46d1-a2cc-950c27983aba.json created
# file TopTen81af51ef-1387-495a-bef2-57f219415370.json created
# file TopTen9550b18e-bb43-4c41-bac6-1d242f29ca41.json created
# file TopTencafd29c0-91ac-4472-819c-c6dfb04bad71.json created
# file TopTen9550b18e-bb43-4c41-bac6-1d242f29ca41.json created
# file TopTend44ce1a2-abea-46d1-a2cc-950c27983aba.json created
# file TopTen116ddf3b-e590-429f-a7c0-3493f83a5b87.json created
# file TopTenc91b7458-14bf-4a62-b147-c47ad2f19396.json created
# file TopTend44ce1a2-abea-46d1-a2cc-950c27983aba.json created
# file TopTen81125861-72f8-461c-b7c2-46fc460a7115.json created
# file TopTendae38ebc-f1dc-4b47-a8b6-9bee0fc2a2dd.json created
# file TopTendb6ced3d-7838-4a7c-92a5-50d0b63dac3b.json created
# file TopTenfb58e481-089f-44e5-abd4-f66646b3811a.json created
# file TopTena2c6cf2d-e796-4b45-900d-7db1bd6d39f7.json created
# file TopTen00d70364-1c07-464f-bd34-f571f7d7ae10.json created
# file TopTen7d494bf9-a3ce-4e7c-a122-bc8e8c13c87b.json created
# file TopTenca0f384f-9c57-43eb-89dc-dd8797fcb0ca.json created
# file TopTen0b34eac2-fe40-49b6-b6ae-89826d8059da.json created
# file TopTen116ddf3b-e590-429f-a7c0-3493f83a5b87.json created
# file TopTen276cbbde-fb0e-43ff-99be-355a6ebb531c.json created
# file TopTen780e8c91-53d2-4d3a-ae24-ac7a7717e01e.json created
# file TopTen80411944-bd62-46cf-8794-06a837b1c21c.json created
# file TopTen05b5805b-3b4e-40f6-982b-03081465c961.json created
# file TopTen97f72e12-2dab-4976-87bf-377f4b3be400.json created
# file TopTen9babdf5b-fa9c-4169-b9af-4d8b8dff93a0.json created
# file TopTen71948aff-effa-49e9-a040-396bc6b22f31.json created
# file TopTen0f626ddc-1c79-43af-9407-12aa1381d420.json created
# file TopTen135505bb-4541-4ca6-8d2e-80febcf830bd.json created
# file TopTen96600e21-d075-440d-8762-5d48a466b053.json created
# file TopTenfaf93f6f-b60e-4c9e-a83f-5ba8b0aca02c.json created
# file TopTen0f626ddc-1c79-43af-9407-12aa1381d420.json created
# file TopTenb93bec13-df83-4d67-98f6-81d2b4d4da1f.json created
# file TopTene26d31f5-1199-4edf-a154-a8ed209ac971.json created
# file TopTen96600e21-d075-440d-8762-5d48a466b053.json created
# file TopTend4bc8879-c7dc-430f-bcb8-e932b21a2e7c.json created
# file TopTen135505bb-4541-4ca6-8d2e-80febcf830bd.json created
# file TopTenb42351bd-4834-47f0-bc95-612eb5fa9669.json created
# file TopTen17c0c208-3c37-4553-b37f-a99ba885a206.json created
# file TopTenf4923e5e-7d80-4d32-b226-c1d67345a270.json created
# file TopTencf9815a7-220b-45f9-bbdf-9c6c8b792154.json created
# file TopTen2412a017-f7ec-4b7b-a19f-e441554cf49a.json created
# file TopTen135505bb-4541-4ca6-8d2e-80febcf830bd.json created
# file TopTen0672f3d5-5781-47bb-b111-abec96c38355.json created
# file TopTen17c0c208-3c37-4553-b37f-a99ba885a206.json created
# file TopTen135505bb-4541-4ca6-8d2e-80febcf830bd.json created
# file TopTen0672f3d5-5781-47bb-b111-abec96c38355.json created
# file TopTen9fc34f7c-7d68-4d82-9460-0b12f3e728b5.json created
# file TopTenddfbc667-95d8-49fc-8e77-a8e4e452d820.json created
# file TopTen135505bb-4541-4ca6-8d2e-80febcf830bd.json created
# file TopTend2c5e643-fe5d-4ece-8f1e-560d6b2048ed.json created
# file TopTenb9766398-e982-43a6-a3a0-f7f8e24061c6.json created
# file TopTend6c41179-8aef-407c-843d-225a397935f0.json created
# file TopTen7960a26a-3ee0-4c7a-bc10-585cf71b02a5.json created
# file TopTenb289c3a7-e653-4fa1-931f-733d1a8ba26c.json created
# file TopTen11c4591d-a21d-45b9-8e3a-cbba1d633646.json created
# file TopTen29ab0dc1-7fa9-4fd2-920c-d88fd00edb48.json created
# file TopTena68b7a2e-0eae-4ab1-ba02-ee1c9cca5850.json created
# file TopTena370e82a-6bdd-438b-9c20-89fbffa80050.json created
# file TopTen9fc34f7c-7d68-4d82-9460-0b12f3e728b5.json created
# file TopTena370e82a-6bdd-438b-9c20-89fbffa80050.json created
# file TopTen9e883466-7d2d-45a0-a509-44c14aeff967.json created
# file TopTen0daadfb1-9f92-4ecf-87c4-bbfc0a232e6c.json created
# file TopTen4925447b-7d3f-43c0-8092-6c0d54cef288.json created
# file TopTen9ceccdf6-6eb7-464e-bc7d-3eaa49cbcbe2.json created
# file TopTen636653db-659f-46b4-a672-fcc478fc5be5.json created
# file TopTene7fbf15a-c6d6-4d32-b191-bbafc25bb8a4.json created
# file TopTend954e80f-b7c3-46a6-b75c-15038552c138.json created
# file TopTena845cf84-1aa5-43f1-a25d-21c98bbfde3a.json created
# file TopTend5dc9502-ff51-4345-b714-0c0b6636ae08.json created
# file TopTen0e5244cd-9226-4ee1-bb63-d022a9240ca0.json created
# file TopTen6f7a2f3c-0341-47be-a60a-f6c15d7a9a0b.json created

# %%
Final_slice = just_id[120:180]
set(Final_slice)
len(Final_slice)
# Out:
# 60

# %%
for id in Final_slice:
    try: 
        url2 = "http://api.sportradar.us/mlb/trial/v7/en/players/"
        # Build partial query URL
        query_url = f"{url2}{id}/profile.json?api_key={api_key}"
        response = requests.get(query_url)
        response_json = response.json()
        file_name = f"TopTen{id}.json"
      
        with open(f"TopTen{id}.json", 'w', encoding='utf-8') as f:
            json.dump(response_json, f, ensure_ascii=False, indent=4)
        print(f"file {file_name} created")
        time.sleep(5)
    except: 
        print("I found an error")
        print(id)
        print(response)
# Out:
# file TopTenf423faea-d0e3-49b6-b347-52ec5cfac66a.json created
# file TopTen0199150d-29c1-49d2-bb85-027921a33c8e.json created
# file TopTen6f7a2f3c-0341-47be-a60a-f6c15d7a9a0b.json created
# file TopTen8279fb7a-866f-4c8f-8a4d-f55d81202185.json created
# file TopTen89bab4bd-0fb6-41a6-88d6-0fd6307ae072.json created
# file TopTen6f7a2f3c-0341-47be-a60a-f6c15d7a9a0b.json created
# file TopTenf423faea-d0e3-49b6-b347-52ec5cfac66a.json created
# file TopTenfe966998-15e1-4022-89d5-6b4750516176.json created
# file TopTenac760643-fe40-475e-8cf0-5b7faa47c5a1.json created
# file TopTen5fe17998-9821-41ca-af92-2f78ab89ac61.json created
# file TopTen0199150d-29c1-49d2-bb85-027921a33c8e.json created
# file TopTen272abdba-ae99-4137-a6dd-5615f234adfc.json created
# file TopTen5fe17998-9821-41ca-af92-2f78ab89ac61.json created
# file TopTen1d6fc3c6-7172-4189-bf35-dfafd17e37e6.json created
# file TopTen0199150d-29c1-49d2-bb85-027921a33c8e.json created
# file TopTen40085c05-fa06-4eec-9f41-f0245980f6a0.json created
# file TopTenac760643-fe40-475e-8cf0-5b7faa47c5a1.json created
# file TopTen0199150d-29c1-49d2-bb85-027921a33c8e.json created
# file TopTen6dd571bc-b26c-4efc-87da-7b501c96faf1.json created
# file TopTen66c43b7f-760a-446c-9f50-671915570227.json created
# file TopTen93413a68-2c05-405a-a38c-9ee983b36913.json created
# file TopTen1b0ad742-0bc5-49b0-abe0-005e8581b1d3.json created
# file TopTend49a253f-518e-4a86-9dcf-c91497c29d92.json created
# file TopTen24322a1d-4b4b-4c18-9ef4-1bdefe6abae8.json created
# file TopTen0d7a27a9-f41c-4fce-930e-113aa4cf4c52.json created
# file TopTenb1f6fc22-f38e-4d77-a7e7-6a2ffdcf77f2.json created
# file TopTenf423faea-d0e3-49b6-b347-52ec5cfac66a.json created
# file TopTen6f7a2f3c-0341-47be-a60a-f6c15d7a9a0b.json created
# file TopTen6426ad53-44d1-4ae9-b14c-b068106f5949.json created
# file TopTen65cf79ea-c3bf-409a-8b86-a5e334a186dc.json created
# file TopTen29311663-0a56-451d-a9fa-7c8ff207013c.json created
# file TopTen58831505-e236-4871-9f20-1e9d8bb0fa60.json created
# file TopTenad2422c3-0323-4ac1-b1cf-ddc109c1747b.json created
# file TopTenb25f0afc-4671-43a9-90e0-61bd7bd08604.json created
# file TopTene2bb2600-ed84-4223-b829-cacddcbfa193.json created
# file TopTen61bc96e6-dbb3-4dc0-972d-0c85d49f37ca.json created
# file TopTendb6334d5-f34a-4db9-8e6b-5cb843617550.json created
# file TopTen1e346b4f-2348-4a1c-9887-45ba04d91e7b.json created
# file TopTen24a794bb-adde-4f27-abb9-a762a6a4da2f.json created
# file TopTencaa6a930-ebf6-41a5-8a3b-93e0280e8077.json created
# file TopTen4ea710f8-d2b5-42d4-ba58-5cb6e4517dfa.json created
# file TopTen24a794bb-adde-4f27-abb9-a762a6a4da2f.json created
# file TopTencaa6a930-ebf6-41a5-8a3b-93e0280e8077.json created
# file TopTen86f7390e-61bd-4556-8325-a6705c7f693b.json created
# file TopTen24a794bb-adde-4f27-abb9-a762a6a4da2f.json created
# file TopTen1e346b4f-2348-4a1c-9887-45ba04d91e7b.json created
# file TopTencaa6a930-ebf6-41a5-8a3b-93e0280e8077.json created
# file TopTen82862830-8124-401f-94f6-020802e1761d.json created
# file TopTencaa6a930-ebf6-41a5-8a3b-93e0280e8077.json created
# file TopTen781d3396-df55-4b42-bea4-5c9cad9dcad0.json created
# file TopTencaa6a930-ebf6-41a5-8a3b-93e0280e8077.json created
# file TopTen2df4c1ae-3eb7-4009-a7ef-00335aa82893.json created
# file TopTencaa6a930-ebf6-41a5-8a3b-93e0280e8077.json created
# file TopTen2df4c1ae-3eb7-4009-a7ef-00335aa82893.json created
# file TopTen0c01759a-98ad-4f73-84f8-60f95683fc9b.json created
# file TopTeneedd0e21-283e-4534-aa38-afe98d4415a1.json created
# file TopTeneebc991a-23ea-4f1c-ba3b-37ff21ee1603.json created
# file TopTene96d88f5-3593-48fb-b1fd-840b41c08cc5.json created
# file TopTenedd50bcc-f6b2-4748-8898-038505d94a39.json created
# file TopTen8adff54a-cb4b-4692-b18c-e9aaa9a8e076.json created

# %%
url2 = "http://api.sportradar.us/mlb/trial/v7/en/players/"
# Build partial query URL
query_url = f"{url2}5a1ba87b-8ec6-4588-97c8-79db8d044cca/profile.json?api_key={api_key}"
response_check = requests.get(query_url).json()
#     barrels = response['player']['seasons'][0]['totals']['statcast_metrics']['hitting']['overall'][1]['barreled_ball']['count']
#     Max_exit_velo = response['player']['seasons'][0]['totals']['statcast_metrics']['hitting']['overall'][6]['launch_speed']['max']
#     pa = response['player']['seasons']['totals']['statistics']['hitting']['overall']['ap']
print(response_check)
# Out:
# {'player': {'id': '5a1ba87b-8ec6-4588-97c8-79db8d044cca', 'status': 'A', 'position': 'OF', 'primary_position': 'CF', 'first_name': 'Randal', 'last_name': 'Grichuk', 'preferred_name': 'Randal', 'jersey_number': '15', 'full_name': 'Randal Grichuk', 'height': '74', 'weight': '216', 'throw_hand': 'R', 'bat_hand': 'R', 'high_school': 'Lamar Consolidated (TX)', 'birthdate': '1991-08-13', 'birthstate': 'TX', 'birthcountry': 'USA', 'birthcity': 'Rosenberg', 'pro_debut': '2014-04-28', 'updated': '2020-09-16T16:04:57+00:00', 'reference': '545341', 'draft': {'team_id': '4f735188-37c8-473d-ae32-1f7e34ccf892', 'year': 2009, 'round': 1, 'pick': 24}, 'team': {'name': 'Blue Jays', 'market': 'Toronto', 'abbr': 'TOR', 'id': '1d678440-b4b1-4954-9b39-70afb3ebbcfa'}, 'seasons': [{'id': 'ca08b3a2-4adf-4fd7-b35b-01f194f665e2', 'year': 2020, 'type': 'PST', 'totals': {'statistics': {'hitting': {'overall': {'ab': 7, 'lob': 2, 'rbi': 0, 'abhr': 0, 'abk': 1.4, 'bip': 2, 'babip': 0.5, 'bbk': 0.2, 'bbpa': 0.125, 'iso': 0.0, 'obp': 0.25, 'ops': 0.393, 'seca': 0.143, 'slg': 0.143, 'xbh': 0, 'pitch_count': 36, 'lob_risp_2out': 1, 'team_lob': 1, 'ab_risp': 2, 'hit_risp': 0, 'rbi_2out': 0, 'linedrive': 1, 'groundball': 1, 'popup': 0, 'flyball': 0, 'ap': 8, 'avg': '.143', 'gofo': 0.0, 'onbase': {'s': 1, 'd': 0, 't': 0, 'hr': 0, 'tb': 1, 'bb': 1, 'ibb': 0, 'hbp': 0, 'fc': 0, 'roe': 0, 'h': 1, 'cycle': 0}, 'runs': {'total': 0}, 'outcome': {'klook': 8, 'kswing': 8, 'ktotal': 16, 'ball': 14, 'iball': 0, 'dirtball': 0, 'foul': 4}, 'outs': {'po': 0, 'fo': 0, 'fidp': 0, 'lo': 1, 'lidp': 0, 'go': 0, 'gidp': 0, 'klook': 1, 'kswing': 4, 'ktotal': 5, 'sacfly': 0, 'sachit': 0}, 'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0}, 'pitches': {'count': 36, 'btotal': 14, 'ktotal': 22}, 'games': {'start': 2, 'play': 2, 'finish': 0, 'complete': 2}}}, 'fielding': {'overall': {'po': 3, 'a': 0, 'dp': 0, 'tp': 0, 'error': 0, 'tc': 3, 'fpct': 1.0, 'c_wp': 0, 'pb': 0, 'rf': 1.5, 'inn_1': 48, 'inn_2': 16.0, 'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0}, 'errors': {'throwing': 0, 'fielding': 0, 'interference': 0, 'total': 0}, 'assists': {'outfield': 0, 'total': 0}, 'games': {'start': 2, 'play': 2, 'finish': 0, 'complete': 0}}, 'positions': [{'po': 3, 'a': 0, 'dp': 0, 'tp': 0, 'error': 0, 'tc': 3, 'fpct': 1.0, 'c_wp': 0, 'pb': 0, 'rf': 1.5, 'inn_1': 48, 'inn_2': 16.0, 'position': 'CF', 'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0}, 'errors': {'throwing': 0, 'fielding': 0, 'interference': 0, 'total': 0}, 'assists': {'outfield': 0, 'total': 0}, 'games': {'start': 2, 'play': 2, 'finish': 0, 'complete': 0}}]}}, 'splits': {'hitting': {'overall': [{'total': [{'ab': 7, 'runs': 0, 's': 1, 'd': 0, 't': 0, 'hr': 0, 'rbi': 0, 'bb': 1, 'ibb': 0, 'hbp': 0, 'sb': 0, 'cs': 0, 'obp': 0.25, 'slg': 0.143, 'ops': 0.393, 'h': 1, 'ktotal': 5, 'avg': '.143'}], 'day_night': [{'value': 'day', 'ab': 7, 'runs': 0, 's': 1, 'd': 0, 't': 0, 'hr': 0, 'rbi': 0, 'bb': 1, 'ibb': 0, 'hbp': 0, 'sb': 0, 'cs': 0, 'obp': 0.25, 'slg': 0.143, 'ops': 0.393, 'h': 1, 'ktotal': 5, 'avg': '.143'}], 'venue': [{'id': '3aaaf4af-0f8c-49c1-8bf1-1780bb5a5f5c', 'name': 'Tropicana Field', 'market': 'Tampa Bay', 'surface': 'turf', 'ab': 7, 'runs': 0, 's': 1, 'd': 0, 't': 0, 'hr': 0, 'rbi': 0, 'bb': 1, 'ibb': 0, 'hbp': 0, 'sb': 0, 'cs': 0, 'obp': 0.25, 'slg': 0.143, 'ops': 0.393, 'h': 1, 'ktotal': 5, 'avg': '.143'}], 'surface': [{'value': 'turf', 'ab': 7, 'runs': 0, 's': 1, 'd': 0, 't': 0, 'hr': 0, 'rbi': 0, 'bb': 1, 'ibb': 0, 'hbp': 0, 'sb': 0, 'cs': 0, 'obp': 0.25, 'slg': 0.143, 'ops': 0.393, 'h': 1, 'ktotal': 5, 'avg': '.143'}], 'month': [{'value': '9', 'ab': 7, 'runs': 0, 's': 1, 'd': 0, 't': 0, 'hr': 0, 'rbi': 0, 'bb': 1, 'ibb': 0, 'hbp': 0, 'sb': 0, 'cs': 0, 'obp': 0.25, 'slg': 0.143, 'ops': 0.393, 'h': 1, 'ktotal': 5, 'avg': '.143'}], 'home_away': [{'value': 'away', 'ab': 7, 'runs': 0, 's': 1, 'd': 0, 't': 0, 'hr': 0, 'rbi': 0, 'bb': 1, 'ibb': 0, 'hbp': 0, 'sb': 0, 'cs': 0, 'obp': 0.25, 'slg': 0.143 ...

# %%
response_check['player']
# Out:
# {'id': '5a1ba87b-8ec6-4588-97c8-79db8d044cca',
#  'status': 'A',
#  'position': 'OF',
#  'primary_position': 'CF',
#  'first_name': 'Randal',
#  'last_name': 'Grichuk',
#  'preferred_name': 'Randal',
#  'jersey_number': '15',
#  'full_name': 'Randal Grichuk',
#  'height': '74',
#  'weight': '216',
#  'throw_hand': 'R',
#  'bat_hand': 'R',
#  'high_school': 'Lamar Consolidated (TX)',
#  'birthdate': '1991-08-13',
#  'birthstate': 'TX',
#  'birthcountry': 'USA',
#  'birthcity': 'Rosenberg',
#  'pro_debut': '2014-04-28',
#  'updated': '2020-09-16T16:04:57+00:00',
#  'reference': '545341',
#  'draft': {'team_id': '4f735188-37c8-473d-ae32-1f7e34ccf892',
#   'year': 2009,
#   'round': 1,
#   'pick': 24},
#  'team': {'name': 'Blue Jays',
#   'market': 'Toronto',
#   'abbr': 'TOR',
#   'id': '1d678440-b4b1-4954-9b39-70afb3ebbcfa'},
#  'seasons': [{'id': 'ca08b3a2-4adf-4fd7-b35b-01f194f665e2',
#    'year': 2020,
#    'type': 'PST',
#    'totals': {'statistics': {'hitting': {'overall': {'ab': 7,
#        'lob': 2,
#        'rbi': 0,
#        'abhr': 0,
#        'abk': 1.4,
#        'bip': 2,
#        'babip': 0.5,
#        'bbk': 0.2,
#        'bbpa': 0.125,
#        'iso': 0.0,
#        'obp': 0.25,
#        'ops': 0.393,
#        'seca': 0.143,
#        'slg': 0.143,
#        'xbh': 0,
#        'pitch_count': 36,
#        'lob_risp_2out': 1,
#        'team_lob': 1,
#        'ab_risp': 2,
#        'hit_risp': 0,
#        'rbi_2out': 0,
#        'linedrive': 1,
#        'groundball': 1,
#        'popup': 0,
#        'flyball': 0,
#        'ap': 8,
#        'avg': '.143',
#        'gofo': 0.0,
#        'onbase': {'s': 1,
#         'd': 0,
#         't': 0,
#         'hr': 0,
#         'tb': 1,
#         'bb': 1,
#         'ibb': 0,
#         'hbp': 0,
#         'fc': 0,
#         'roe': 0,
#         'h': 1,
#         'cycle': 0},
#        'runs': {'total': 0},
#        'outcome': {'klook': 8,
#         'kswing': 8,
#         'ktotal': 16,
#         'ball': 14,
#         'iball': 0,
#         'dirtball': 0,
#         'foul': 4},
#        'outs': {'po': 0,
#         'fo': 0,
#         'fidp': 0,
#         'lo': 1,
#         'lidp': 0,
#         'go': 0,
#         'gidp': 0,
#         'klook': 1,
#         'kswing': 4,
#         'ktotal': 5,
#         'sacfly': 0,
#         'sachit': 0},
#        'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#        'pitches': {'count': 36, 'btotal': 14, 'ktotal': 22},
#        'games': {'start': 2, 'play': 2, 'finish': 0, 'complete': 2}}},
#      'fielding': {'overall': {'po': 3,
#        'a': 0,
#        'dp': 0,
#        'tp': 0,
#        'error': 0,
#        'tc': 3,
#        'fpct': 1.0,
#        'c_wp': 0,
#        'pb': 0,
#        'rf': 1.5,
#        'inn_1': 48,
#        'inn_2': 16.0,
#        'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#        'errors': {'throwing': 0, 'fielding': 0, 'interference': 0, 'total': 0},
#        'assists': {'outfield': 0, 'total': 0},
#        'games': {'start': 2, 'play': 2, 'finish': 0, 'complete': 0}},
#       'positions': [{'po': 3,
#         'a': 0,
#         'dp': 0,
#         'tp': 0,
#         'error': 0,
#         'tc': 3,
#         'fpct': 1.0,
#         'c_wp': 0,
#         'pb': 0,
#         'rf': 1.5,
#         'inn_1': 48,
#         'inn_2': 16.0,
#         'position': 'CF',
#         'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#         'errors': {'throwing': 0,
#          'fielding': 0,
#          'interference': 0,
#          'total': 0},
#         'assists': {'outfield': 0, 'total': 0},
#         'games': {'start': 2, 'play': 2, 'finish': 0, 'complete': 0}}]}},
#     'splits': {'hitting': {'overall': [{'total': [{'ab': 7,
#           'runs': 0,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.25,
#           'slg': 0.143,
#           'ops': 0.393,
#           'h': 1,
#           'ktotal': 5,
#           'avg': '.143'}],
#         'day_night': [{'value': 'day',
#           'ab': 7,
#           'runs': 0,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.25,
#           'slg': 0.143,
#           'ops': 0.393,
#           'h': 1,
#           'ktotal': 5,
#           'avg': '.143'}],
#         'venue': [{'id': '3aaaf4af-0f8c-49c1-8bf1-1780bb5a5f5c',
#           'name': 'Tropicana Field',
#           'market': 'Tampa Bay',
#           'surface': 'turf',
#           'ab': 7,
#           'runs': 0,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.25,
#           'slg': 0.143,
#           'ops': 0.393,
#           'h': 1,
#           'ktotal': 5,
#           'avg': '.143'}],
#         'surface': [{'value': 'turf',
#           'ab': 7,
#           'runs': 0,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.25,
#           'slg': 0.143,
#           'ops': 0.393,
#           'h': 1,
#           'ktotal': 5,
#           'avg': '.143'}],
#         'month': [{'value': '9',
#           'ab': 7,
#           'runs': 0,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.25,
#           'slg': 0.143,
#           'ops': 0.393,
#           'h': 1,
#           'ktotal': 5,
#           'avg': '.143'}],
#         'home_away': [{'value': 'away',
#           'ab': 7,
#           'runs': 0,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.25,
#           'slg': 0.143,
#           'ops': 0.393,
#           'h': 1,
#           'ktotal': 5,
#           'avg': '.143'}],
#         'pitcher_hand': [{'value': 'R',
#           'ab': 6,
#           'runs': 0,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.167,
#           'slg': 0.167,
#           'ops': 0.334,
#           'h': 1,
#           'ktotal': 4,
#           'avg': '.167'},
#          {'value': 'L',
#           'ab': 1,
#           'runs': 0,
#           's': 0,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.5,
#           'slg': 0.0,
#           'ops': 0.5,
#           'h': 0,
#           'ktotal': 1,
#           'avg': '.000'}],
#         'opponent': [{'id': 'bdc11650-6f74-49c4-875e-778aeb7632d9',
#           'name': 'Rays',
#           'market': 'Tampa Bay',
#           'abbr': 'TB',
#           'ab': 7,
#           'runs': 0,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.25,
#           'slg': 0.143,
#           'ops': 0.393,
#           'h': 1,
#           'ktotal': 5,
#           'avg': '.143'}]}]}}},
#    'teams': [{'name': 'Blue Jays',
#      'market': 'Toronto',
#      'abbr': 'TOR',
#      'id': '1d678440-b4b1-4954-9b39-70afb3ebbcfa',
#      'statistics': {'hitting': {'overall': {'ab': 7,
#         'lob': 2,
#         'rbi': 0,
#         'abhr': 0,
#         'abk': 1.4,
#         'bip': 2,
#         'babip': 0.5,
#         'bbk': 0.2,
#         'bbpa': 0.125,
#         'iso': 0.0,
#         'obp': 0.25,
#         'ops': 0.393,
#         'seca': 0.143,
#         'slg': 0.143,
#         'xbh': 0,
#         'pitch_count': 36,
#         'lob_risp_2out': 1,
#         'team_lob': 1,
#         'ab_risp': 2,
#         'hit_risp': 0,
#         'rbi_2out': 0,
#         'linedrive': 1,
#         'groundball': 1,
#         'popup': 0,
#         'flyball': 0,
#         'ap': 8,
#         'avg': '.143',
#         'gofo': 0.0,
#         'onbase': {'s': 1,
#          'd': 0,
#          't': 0,
#          'hr': 0,
#          'tb': 1,
#          'bb': 1,
#          'ibb': 0,
#          'hbp': 0,
#          'fc': 0,
#          'roe': 0,
#          'h': 1,
#          'cycle': 0},
#         'runs': {'total': 0},
#         'outcome': {'klook': 8,
#          'kswing': 8,
#          'ktotal': 16,
#          'ball': 14,
#          'iball': 0,
#          'dirtball': 0,
#          'foul': 4},
#         'outs': {'po': 0,
#          'fo': 0,
#          'fidp': 0,
#          'lo': 1,
#          'lidp': 0,
#          'go': 0,
#          'gidp': 0,
#          'klook': 1,
#          'kswing': 4,
#          'ktotal': 5,
#          'sacfly': 0,
#          'sachit': 0},
#         'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#         'pitches': {'count': 36, 'btotal': 14, 'ktotal': 22},
#         'games': {'start': 2, 'play': 2, 'finish': 0, 'complete': 2}}},
#       'fielding': {'overall': {'po': 3,
#         'a': 0,
#         'dp': 0,
#         'tp': 0,
#         'error': 0,
#         'tc': 3,
#         'fpct': 1.0,
#         'c_wp': 0,
#         'pb': 0,
#         'rf': 1.5,
#         'inn_1': 48,
#         'inn_2': 16.0,
#         'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#         'errors': {'throwing': 0,
#          'fielding': 0,
#          'interference': 0,
#          'total': 0},
#         'assists': {'outfield': 0, 'total': 0},
#         'games': {'start': 2, 'play': 2, 'finish': 0, 'complete': 0}},
#        'positions': [{'po': 3,
#          'a': 0,
#          'dp': 0,
#          'tp': 0,
#          'error': 0,
#          'tc': 3,
#          'fpct': 1.0,
#          'c_wp': 0,
#          'pb': 0,
#          'rf': 1.5,
#          'inn_1': 48,
#          'inn_2': 16.0,
#          'position': 'CF',
#          'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#          'errors': {'throwing': 0,
#           'fielding': 0,
#           'interference': 0,
#           'total': 0},
#          'assists': {'outfield': 0, 'total': 0},
#          'games': {'start': 2, 'play': 2, 'finish': 0, 'complete': 0}}]}},
#      'splits': {'hitting': {'overall': [{'total': [{'ab': 7,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.143,
#            'ops': 0.393,
#            'h': 1,
#            'ktotal': 5,
#            'avg': '.143'}],
#          'day_night': [{'value': 'day',
#            'ab': 7,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.143,
#            'ops': 0.393,
#            'h': 1,
#            'ktotal': 5,
#            'avg': '.143'}],
#          'venue': [{'id': '3aaaf4af-0f8c-49c1-8bf1-1780bb5a5f5c',
#            'name': 'Tropicana Field',
#            'market': 'Tampa Bay',
#            'surface': 'turf',
#            'ab': 7,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.143,
#            'ops': 0.393,
#            'h': 1,
#            'ktotal': 5,
#            'avg': '.143'}],
#          'surface': [{'value': 'turf',
#            'ab': 7,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.143,
#            'ops': 0.393,
#            'h': 1,
#            'ktotal': 5,
#            'avg': '.143'}],
#          'month': [{'value': '9',
#            'ab': 7,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.143,
#            'ops': 0.393,
#            'h': 1,
#            'ktotal': 5,
#            'avg': '.143'}],
#          'home_away': [{'value': 'away',
#            'ab': 7,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.143,
#            'ops': 0.393,
#            'h': 1,
#            'ktotal': 5,
#            'avg': '.143'}],
#          'pitcher_hand': [{'value': 'R',
#            'ab': 6,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.167,
#            'slg': 0.167,
#            'ops': 0.334,
#            'h': 1,
#            'ktotal': 4,
#            'avg': '.167'},
#           {'value': 'L',
#            'ab': 1,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.5,
#            'slg': 0.0,
#            'ops': 0.5,
#            'h': 0,
#            'ktotal': 1,
#            'avg': '.000'}],
#          'opponent': [{'id': 'bdc11650-6f74-49c4-875e-778aeb7632d9',
#            'name': 'Rays',
#            'market': 'Tampa Bay',
#            'abbr': 'TB',
#            'ab': 7,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.143,
#            'ops': 0.393,
#            'h': 1,
#            'ktotal': 5,
#            'avg': '.143'}]}]}}}]},
#   {'id': 'bd17502c-7dff-4f86-980b-df765f895163',
#    'year': 2020,
#    'type': 'PRE',
#    'totals': {'statistics': {'hitting': {'overall': {'ab': 25,
#        'lob': 10,
#        'rbi': 9,
#        'abhr': 8.333,
#        'abk': 4.167,
#        'bip': 16,
#        'babip': 0.313,
#        'bbk': 0.833,
#        'bbpa': 0.167,
#        'iso': 0.4,
#        'obp': 0.433,
#        'ops': 1.153,
#        'seca': 0.6,
#        'slg': 0.72,
#        'xbh': 4,
#        'pitch_count': 65,
#        'lob_risp_2out': 2,
#        'team_lob': 4,
#        'ab_risp': 10,
#        'hit_risp': 6,
#        'rbi_2out': 2,
#        'linedrive': 3,
#        'groundball': 7,
#        'popup': 1,
#        'flyball': 7,
#        'ap': 30,
#        'avg': '.320',
#        'gofo': 0.83,
#        'onbase': {'s': 4,
#         'd': 1,
#         't': 0,
#         'hr': 3,
#         'tb': 18,
#         'bb': 5,
#         'ibb': 0,
#         'hbp': 0,
#         'fc': 1,
#         'roe': 0,
#         'h': 8,
#         'cycle': 0},
#        'runs': {'total': 8},
#        'outcome': {'klook': 4,
#         'kswing': 17,
#         'ktotal': 21,
#         'ball': 24,
#         'iball': 0,
#         'dirtball': 0,
#         'foul': 1},
#        'outs': {'po': 1,
#         'fo': 4,
#         'fidp': 0,
#         'lo': 1,
#         'lidp': 0,
#         'go': 5,
#         'gidp': 0,
#         'klook': 1,
#         'kswing': 5,
#         'ktotal': 6,
#         'sacfly': 0,
#         'sachit': 0},
#        'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#        'pitches': {'count': 65, 'btotal': 24, 'ktotal': 41},
#        'games': {'start': 11, 'play': 11, 'finish': 0, 'complete': 0}}},
#      'fielding': {'overall': {'po': 9,
#        'a': 0,
#        'dp': 0,
#        'tp': 0,
#        'error': 0,
#        'tc': 9,
#        'fpct': 1.0,
#        'c_wp': 0,
#        'pb': 0,
#        'rf': 1.286,
#        'inn_1': 108,
#        'inn_2': 36.0,
#        'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#        'errors': {'throwing': 0, 'fielding': 0, 'interference': 0, 'total': 0},
#        'assists': {'outfield': 0, 'total': 0},
#        'games': {'start': 7, 'play': 7, 'finish': 0, 'complete': 0}},
#       'positions': [{'po': 9,
#         'a': 0,
#         'dp': 0,
#         'tp': 0,
#         'error': 0,
#         'tc': 9,
#         'fpct': 1.0,
#         'c_wp': 0,
#         'pb': 0,
#         'rf': 1.286,
#         'inn_1': 108,
#         'inn_2': 36.0,
#         'position': 'CF',
#         'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#         'errors': {'throwing': 0,
#          'fielding': 0,
#          'interference': 0,
#          'total': 0},
#         'assists': {'outfield': 0, 'total': 0},
#         'games': {'start': 7, 'play': 7, 'finish': 0, 'complete': 0}}]}},
#     'splits': {'hitting': {'overall': [{'total': [{'ab': 25,
#           'runs': 8,
#           's': 4,
#           'd': 1,
#           't': 0,
#           'hr': 3,
#           'rbi': 9,
#           'bb': 5,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.433,
#           'slg': 0.72,
#           'ops': 1.153,
#           'h': 8,
#           'ktotal': 6,
#           'avg': '.320'}],
#         'day_night': [{'value': 'day',
#           'ab': 25,
#           'runs': 8,
#           's': 4,
#           'd': 1,
#           't': 0,
#           'hr': 3,
#           'rbi': 9,
#           'bb': 5,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.433,
#           'slg': 0.72,
#           'ops': 1.153,
#           'h': 8,
#           'ktotal': 6,
#           'avg': '.320'}],
#         'venue': [{'id': '49a8bee4-beb0-46fd-9e47-730a23ead816',
#           'name': 'TD Ballpark',
#           'surface': 'grass',
#           'ab': 17,
#           'runs': 7,
#           's': 2,
#           'd': 1,
#           't': 0,
#           'hr': 3,
#           'rbi': 8,
#           'bb': 5,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.5,
#           'slg': 0.941,
#           'ops': 1.441,
#           'h': 6,
#           'ktotal': 3,
#           'avg': '.353'},
#          {'id': 'fca673a0-c7f8-42c3-868b-5bcb681c089d',
#           'name': 'George M. Steinbrenner Field',
#           'surface': 'grass',
#           'ab': 5,
#           'runs': 1,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.2,
#           'slg': 0.2,
#           'ops': 0.4,
#           'h': 1,
#           'ktotal': 2,
#           'avg': '.200'},
#          {'id': '7f5ccc24-6f45-4c0f-8a20-378f8bbd3ba5',
#           'name': 'Spectrum Field',
#           'surface': 'grass',
#           'ab': 3,
#           'runs': 0,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 1,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.333,
#           'slg': 0.333,
#           'ops': 0.666,
#           'h': 1,
#           'ktotal': 1,
#           'avg': '.333'}],
#         'surface': [{'value': 'grass',
#           'ab': 25,
#           'runs': 8,
#           's': 4,
#           'd': 1,
#           't': 0,
#           'hr': 3,
#           'rbi': 9,
#           'bb': 5,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.433,
#           'slg': 0.72,
#           'ops': 1.153,
#           'h': 8,
#           'ktotal': 6,
#           'avg': '.320'}],
#         'month': [{'value': '3',
#           'ab': 15,
#           'runs': 6,
#           's': 3,
#           'd': 0,
#           't': 0,
#           'hr': 3,
#           'rbi': 8,
#           'bb': 3,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.5,
#           'slg': 1.0,
#           'ops': 1.5,
#           'h': 6,
#           'ktotal': 5,
#           'avg': '.400'},
#          {'value': '2',
#           'ab': 10,
#           'runs': 2,
#           's': 1,
#           'd': 1,
#           't': 0,
#           'hr': 0,
#           'rbi': 1,
#           'bb': 2,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.333,
#           'slg': 0.3,
#           'ops': 0.633,
#           'h': 2,
#           'ktotal': 1,
#           'avg': '.200'}],
#         'home_away': [{'value': 'away',
#           'ab': 8,
#           'runs': 1,
#           's': 2,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 1,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.25,
#           'slg': 0.25,
#           'ops': 0.5,
#           'h': 2,
#           'ktotal': 3,
#           'avg': '.250'},
#          {'value': 'home',
#           'ab': 17,
#           'runs': 7,
#           's': 2,
#           'd': 1,
#           't': 0,
#           'hr': 3,
#           'rbi': 8,
#           'bb': 5,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.5,
#           'slg': 0.941,
#           'ops': 1.441,
#           'h': 6,
#           'ktotal': 3,
#           'avg': '.353'}],
#         'pitcher_hand': [{'value': 'R',
#           'ab': 16,
#           'runs': 7,
#           's': 4,
#           'd': 0,
#           't': 0,
#           'hr': 2,
#           'rbi': 6,
#           'bb': 4,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.5,
#           'slg': 0.75,
#           'ops': 1.25,
#           'h': 6,
#           'ktotal': 5,
#           'avg': '.375'},
#          {'value': 'L',
#           'ab': 9,
#           'runs': 1,
#           's': 0,
#           'd': 1,
#           't': 0,
#           'hr': 1,
#           'rbi': 3,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.3,
#           'slg': 0.667,
#           'ops': 0.967,
#           'h': 2,
#           'ktotal': 1,
#           'avg': '.222'}],
#         'opponent': [{'id': '481dfe7e-5dab-46ab-a49f-9dcc2b6e2cfd',
#           'name': 'Pirates',
#           'market': 'Pittsburgh',
#           'abbr': 'PIT',
#           'ab': 4,
#           'runs': 2,
#           's': 0,
#           'd': 0,
#           't': 0,
#           'hr': 1,
#           'rbi': 2,
#           'bb': 2,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.5,
#           'slg': 1.0,
#           'ops': 1.5,
#           'h': 1,
#           'ktotal': 1,
#           'avg': '.250'},
#          {'id': '12079497-e414-450a-8bf2-29f91de646bf',
#           'name': 'Braves',
#           'market': 'Atlanta',
#           'abbr': 'ATL',
#           'ab': 1,
#           'runs': 1,
#           's': 0,
#           'd': 1,
#           't': 0,
#           'hr': 0,
#           'rbi': 1,
#           'bb': 2,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 1.0,
#           'slg': 2.0,
#           'ops': 3.0,
#           'h': 1,
#           'ktotal': 0,
#           'avg': '1.000'},
#          {'id': '2142e1ba-3b40-445c-b8bb-f1f8b1054220',
#           'name': 'Phillies',
#           'market': 'Philadelphia',
#           'abbr': 'PHI',
#           'ab': 8,
#           'runs': 1,
#           's': 2,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 1,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.333,
#           'slg': 0.25,
#           'ops': 0.583,
#           'h': 2,
#           'ktotal': 3,
#           'avg': '.250'},
#          {'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#           'name': 'Orioles',
#           'market': 'Baltimore',
#           'abbr': 'BAL',
#           'ab': 3,
#           'runs': 3,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 2,
#           'rbi': 5,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 1.0,
#           'slg': 3.0,
#           'ops': 4.0,
#           'h': 3,
#           'ktotal': 0,
#           'avg': '1.000'},
#          {'id': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d',
#           'name': 'Twins',
#           'market': 'Minnesota',
#           'abbr': 'MIN',
#           'ab': 2,
#           'runs': 0,
#           's': 0,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.0,
#           'slg': 0.0,
#           'ops': 0.0,
#           'h': 0,
#           'ktotal': 0,
#           'avg': '.000'},
#          {'id': 'a09ec676-f887-43dc-bbb3-cf4bbaee9a18',
#           'name': 'Yankees',
#           'market': 'New York',
#           'abbr': 'NYY',
#           'ab': 7,
#           'runs': 1,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.143,
#           'slg': 0.143,
#           'ops': 0.286,
#           'h': 1,
#           'ktotal': 2,
#           'avg': '.143'}]}]}}},
#    'teams': [{'name': 'Blue Jays',
#      'market': 'Toronto',
#      'abbr': 'TOR',
#      'id': '1d678440-b4b1-4954-9b39-70afb3ebbcfa',
#      'statistics': {'hitting': {'overall': {'ab': 25,
#         'lob': 10,
#         'rbi': 9,
#         'abhr': 8.333,
#         'abk': 4.167,
#         'bip': 16,
#         'babip': 0.313,
#         'bbk': 0.833,
#         'bbpa': 0.167,
#         'iso': 0.4,
#         'obp': 0.433,
#         'ops': 1.153,
#         'seca': 0.6,
#         'slg': 0.72,
#         'xbh': 4,
#         'pitch_count': 65,
#         'lob_risp_2out': 2,
#         'team_lob': 4,
#         'ab_risp': 10,
#         'hit_risp': 6,
#         'rbi_2out': 2,
#         'linedrive': 3,
#         'groundball': 7,
#         'popup': 1,
#         'flyball': 7,
#         'ap': 30,
#         'avg': '.320',
#         'gofo': 0.83,
#         'onbase': {'s': 4,
#          'd': 1,
#          't': 0,
#          'hr': 3,
#          'tb': 18,
#          'bb': 5,
#          'ibb': 0,
#          'hbp': 0,
#          'fc': 1,
#          'roe': 0,
#          'h': 8,
#          'cycle': 0},
#         'runs': {'total': 8},
#         'outcome': {'klook': 4,
#          'kswing': 17,
#          'ktotal': 21,
#          'ball': 24,
#          'iball': 0,
#          'dirtball': 0,
#          'foul': 1},
#         'outs': {'po': 1,
#          'fo': 4,
#          'fidp': 0,
#          'lo': 1,
#          'lidp': 0,
#          'go': 5,
#          'gidp': 0,
#          'klook': 1,
#          'kswing': 5,
#          'ktotal': 6,
#          'sacfly': 0,
#          'sachit': 0},
#         'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#         'pitches': {'count': 65, 'btotal': 24, 'ktotal': 41},
#         'games': {'start': 11, 'play': 11, 'finish': 0, 'complete': 0}}},
#       'fielding': {'overall': {'po': 9,
#         'a': 0,
#         'dp': 0,
#         'tp': 0,
#         'error': 0,
#         'tc': 9,
#         'fpct': 1.0,
#         'c_wp': 0,
#         'pb': 0,
#         'rf': 1.286,
#         'inn_1': 108,
#         'inn_2': 36.0,
#         'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#         'errors': {'throwing': 0,
#          'fielding': 0,
#          'interference': 0,
#          'total': 0},
#         'assists': {'outfield': 0, 'total': 0},
#         'games': {'start': 7, 'play': 7, 'finish': 0, 'complete': 0}},
#        'positions': [{'po': 9,
#          'a': 0,
#          'dp': 0,
#          'tp': 0,
#          'error': 0,
#          'tc': 9,
#          'fpct': 1.0,
#          'c_wp': 0,
#          'pb': 0,
#          'rf': 1.286,
#          'inn_1': 108,
#          'inn_2': 36.0,
#          'position': 'CF',
#          'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#          'errors': {'throwing': 0,
#           'fielding': 0,
#           'interference': 0,
#           'total': 0},
#          'assists': {'outfield': 0, 'total': 0},
#          'games': {'start': 7, 'play': 7, 'finish': 0, 'complete': 0}}]}},
#      'splits': {'hitting': {'overall': [{'total': [{'ab': 25,
#            'runs': 8,
#            's': 4,
#            'd': 1,
#            't': 0,
#            'hr': 3,
#            'rbi': 9,
#            'bb': 5,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.433,
#            'slg': 0.72,
#            'ops': 1.153,
#            'h': 8,
#            'ktotal': 6,
#            'avg': '.320'}],
#          'day_night': [{'value': 'day',
#            'ab': 25,
#            'runs': 8,
#            's': 4,
#            'd': 1,
#            't': 0,
#            'hr': 3,
#            'rbi': 9,
#            'bb': 5,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.433,
#            'slg': 0.72,
#            'ops': 1.153,
#            'h': 8,
#            'ktotal': 6,
#            'avg': '.320'}],
#          'venue': [{'id': '49a8bee4-beb0-46fd-9e47-730a23ead816',
#            'name': 'TD Ballpark',
#            'surface': 'grass',
#            'ab': 17,
#            'runs': 7,
#            's': 2,
#            'd': 1,
#            't': 0,
#            'hr': 3,
#            'rbi': 8,
#            'bb': 5,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.5,
#            'slg': 0.941,
#            'ops': 1.441,
#            'h': 6,
#            'ktotal': 3,
#            'avg': '.353'},
#           {'id': 'fca673a0-c7f8-42c3-868b-5bcb681c089d',
#            'name': 'George M. Steinbrenner Field',
#            'surface': 'grass',
#            'ab': 5,
#            'runs': 1,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.2,
#            'slg': 0.2,
#            'ops': 0.4,
#            'h': 1,
#            'ktotal': 2,
#            'avg': '.200'},
#           {'id': '7f5ccc24-6f45-4c0f-8a20-378f8bbd3ba5',
#            'name': 'Spectrum Field',
#            'surface': 'grass',
#            'ab': 3,
#            'runs': 0,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.333,
#            'slg': 0.333,
#            'ops': 0.666,
#            'h': 1,
#            'ktotal': 1,
#            'avg': '.333'}],
#          'surface': [{'value': 'grass',
#            'ab': 25,
#            'runs': 8,
#            's': 4,
#            'd': 1,
#            't': 0,
#            'hr': 3,
#            'rbi': 9,
#            'bb': 5,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.433,
#            'slg': 0.72,
#            'ops': 1.153,
#            'h': 8,
#            'ktotal': 6,
#            'avg': '.320'}],
#          'month': [{'value': '3',
#            'ab': 15,
#            'runs': 6,
#            's': 3,
#            'd': 0,
#            't': 0,
#            'hr': 3,
#            'rbi': 8,
#            'bb': 3,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.5,
#            'slg': 1.0,
#            'ops': 1.5,
#            'h': 6,
#            'ktotal': 5,
#            'avg': '.400'},
#           {'value': '2',
#            'ab': 10,
#            'runs': 2,
#            's': 1,
#            'd': 1,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 2,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.333,
#            'slg': 0.3,
#            'ops': 0.633,
#            'h': 2,
#            'ktotal': 1,
#            'avg': '.200'}],
#          'home_away': [{'value': 'away',
#            'ab': 8,
#            'runs': 1,
#            's': 2,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.25,
#            'slg': 0.25,
#            'ops': 0.5,
#            'h': 2,
#            'ktotal': 3,
#            'avg': '.250'},
#           {'value': 'home',
#            'ab': 17,
#            'runs': 7,
#            's': 2,
#            'd': 1,
#            't': 0,
#            'hr': 3,
#            'rbi': 8,
#            'bb': 5,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.5,
#            'slg': 0.941,
#            'ops': 1.441,
#            'h': 6,
#            'ktotal': 3,
#            'avg': '.353'}],
#          'pitcher_hand': [{'value': 'R',
#            'ab': 16,
#            'runs': 7,
#            's': 4,
#            'd': 0,
#            't': 0,
#            'hr': 2,
#            'rbi': 6,
#            'bb': 4,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.5,
#            'slg': 0.75,
#            'ops': 1.25,
#            'h': 6,
#            'ktotal': 5,
#            'avg': '.375'},
#           {'value': 'L',
#            'ab': 9,
#            'runs': 1,
#            's': 0,
#            'd': 1,
#            't': 0,
#            'hr': 1,
#            'rbi': 3,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.3,
#            'slg': 0.667,
#            'ops': 0.967,
#            'h': 2,
#            'ktotal': 1,
#            'avg': '.222'}],
#          'opponent': [{'id': '481dfe7e-5dab-46ab-a49f-9dcc2b6e2cfd',
#            'name': 'Pirates',
#            'market': 'Pittsburgh',
#            'abbr': 'PIT',
#            'ab': 4,
#            'runs': 2,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 1,
#            'rbi': 2,
#            'bb': 2,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.5,
#            'slg': 1.0,
#            'ops': 1.5,
#            'h': 1,
#            'ktotal': 1,
#            'avg': '.250'},
#           {'id': '12079497-e414-450a-8bf2-29f91de646bf',
#            'name': 'Braves',
#            'market': 'Atlanta',
#            'abbr': 'ATL',
#            'ab': 1,
#            'runs': 1,
#            's': 0,
#            'd': 1,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 2,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 1.0,
#            'slg': 2.0,
#            'ops': 3.0,
#            'h': 1,
#            'ktotal': 0,
#            'avg': '1.000'},
#           {'id': '2142e1ba-3b40-445c-b8bb-f1f8b1054220',
#            'name': 'Phillies',
#            'market': 'Philadelphia',
#            'abbr': 'PHI',
#            'ab': 8,
#            'runs': 1,
#            's': 2,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.333,
#            'slg': 0.25,
#            'ops': 0.583,
#            'h': 2,
#            'ktotal': 3,
#            'avg': '.250'},
#           {'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#            'name': 'Orioles',
#            'market': 'Baltimore',
#            'abbr': 'BAL',
#            'ab': 3,
#            'runs': 3,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 2,
#            'rbi': 5,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 1.0,
#            'slg': 3.0,
#            'ops': 4.0,
#            'h': 3,
#            'ktotal': 0,
#            'avg': '1.000'},
#           {'id': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d',
#            'name': 'Twins',
#            'market': 'Minnesota',
#            'abbr': 'MIN',
#            'ab': 2,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.0,
#            'slg': 0.0,
#            'ops': 0.0,
#            'h': 0,
#            'ktotal': 0,
#            'avg': '.000'},
#           {'id': 'a09ec676-f887-43dc-bbb3-cf4bbaee9a18',
#            'name': 'Yankees',
#            'market': 'New York',
#            'abbr': 'NYY',
#            'ab': 7,
#            'runs': 1,
#            's': 1,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.143,
#            'slg': 0.143,
#            'ops': 0.286,
#            'h': 1,
#            'ktotal': 2,
#            'avg': '.143'}]}]}}}]},
#   {'id': 'd790e0e3-a022-4da3-9507-e127cae8dea2',
#    'year': 2020,
#    'type': 'REG',
#    'totals': {'statistics': {'hitting': {'overall': {'ab': 216,
#        'lob': 93,
#        'rbi': 35,
#        'abhr': 18.0,
#        'abk': 4.408,
#        'bip': 157,
#        'babip': 0.299,
#        'bbk': 0.265,
#        'bbpa': 0.056,
#        'iso': 0.208,
#        'obp': 0.312,
#        'ops': 0.793,
#        'seca': 0.269,
#        'slg': 0.481,
#        'xbh': 21,
#        'pitch_count': 855,
#        'lob_risp_2out': 27,
#        'team_lob': 51,
#        'ab_risp': 62,
#        'hit_risp': 19,
#        'rbi_2out': 14,
#        'linedrive': 44,
#        'groundball': 72,
#        'popup': 18,
#        'flyball': 35,
#        'ap': 231,
#        'avg': '.273',
#        'gofo': 0.92,
#        'onbase': {'s': 38,
#         'd': 9,
#         't': 0,
#         'hr': 12,
#         'tb': 104,
#         'bb': 12,
#         'ibb': 1,
#         'hbp': 0,
#         'fc': 8,
#         'roe': 2,
#         'h': 59,
#         'cycle': 0},
#        'runs': {'total': 38},
#        'outcome': {'klook': 124,
#         'kswing': 101,
#         'ktotal': 225,
#         'ball': 271,
#         'iball': 0,
#         'dirtball': 19,
#         'foul': 171},
#        'outs': {'po': 16,
#         'fo': 27,
#         'fidp': 0,
#         'lo': 17,
#         'lidp': 0,
#         'go': 55,
#         'gidp': 5,
#         'klook': 5,
#         'kswing': 44,
#         'ktotal': 49,
#         'sacfly': 2,
#         'sachit': 0},
#        'steal': {'caught': 1, 'stolen': 1, 'pct': 0.5, 'pickoff': 0},
#        'pitches': {'count': 855, 'btotal': 290, 'ktotal': 565},
#        'games': {'start': 54, 'play': 55, 'finish': 1, 'complete': 50}}},
#      'fielding': {'overall': {'po': 96,
#        'a': 2,
#        'dp': 0,
#        'tp': 0,
#        'error': 1,
#        'tc': 99,
#        'fpct': 0.99,
#        'c_wp': 0,
#        'pb': 0,
#        'rf': 2.042,
#        'inn_1': 1199,
#        'inn_2': 399.2,
#        'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#        'errors': {'throwing': 0, 'fielding': 1, 'interference': 0, 'total': 1},
#        'assists': {'outfield': 2, 'total': 2},
#        'games': {'start': 47, 'play': 48, 'finish': 1, 'complete': 0}},
#       'positions': [{'po': 96,
#         'a': 2,
#         'dp': 0,
#         'tp': 0,
#         'error': 1,
#         'tc': 99,
#         'fpct': 0.99,
#         'c_wp': 0,
#         'pb': 0,
#         'rf': 2.042,
#         'inn_1': 1199,
#         'inn_2': 399.2,
#         'position': 'CF',
#         'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#         'errors': {'throwing': 0,
#          'fielding': 1,
#          'interference': 0,
#          'total': 1},
#         'assists': {'outfield': 2, 'total': 2},
#         'games': {'start': 47, 'play': 48, 'finish': 1, 'complete': 0}}]}},
#     'splits': {'hitting': {'overall': [{'total': [{'ab': 216,
#           'runs': 38,
#           's': 38,
#           'd': 9,
#           't': 0,
#           'hr': 12,
#           'rbi': 35,
#           'bb': 12,
#           'ibb': 1,
#           'hbp': 0,
#           'sb': 1,
#           'cs': 1,
#           'obp': 0.312,
#           'slg': 0.481,
#           'ops': 0.793,
#           'h': 59,
#           'ktotal': 49,
#           'avg': '.273'}],
#         'day_night': [{'value': 'night',
#           'ab': 154,
#           'runs': 24,
#           's': 29,
#           'd': 4,
#           't': 0,
#           'hr': 8,
#           'rbi': 24,
#           'bb': 8,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 1,
#           'cs': 1,
#           'obp': 0.301,
#           'slg': 0.448,
#           'ops': 0.749,
#           'h': 41,
#           'ktotal': 38,
#           'avg': '.266'},
#          {'value': 'day',
#           'ab': 62,
#           'runs': 14,
#           's': 9,
#           'd': 5,
#           't': 0,
#           'hr': 4,
#           'rbi': 11,
#           'bb': 4,
#           'ibb': 1,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.338,
#           'slg': 0.565,
#           'ops': 0.903,
#           'h': 18,
#           'ktotal': 11,
#           'avg': '.290'}],
#         'venue': [{'id': '706e9828-6687-4ac8-a409-3fb972e8bae9',
#           'name': 'Yankee Stadium',
#           'market': 'New York',
#           'surface': 'grass',
#           'ab': 12,
#           'runs': 0,
#           's': 2,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.167,
#           'slg': 0.167,
#           'ops': 0.334,
#           'h': 2,
#           'ktotal': 3,
#           'avg': '.167'},
#          {'id': 'b27b0dc5-c2c5-401d-b8b9-a6a2dbc225e5',
#           'name': 'Fenway Park',
#           'market': 'Boston',
#           'surface': 'grass',
#           'ab': 28,
#           'runs': 4,
#           's': 6,
#           'd': 2,
#           't': 0,
#           'hr': 0,
#           'rbi': 2,
#           'bb': 2,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 1,
#           'obp': 0.333,
#           'slg': 0.357,
#           'ops': 0.69,
#           'h': 8,
#           'ktotal': 5,
#           'avg': '.286'},
#          {'id': 'b4186004-b6d0-42e7-8dc1-82ef0d946ecc',
#           'name': 'Citizens Bank Park',
#           'market': 'Philadelphia',
#           'surface': 'grass',
#           'ab': 13,
#           'runs': 1,
#           's': 1,
#           'd': 1,
#           't': 0,
#           'hr': 0,
#           'rbi': 1,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.143,
#           'slg': 0.231,
#           'ops': 0.374,
#           'h': 2,
#           'ktotal': 2,
#           'avg': '.154'},
#          {'id': '434aa63c-1049-4a54-a6bc-3790c7772ee1',
#           'name': 'Oriole Park at Camden Yards',
#           'market': 'Baltimore',
#           'surface': 'grass',
#           'ab': 14,
#           'runs': 5,
#           's': 1,
#           'd': 1,
#           't': 0,
#           'hr': 4,
#           'rbi': 11,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.429,
#           'slg': 1.357,
#           'ops': 1.786,
#           'h': 6,
#           'ktotal': 1,
#           'avg': '.429'},
#          {'id': '3aaaf4af-0f8c-49c1-8bf1-1780bb5a5f5c',
#           'name': 'Tropicana Field',
#           'market': 'Tampa Bay',
#           'surface': 'turf',
#           'ab': 29,
#           'runs': 2,
#           's': 5,
#           'd': 3,
#           't': 0,
#           'hr': 1,
#           'rbi': 5,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.333,
#           'slg': 0.517,
#           'ops': 0.85,
#           'h': 9,
#           'ktotal': 5,
#           'avg': '.310'},
#          {'id': 'd5a66fb3-ff26-4f36-910c-3df5cedb36b3',
#           'name': 'Marlins Park',
#           'market': 'Miami',
#           'surface': 'grass',
#           'ab': 8,
#           'runs': 0,
#           's': 0,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 0,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.0,
#           'slg': 0.0,
#           'ops': 0.0,
#           'h': 0,
#           'ktotal': 4,
#           'avg': '.000'},
#          {'id': '3ca8b577-5844-42ed-81a5-bd5d5cbe350c',
#           'name': 'Truist Park',
#           'market': 'Atlanta',
#           'surface': 'grass',
#           'ab': 10,
#           'runs': 0,
#           's': 1,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 0,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.182,
#           'slg': 0.1,
#           'ops': 0.282,
#           'h': 1,
#           'ktotal': 5,
#           'avg': '.100'},
#          {'id': 'cfbfd665-07a1-434f-8cca-8b626761df00',
#           'name': 'Sahlen Field',
#           'surface': 'grass',
#           'ab': 102,
#           'runs': 26,
#           's': 22,
#           'd': 2,
#           't': 0,
#           'hr': 7,
#           'rbi': 16,
#           'bb': 8,
#           'ibb': 1,
#           'hbp': 0,
#           'sb': 1,
#           'cs': 0,
#           'obp': 0.357,
#           'slg': 0.529,
#           'ops': 0.886,
#           'h': 31,
#           'ktotal': 24,
#           'avg': '.304'}],
#         'surface': [{'value': 'grass',
#           'ab': 187,
#           'runs': 36,
#           's': 33,
#           'd': 6,
#           't': 0,
#           'hr': 11,
#           'rbi': 30,
#           'bb': 11,
#           'ibb': 1,
#           'hbp': 0,
#           'sb': 1,
#           'cs': 1,
#           'obp': 0.308,
#           'slg': 0.476,
#           'ops': 0.784,
#           'h': 50,
#           'ktotal': 44,
#           'avg': '.267'},
#          {'value': 'turf',
#           'ab': 29,
#           'runs': 2,
#           's': 5,
#           'd': 3,
#           't': 0,
#           'hr': 1,
#           'rbi': 5,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.333,
#           'slg': 0.517,
#           'ops': 0.85,
#           'h': 9,
#           'ktotal': 5,
#           'avg': '.310'}],
#         'month': [{'value': '9',
#           'ab': 98,
#           'runs': 17,
#           's': 18,
#           'd': 3,
#           't': 0,
#           'hr': 3,
#           'rbi': 11,
#           'bb': 5,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 1,
#           'cs': 0,
#           'obp': 0.279,
#           'slg': 0.367,
#           'ops': 0.646,
#           'h': 24,
#           'ktotal': 21,
#           'avg': '.245'},
#          {'value': '8',
#           'ab': 108,
#           'runs': 20,
#           's': 16,
#           'd': 6,
#           't': 0,
#           'hr': 9,
#           'rbi': 23,
#           'bb': 6,
#           'ibb': 1,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 1,
#           'obp': 0.328,
#           'slg': 0.593,
#           'ops': 0.921,
#           'h': 31,
#           'ktotal': 28,
#           'avg': '.287'},
#          {'value': '7',
#           'ab': 10,
#           'runs': 1,
#           's': 4,
#           'd': 0,
#           't': 0,
#           'hr': 0,
#           'rbi': 1,
#           'bb': 1,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.455,
#           'slg': 0.4,
#           'ops': 0.855,
#           'h': 4,
#           'ktotal': 0,
#           'avg': '.400'}],
#         'home_away': [{'value': 'away',
#           'ab': 111,
#           'runs': 11,
#           's': 16,
#           'd': 6,
#           't': 0,
#           'hr': 5,
#           'rbi': 19,
#           'bb': 4,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 1,
#           'obp': 0.267,
#           'slg': 0.432,
#           'ops': 0.699,
#           'h': 27,
#           'ktotal': 25,
#           'avg': '.243'},
#          {'value': 'home',
#           'ab': 105,
#           'runs': 27,
#           's': 22,
#           'd': 3,
#           't': 0,
#           'hr': 7,
#           'rbi': 16,
#           'bb': 8,
#           'ibb': 1,
#           'hbp': 0,
#           'sb': 1,
#           'cs': 0,
#           'obp': 0.357,
#           'slg': 0.533,
#           'ops': 0.89,
#           'h': 32,
#           'ktotal': 24,
#           'avg': '.305'}],
#         'pitcher_hand': [{'value': 'R',
#           'ab': 155,
#           'runs': 29,
#           's': 26,
#           'd': 5,
#           't': 0,
#           'hr': 8,
#           'rbi': 26,
#           'bb': 9,
#           'ibb': 1,
#           'hbp': 0,
#           'sb': 1,
#           'cs': 1,
#           'obp': 0.293,
#           'slg': 0.439,
#           'ops': 0.732,
#           'h': 39,
#           'ktotal': 38,
#           'avg': '.252'},
#          {'value': 'L',
#           'ab': 61,
#           'runs': 9,
#           's': 12,
#           'd': 4,
#           't': 0,
#           'hr': 4,
#           'rbi': 9,
#           'bb': 3,
#           'ibb': 0,
#           'hbp': 0,
#           'sb': 0,
#           'cs': 0,
#           'obp': 0.359,
#           'slg': 0.59,
#           'ops': 0.949,
#           'h': 20,
#           'ktotal': 11,
#           'avg': '.328'}],
# ...
#            'runs': 32,
#            's': 27,
#            'd': 16,
#            't': 5,
#            'hr': 11,
#            'rbi': 33,
#            'bb': 16,
#            'ibb': 2,
#            'hbp': 3,
#            'sb': 2,
#            'cs': 1,
#            'obp': 0.345,
#            'slg': 0.562,
#            'ops': 0.907,
#            'h': 59,
#            'ktotal': 76,
#            'avg': '.281'}],
#          'opponent': [{'id': '2142e1ba-3b40-445c-b8bb-f1f8b1054220',
#            'name': 'Phillies',
#            'market': 'Philadelphia',
#            'abbr': 'PHI',
#            'ab': 14,
#            'runs': 5,
#            's': 2,
#            'd': 1,
#            't': 0,
#            'hr': 3,
#            'rbi': 5,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.467,
#            'slg': 1.143,
#            'ops': 1.61,
#            'h': 6,
#            'ktotal': 5,
#            'avg': '.429'},
#           {'id': '575c19b7-4052-41c2-9f0a-1c5813d02f99',
#            'name': 'Tigers',
#            'market': 'Detroit',
#            'abbr': 'DET',
#            'ab': 5,
#            'runs': 0,
#            's': 1,
#            'd': 1,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.5,
#            'slg': 0.6,
#            'ops': 1.1,
#            'h': 2,
#            'ktotal': 0,
#            'avg': '.400'},
#           {'id': '29dd9a87-5bcc-4774-80c3-7f50d985068b',
#            'name': 'Rockies',
#            'market': 'Colorado',
#            'abbr': 'COL',
#            'ab': 28,
#            'runs': 4,
#            's': 4,
#            'd': 2,
#            't': 0,
#            'hr': 2,
#            'rbi': 3,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.31,
#            'slg': 0.571,
#            'ops': 0.881,
#            'h': 8,
#            'ktotal': 10,
#            'avg': '.286'},
#           {'id': 'c874a065-c115-4e7d-b0f0-235584fb0e6f',
#            'name': 'Reds',
#            'market': 'Cincinnati',
#            'abbr': 'CIN',
#            'ab': 29,
#            'runs': 5,
#            's': 2,
#            'd': 1,
#            't': 1,
#            'hr': 3,
#            'rbi': 5,
#            'bb': 2,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.29,
#            'slg': 0.655,
#            'ops': 0.945,
#            'h': 7,
#            'ktotal': 10,
#            'avg': '.241'},
#           {'id': '481dfe7e-5dab-46ab-a49f-9dcc2b6e2cfd',
#            'name': 'Pirates',
#            'market': 'Pittsburgh',
#            'abbr': 'PIT',
#            'ab': 35,
#            'runs': 4,
#            's': 7,
#            'd': 3,
#            't': 0,
#            'hr': 0,
#            'rbi': 2,
#            'bb': 2,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 1,
#            'obp': 0.324,
#            'slg': 0.371,
#            'ops': 0.695,
#            'h': 10,
#            'ktotal': 10,
#            'avg': '.286'},
#           {'id': 'f246a5e5-afdb-479c-9aaa-c68beeda7af6',
#            'name': 'Mets',
#            'market': 'New York',
#            'abbr': 'NYM',
#            'ab': 31,
#            'runs': 5,
#            's': 1,
#            'd': 4,
#            't': 2,
#            'hr': 2,
#            'rbi': 10,
#            'bb': 1,
#            'ibb': 1,
#            'hbp': 2,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.371,
#            'slg': 0.742,
#            'ops': 1.113,
#            'h': 9,
#            'ktotal': 13,
#            'avg': '.290'},
#           {'id': 'dcfd5266-00ce-442c-bc09-264cd20cf455',
#            'name': 'Brewers',
#            'market': 'Milwaukee',
#            'abbr': 'MIL',
#            'ab': 32,
#            'runs': 5,
#            's': 5,
#            'd': 3,
#            't': 0,
#            'hr': 1,
#            'rbi': 4,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.303,
#            'slg': 0.469,
#            'ops': 0.772,
#            'h': 9,
#            'ktotal': 10,
#            'avg': '.281'},
#           {'id': '25507be1-6a68-4267-bd82-e097d94b359b',
#            'name': 'Diamondbacks',
#            'market': 'Arizona',
#            'abbr': 'ARI',
#            'ab': 8,
#            'runs': 1,
#            's': 3,
#            'd': 1,
#            't': 0,
#            'hr': 1,
#            'rbi': 2,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 1,
#            'cs': 0,
#            'obp': 0.625,
#            'slg': 1.125,
#            'ops': 1.75,
#            'h': 5,
#            'ktotal': 1,
#            'avg': '.625'},
#           {'id': '833a51a9-0d84-410f-bd77-da08c3e5e26e',
#            'name': 'Royals',
#            'market': 'Kansas City',
#            'abbr': 'KC',
#            'ab': 21,
#            'runs': 3,
#            's': 4,
#            'd': 0,
#            't': 1,
#            'hr': 1,
#            'rbi': 3,
#            'bb': 1,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.318,
#            'slg': 0.524,
#            'ops': 0.842,
#            'h': 6,
#            'ktotal': 5,
#            'avg': '.286'},
#           {'id': '55714da8-fcaf-4574-8443-59bfb511a524',
#            'name': 'Cubs',
#            'market': 'Chicago',
#            'abbr': 'CHC',
#            'ab': 27,
#            'runs': 6,
#            's': 1,
#            'd': 2,
#            't': 2,
#            'hr': 1,
#            'rbi': 7,
#            'bb': 2,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.276,
#            'slg': 0.556,
#            'ops': 0.832,
#            'h': 6,
#            'ktotal': 13,
#            'avg': '.222'},
#           {'id': '12079497-e414-450a-8bf2-29f91de646bf',
#            'name': 'Braves',
#            'market': 'Atlanta',
#            'abbr': 'ATL',
#            'ab': 16,
#            'runs': 2,
#            's': 3,
#            'd': 1,
#            't': 0,
#            'hr': 1,
#            'rbi': 2,
#            'bb': 2,
#            'ibb': 0,
#            'hbp': 1,
#            'sb': 1,
#            'cs': 0,
#            'obp': 0.421,
#            'slg': 0.563,
#            'ops': 0.984,
#            'h': 5,
#            'ktotal': 7,
#            'avg': '.313'},
#           {'id': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d',
#            'name': 'Twins',
#            'market': 'Minnesota',
#            'abbr': 'MIN',
#            'ab': 10,
#            'runs': 1,
#            's': 2,
#            'd': 0,
#            't': 1,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 1,
#            'cs': 0,
#            'obp': 0.273,
#            'slg': 0.5,
#            'ops': 0.773,
#            'h': 3,
#            'ktotal': 5,
#            'avg': '.300'},
#           {'id': '03556285-bdbb-4576-a06d-42f71f46ddc5',
#            'name': 'Marlins',
#            'market': 'Miami',
#            'abbr': 'MIA',
#            'ab': 17,
#            'runs': 5,
#            's': 3,
#            'd': 1,
#            't': 0,
#            'hr': 1,
#            'rbi': 1,
#            'bb': 4,
#            'ibb': 0,
#            'hbp': 1,
#            'sb': 1,
#            'cs': 1,
#            'obp': 0.455,
#            'slg': 0.529,
#            'ops': 0.984,
#            'h': 5,
#            'ktotal': 4,
#            'avg': '.294'},
#           {'id': '47f490cd-2f58-4ef7-9dfd-2ad6ba6c1ae8',
#            'name': 'White Sox',
#            'market': 'Chicago',
#            'abbr': 'CWS',
#            'ab': 18,
#            'runs': 2,
#            's': 2,
#            'd': 1,
#            't': 0,
#            'hr': 1,
#            'rbi': 1,
#            'bb': 0,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.222,
#            'slg': 0.444,
#            'ops': 0.666,
#            'h': 4,
#            'ktotal': 6,
#            'avg': '.222'},
#           {'id': 'd52d5339-cbdd-43f3-9dfa-a42fd588b9a3',
#            'name': 'Padres',
#            'market': 'San Diego',
#            'abbr': 'SD',
#            'ab': 12,
#            'runs': 0,
#            's': 0,
#            'd': 0,
#            't': 0,
#            'hr': 0,
#            'rbi': 0,
#            'bb': 2,
#            'ibb': 0,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.143,
#            'slg': 0.0,
#            'ops': 0.143,
#            'h': 0,
#            'ktotal': 4,
#            'avg': '.000'},
#           {'id': 'ef64da7f-cfaf-4300-87b0-9313386b977c',
#            'name': 'Dodgers',
#            'market': 'Los Angeles',
#            'abbr': 'LAD',
#            'ab': 20,
#            'runs': 1,
#            's': 2,
#            'd': 2,
#            't': 0,
#            'hr': 0,
#            'rbi': 1,
#            'bb': 0,
#            'ibb': 1,
#            'hbp': 0,
#            'sb': 0,
#            'cs': 0,
#            'obp': 0.238,
#            'slg': 0.3,
#            'ops': 0.538,
#            'h': 4,
#            'ktotal': 7,
#            'avg': '.200'}]}]}}}]},
#   {'id': '8f4e3a30-8444-11e3-808c-22000a904a71',
#    'year': 2014,
#    'type': 'PST',
#    'totals': {'statistics': {'hitting': {'overall': {'ab': 35,
#        'lob': 8,
#        'rbi': 3,
#        'abhr': 17.5,
#        'abk': 2.692,
#        'bip': 20,
#        'babip': 0.2,
#        'bbk': 0.077,
#        'bbpa': 0.028,
#        'iso': 0.172,
#        'obp': 0.194,
#        'ops': 0.537,
#        'seca': 0.2,
#        'slg': 0.343,
#        'xbh': 2,
#        'pitch_count': 149,
#        'ap': 36,
#        'avg': '.171',
#        'gofo': 0.46,
#        'onbase': {'s': 4,
#         'd': 0,
#         't': 0,
#         'hr': 2,
#         'tb': 12,
#         'bb': 1,
#         'ibb': 0,
#         'hbp': 0,
#         'fc': 0,
#         'roe': 0,
#         'h': 6,
#         'cycle': 0},
#        'runs': {'total': 3},
#        'outcome': {'klook': 16,
#         'kswing': 12,
#         'ktotal': 28,
#         'ball': 52,
#         'iball': 0,
#         'dirtball': 1,
#         'foul': 0},
#        'outs': {'po': 4,
#         'fo': 6,
#         'fidp': 0,
#         'lo': 1,
#         'lidp': 0,
#         'go': 5,
#         'gidp': 0,
#         'klook': 1,
#         'kswing': 12,
#         'ktotal': 13,
#         'sacfly': 0,
#         'sachit': 0},
#        'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#        'games': {'start': 9, 'play': 9, 'finish': 0, 'complete': 9}}},
#      'fielding': {'overall': {'po': 15,
#        'a': 0,
#        'dp': 0,
#        'tp': 0,
#        'error': 0,
#        'tc': 15,
#        'fpct': 1.0,
#        'rf': 1.5,
#        'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#        'errors': {'throwing': 0, 'fielding': 0, 'interference': 0, 'total': 0},
#        'games': {'start': 9, 'play': 10, 'finish': 1, 'complete': 1}}}}},
#    'teams': [{'name': 'Cardinals',
#      'market': 'St. Louis',
#      'abbr': 'STL',
#      'id': '44671792-dc02-4fdd-a5ad-f5f17edaa9d7',
#      'statistics': {'hitting': {'overall': {'ab': 35,
#         'lob': 8,
#         'rbi': 3,
#         'abhr': 17.5,
#         'abk': 2.692,
#         'bip': 20,
#         'babip': 0.2,
#         'bbk': 0.077,
#         'bbpa': 0.028,
#         'iso': 0.172,
#         'obp': 0.194,
#         'ops': 0.537,
#         'seca': 0.2,
#         'slg': 0.343,
#         'xbh': 2,
#         'pitch_count': 149,
#         'ap': 36,
#         'avg': '.171',
#         'gofo': 0.46,
#         'onbase': {'s': 4,
#          'd': 0,
#          't': 0,
#          'hr': 2,
#          'tb': 12,
#          'bb': 1,
#          'ibb': 0,
#          'hbp': 0,
#          'fc': 0,
#          'roe': 0,
#          'h': 6,
#          'cycle': 0},
#         'runs': {'total': 3},
#         'outcome': {'klook': 16,
#          'kswing': 12,
#          'ktotal': 28,
#          'ball': 52,
#          'iball': 0,
#          'dirtball': 1,
#          'foul': 0},
#         'outs': {'po': 4,
#          'fo': 6,
#          'fidp': 0,
#          'lo': 1,
#          'lidp': 0,
#          'go': 5,
#          'gidp': 0,
#          'klook': 1,
#          'kswing': 12,
#          'ktotal': 13,
#          'sacfly': 0,
#          'sachit': 0},
#         'steal': {'caught': 0, 'stolen': 0, 'pct': 0, 'pickoff': 0},
#         'games': {'start': 9, 'play': 9, 'finish': 0, 'complete': 9}}},
#       'fielding': {'overall': {'po': 15,
#         'a': 0,
#         'dp': 0,
#         'tp': 0,
#         'error': 0,
#         'tc': 15,
#         'fpct': 1.0,
#         'rf': 1.5,
#         'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#         'errors': {'throwing': 0,
#          'fielding': 0,
#          'interference': 0,
#          'total': 0},
#         'games': {'start': 9, 'play': 10, 'finish': 1, 'complete': 1}}}}}]},
#   {'id': '8f4e3a30-8444-11e3-808c-22000a904a71',
#    'year': 2014,
#    'type': 'REG',
#    'totals': {'statistics': {'hitting': {'overall': {'ab': 110,
#        'lob': 46,
#        'rbi': 8,
#        'abhr': 36.667,
#        'abk': 3.548,
#        'bip': 76,
#        'babip': 0.316,
#        'bbk': 0.161,
#        'bbpa': 0.043,
#        'iso': 0.155,
#        'obp': 0.278,
#        'ops': 0.678,
#        'seca': 0.182,
#        'slg': 0.4,
#        'xbh': 10,
#        'pitch_count': 454,
#        'ap': 116,
#        'avg': '.245',
#        'gofo': 0.84,
#        'onbase': {'s': 17,
#         'd': 6,
#         't': 1,
#         'hr': 3,
#         'tb': 44,
#         'bb': 5,
#         'ibb': 0,
#         'hbp': 0,
#         'fc': 2,
#         'roe': 1,
#         'h': 27,
#         'cycle': 0},
#        'runs': {'total': 11},
#        'outcome': {'klook': 60,
#         'kswing': 47,
#         'ktotal': 107,
#         'ball': 139,
#         'iball': 0,
#         'dirtball': 10,
#         'foul': 0},
#        'outs': {'po': 10,
#         'fo': 16,
#         'fidp': 0,
#         'lo': 5,
#         'lidp': 0,
#         'go': 26,
#         'gidp': 4,
#         'klook': 8,
#         'kswing': 23,
#         'ktotal': 31,
#         'sacfly': 0,
#         'sachit': 1},
#        'steal': {'caught': 2, 'stolen': 0, 'pct': 0.0, 'pickoff': 1},
#        'games': {'start': 22, 'play': 47, 'finish': 19, 'complete': 19}}},
#      'fielding': {'overall': {'po': 54,
#        'a': 2,
#        'dp': 0,
#        'tp': 0,
#        'error': 2,
#        'tc': 58,
#        'fpct': 0.966,
#        'rf': 1.474,
#        'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#        'errors': {'throwing': 0, 'fielding': 0, 'interference': 0, 'total': 2},
#        'games': {'start': 22, 'play': 38, 'finish': 15, 'complete': 2}}}}},
#    'teams': [{'name': 'Cardinals',
#      'market': 'St. Louis',
#      'abbr': 'STL',
#      'id': '44671792-dc02-4fdd-a5ad-f5f17edaa9d7',
#      'statistics': {'hitting': {'overall': {'ab': 110,
#         'lob': 46,
#         'rbi': 8,
#         'abhr': 36.667,
#         'abk': 3.548,
#         'bip': 76,
#         'babip': 0.316,
#         'bbk': 0.161,
#         'bbpa': 0.043,
#         'iso': 0.155,
#         'obp': 0.278,
#         'ops': 0.678,
#         'seca': 0.182,
#         'slg': 0.4,
#         'xbh': 10,
#         'pitch_count': 454,
#         'ap': 116,
#         'avg': '.245',
#         'gofo': 0.84,
#         'onbase': {'s': 17,
#          'd': 6,
#          't': 1,
#          'hr': 3,
#          'tb': 44,
#          'bb': 5,
#          'ibb': 0,
#          'hbp': 0,
#          'fc': 2,
#          'roe': 1,
#          'h': 27,
#          'cycle': 0},
#         'runs': {'total': 11},
#         'outcome': {'klook': 60,
#          'kswing': 47,
#          'ktotal': 107,
#          'ball': 139,
#          'iball': 0,
#          'dirtball': 10,
#          'foul': 0},
#         'outs': {'po': 10,
#          'fo': 16,
#          'fidp': 0,
#          'lo': 5,
#          'lidp': 0,
#          'go': 26,
#          'gidp': 4,
#          'klook': 8,
#          'kswing': 23,
#          'ktotal': 31,
#          'sacfly': 0,
#          'sachit': 1},
#         'steal': {'caught': 2, 'stolen': 0, 'pct': 0.0, 'pickoff': 1},
#         'games': {'start': 22, 'play': 47, 'finish': 19, 'complete': 19}}},
#       'fielding': {'overall': {'po': 54,
#         'a': 2,
#         'dp': 0,
#         'tp': 0,
#         'error': 2,
#         'tc': 58,
#         'fpct': 0.966,
#         'rf': 1.474,
#         'steal': {'caught': 0, 'stolen': 0, 'pickoff': 0, 'pct': 0},
#         'errors': {'throwing': 0,
#          'fielding': 0,
#          'interference': 0,
#          'total': 2},
#         'games': {'start': 22, 'play': 38, 'finish': 15, 'complete': 2}}}}}]}]}

# %%
import json

# %%
def get_All_the_ids(teams):
    player_id =[]
    for team in teams:
        for position in team.get("positions",[]):
            for player in position.get("players",{}):
#                 player_id.append((player.get("id","N/A"),
#                                  player.get("preferred_name","N/A"),
#                                  player.get("last_name","N/A")))
                player_id.append({"id": player.get("id","N/A"),
                         "preferred_name":player.get("preferred_name","N/A"),
                         "last_name":player.get("last_name","N/A")})
    return player_id

# %%
playas = get_All_the_ids(data["teams"])

# %%
playas

# %%
len(get_All_the_ids(data["teams"]))

# %%
def get_all_the_teams(teams):
    team_names = []
    for team in teams:
        team_names.append([teams])

# %%
get_All_the_ids(data)

# %%
response['player']['seasons'][0]['totals']['statcast_metrics']['hitting']['overall'][5]['barreled_ball']['count']
# Out:
# 46

# %%
response
# Out:
# 2

# %%
def getseasonAllseasons(seasons):
    seasonsYears = []
    for season in seasons:
        seasonsYears.append([season.get('year','N/A'),season.get('type','N/A')])
    return seasonsYears
